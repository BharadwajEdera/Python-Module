# %% [markdown]
# Table of Contents:
# >11. Deleting Data from Database and Table
#
# >12. Update Table in the Database

# %% [markdown]
# ### 11. Deleting Data from Database and Table

# %%
import mysql.connector as connection
conn = connection.connect(host="127.0.0.1", database = "test456" ,user="root", passwd="Bharadwaja01",use_pure=True)

# %%
conn.is_connected()
# Out:
# True

# %%
cur = conn.cursor()

# %%
cur.execute("select * from test456.test")
cur.fetchall()
# Out:
# [(1234, 'Bharadwaja', datetime.date(2021, 5, 16)),
#  (1234, 'Bharadwaja', datetime.date(2021, 5, 16)),
#  (1234, 'Bharadwaja', datetime.date(2021, 5, 16))]

# %% [markdown]
# ![20.PNG](attachment:20.PNG)

# %%
conn = connection.connect(host="127.0.0.1", database = "test456" ,user="root", passwd="Bharadwaja01",use_pure=True)
cur = conn.cursor()
cur.execute("delete from test where x1 = 1234")
conn.commit()

# %%
conn = connection.connect(host="127.0.0.1", database = "test456" ,user="root", passwd="Bharadwaja01",use_pure=True)
cur = conn.cursor()
cur.execute("select * from test456.test")
cur.fetchall()
# Out:
# []

# %% [markdown]
# ![21.PNG](attachment:21.PNG)

# %% [markdown]
# ### 12. Update Table in the Database

# %%
conn = connection.connect(host="127.0.0.1", database = "test456" ,user="root", passwd="Bharadwaja01",use_pure=True)
cur = conn.cursor()
cur.execute("insert into test values(20104 , 'Bharadwaja' , '2021-05-18'  )  " )
cur.execute("insert into test values(20105 , 'Chinni' , '2021-05-18'  )  " )
cur.execute("insert into test values(20106 , 'Chinnu' , '2021-05-18'  )  " )
conn.commit()

# %%
cur.execute("select * from test456.test")
cur.fetchall()
# Out:
# [(None, None, None),
#  (None, None, None),
#  (20104, 'Bharadwaja', datetime.date(2021, 5, 18)),
#  (20104, 'Bharadwaja', datetime.date(2021, 5, 18)),
#  (20105, 'Chinni', datetime.date(2021, 5, 18)),
#  (20106, 'Chinnu', datetime.date(2021, 5, 18))]

# %%
conn = connection.connect(host="127.0.0.1", database = "test456" ,user="root", passwd="Bharadwaja01",use_pure=True)
cur = conn.cursor()
cur.execute("update test set x1= 23456 , x2 = 'Sai' , x3 ='2021-05-18' where x1=20104 " )
conn.commit()

# %%
cur.execute("select * from test456.test")
cur.fetchall()
# Out:
# [(None, None, None),
#  (None, None, None),
#  (23456, 'Sai', datetime.date(2021, 5, 18)),
#  (23456, 'Sai', datetime.date(2021, 5, 18)),
#  (20105, 'Chinni', datetime.date(2021, 5, 18)),
#  (20106, 'Chinnu', datetime.date(2021, 5, 18))]

# %% [markdown]
# ### INTRODUCTION TO SQL
# ### (Structural Query Language)

# %%
import mysql.connector as connection
import pandas as pd
import csv

# %%
conn = connection.connect(host = 'localhost' , user = 'root' , passwd = 'Bharadwaja01')

# %%
cd M:\01 FSDS ineuron\Python Module\Classes\19.2.MySQL
# Out:
# M:\01 FSDS ineuron\Python Module\Classes\19.2.MySQL

# %%
data = pd.read_csv(r"practise.csv")
data
# Out:
#       Id    a    b    c    d
# 0      1  5.1  3.5  1.4  0.2
# 1      2  4.9  3.0  1.4  0.2
# 2      3  4.7  3.2  1.3  0.2
# 3      4  4.6  3.1  1.5  0.2
# 4      5  5.0  3.6  1.4  0.2
# ..   ...  ...  ...  ...  ...
# 145  146  6.7  3.0  5.2  2.3
# 146  147  6.3  2.5  5.0  1.9
# 147  148  6.5  3.0  5.2  2.0
# 148  149  6.2  3.4  5.4  2.3
# 149  150  5.9  3.0  5.1  1.8
#
# [150 rows x 5 columns]

# %%
conn = connection.connect(host="localhost" , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("create database practise")

# %%
conn = connection.connect(host="localhost" , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("show databases")
cur.fetchall()
# Out:
# [('carbonnanotubes',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('practise',),
#  ('sakila',),
#  ('sys',),
#  ('test123',),
#  ('test456',),
#  ('world',)]

# %%
cur = conn.cursor()
cur.execute("create table practise.tab(Id INT(10), a float(10 , 5) , b float(10 , 5) , c float(10 , 5) , d float(10 , 5))")

# %%
conn = connection.connect(host="localhost" , user= "root" , passwd = "Bharadwaja01",use_pure=True )
cur = conn.cursor()
with open("practise.csv" , "r") as data :
    next(data)
    data = csv.reader(data , delimiter ="\n")
    for i in data:
        #print(str(i[0]))
        cur.execute("insert into practise.tab values({data})".format(data = str(i[0])))
conn.commit()

# %%
data = pd.read_csv(r"practise.csv")
data.sample(5)
# Out:
#       Id    a    b    c    d
# 122  123  7.7  2.8  6.7  2.0
# 85    86  6.0  3.4  4.5  1.6
# 57    58  4.9  2.4  3.3  1.0
# 86    87  6.7  3.1  4.7  1.5
# 116  117  6.5  3.0  5.5  1.8

# %%
data2 = data.sample(75)
data2
# Out:
#       Id    a    b    c    d
# 137  138  6.4  3.1  5.5  1.8
# 148  149  6.2  3.4  5.4  2.3
# 42    43  4.4  3.2  1.3  0.2
# 76    77  6.8  2.8  4.8  1.4
# 68    69  6.2  2.2  4.5  1.5
# ..   ...  ...  ...  ...  ...
# 80    81  5.5  2.4  3.8  1.1
# 5      6  5.4  3.9  1.7  0.4
# 131  132  7.9  3.8  6.4  2.0
# 30    31  4.8  3.1  1.6  0.2
# 58    59  6.6  2.9  4.6  1.3
#
# [75 rows x 5 columns]

# %%
data2.to_csv("table2.csv")

# %% [markdown]
# ### create table1  and insert values

# %%
cur = conn.cursor()
cur.execute("create table practise.table1(Id INT(10), a float(10 , 5) , b float(10 , 5) , c float(10 , 5) , d float(10 , 5))")

# %%
conn = connection.connect(host="localhost" , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
with open("table1.csv" , "r") as data :
    next(data)
    data = csv.reader(data , delimiter ="\n")
    for i in data:
        print(str(i[0]))
        cur.execute("insert into practise.table1 values({data})".format(data = str(i[0])))
conn.commit()

# %% [markdown]
# ### create table2  insert values

# %%
cur = conn.cursor()
cur.execute("create table practise.table2(Id INT(10), a float(10 , 5) , b float(10 , 5) , c float(10 , 5) , d float(10 , 5))")

# %%
conn = connection.connect(host="localhost" , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
with open("table1.csv" , "r") as data :
    next(data)
    data = csv.reader(data , delimiter ="\n")
    for i in data:
        #print(str(i[0]))
        cur.execute("insert into practise.table2 values({data})".format(data = str(i[0])))
conn.commit()

# %% [markdown]
# ### The SQL SELECT QUERY

# %%
conn = connection.connect(host="localhost" , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("select id from practise.table2 Limit 10")
cur.fetchall()
# Out:
# [(88,), (127,), (113,), (53,), (115,), (38,), (106,), (45,), (11,), (134,)]

# %% [markdown]
# ### The SQL SELECT DISTINCT

# %%
conn = connection.connect(host="localhost" , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("select DISTINCT d from practise.table2 ")
cur.fetchall()
# Out:
# [(1.3,),
#  (1.8,),
#  (2.1,),
#  (1.5,),
#  (2.4,),
#  (0.1,),
#  (0.4,),
#  (0.2,),
#  (1.1,),
#  (2.5,),
#  (1.9,),
#  (0.3,),
#  (1.0,),
#  (2.3,),
#  (1.4,),
#  (1.2,),
#  (2.0,),
#  (2.2,),
#  (1.6,),
#  (0.6,)]

# %% [markdown]
# ### The SQL WHERE CLAUSE
# > text values
#
# > numeric fields

# %%
conn = connection.connect(host="localhost" , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("select * from practise.table2 where d = 1 ")
cur.fetchall()
# Out:
# [(94, 5.0, 2.3, 3.3, 1.0),
#  (61, 5.0, 2.0, 3.5, 1.0),
#  (82, 5.5, 2.4, 3.7, 1.0),
#  (80, 5.7, 2.6, 3.5, 1.0)]

# %%
conn = connection.connect(host="localhost" , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("select * from practise.table1 where c = 5.5 ")
cur.fetchall()
# Out:
# [(113, 6.8, 3.0, 5.5, 2.1)]

# %% [markdown]
# ### Operators in where clause
#  = Equal
#
#  \> Greater than
#
#  < Less than
#
#  \>= Greater than equal
#
#  <= Less than equal < > Not equal (also written as !=)
#
#  BETWEEN Between a range
#
#  LIKE Search for pattern
#
#  IN Specify multiple possible values for a column

# %%
conn = connection.connect(host="localhost" , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("select * from practise.table1 where c > 5.5 ")
cur.fetchall()
# Out:
# [(106, 7.6, 3.0, 6.6, 2.1),
#  (145, 6.7, 3.3, 5.7, 2.5),
#  (126, 7.2, 3.2, 6.0, 1.8),
#  (136, 7.7, 3.0, 6.1, 2.3),
#  (103, 7.1, 3.0, 5.9, 2.1),
#  (104, 6.3, 2.9, 5.6, 1.8),
#  (133, 6.4, 2.8, 5.6, 2.2),
#  (137, 6.3, 3.4, 5.6, 2.4),
#  (121, 6.9, 3.2, 5.7, 2.3),
#  (131, 7.4, 2.8, 6.1, 1.9),
#  (144, 6.8, 3.2, 5.9, 2.3),
#  (108, 7.3, 2.9, 6.3, 1.8)]

# %%
conn = connection.connect(host="localhost" , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("select * from practise.table1 where Id like '1%3' ")
cur.fetchall()
# Out:
# [(113, 6.8, 3.0, 5.5, 2.1),
#  (143, 5.8, 2.7, 5.1, 1.9),
#  (103, 7.1, 3.0, 5.9, 2.1),
#  (13, 4.8, 3.0, 1.4, 0.1),
#  (133, 6.4, 2.8, 5.6, 2.2)]

# %%
conn = connection.connect(host="localhost" , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("select * from practise.table1 where d between 2 and 3 ")
cur.fetchall()
# Out:
# [(113, 6.8, 3.0, 5.5, 2.1),
#  (115, 5.8, 2.8, 5.1, 2.4),
#  (106, 7.6, 3.0, 6.6, 2.1),
#  (145, 6.7, 3.3, 5.7, 2.5),
#  (136, 7.7, 3.0, 6.1, 2.3),
#  (103, 7.1, 3.0, 5.9, 2.1),
#  (114, 5.7, 2.5, 5.0, 2.0),
#  (146, 6.7, 3.0, 5.2, 2.3),
#  (116, 6.4, 3.2, 5.3, 2.3),
#  (140, 6.9, 3.1, 5.4, 2.1),
#  (133, 6.4, 2.8, 5.6, 2.2),
#  (149, 6.2, 3.4, 5.4, 2.3),
#  (137, 6.3, 3.4, 5.6, 2.4),
#  (121, 6.9, 3.2, 5.7, 2.3),
#  (148, 6.5, 3.0, 5.2, 2.0),
#  (144, 6.8, 3.2, 5.9, 2.3)]

# %% [markdown]
# ### The SQL WHERE CLAUSE WITH AND, OR & NOT
#
# A WHERE clause with AND:
#
# A WHERE clause with OR:
#
# A WHERE clause with NOT:

# %%
conn = connection.connect(host="localhost" , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("select * from practise.table1 where d = 2.1 AND c = 5.5 ")
cur.fetchall()
# Out:
# [(113, 6.8, 3.0, 5.5, 2.1)]

# %%
conn = connection.connect(host="localhost" , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("select * from practise.table1 where d = 2.1 or c = 5.5 ")
cur.fetchall()
# Out:
# [(113, 6.8, 3.0, 5.5, 2.1),
#  (106, 7.6, 3.0, 6.6, 2.1),
#  (103, 7.1, 3.0, 5.9, 2.1),
#  (140, 6.9, 3.1, 5.4, 2.1)]

# %%
conn = connection.connect(host="localhost" , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("select * from practise.table1 where NOT d = 1 ")
cur.fetchall()

# %% [markdown]
# ### The SQL ORDER BY
# Order By in Descending order
#
# Order By in Ascending order

# %%
conn = connection.connect(host="localhost" , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("select * from practise.checktable order by a DESC")
cur.fetchall()
# Out:
# [(993, 'akc', 9990),
#  (983, 'abc', 9376),
#  (968, 'zfc', 503),
#  (963, 'afc', 9000),
#  (701, ' ', 4000),
#  (701, 'PQRS', 5000),
#  (673, None, 9006),
#  (603, 'zgc', 1),
#  (601, None, 3000),
#  (583, 'zgc', 9000),
#  (573, None, 9100),
#  (503, 'zfc', 9000),
#  (501, None, 2000),
#  (201, 'zgc', 6376),
#  (101, 'abc', 1000)]

# %%
conn = connection.connect(host="localhost" , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("select * from practise.checktable order by a ASC")
cur.fetchall()
# Out:
# [(101, 'abc', 1000),
#  (201, 'zgc', 6376),
#  (501, None, 2000),
#  (503, 'zfc', 9000),
#  (573, None, 9100),
#  (583, 'zgc', 9000),
#  (601, None, 3000),
#  (603, 'zgc', 1),
#  (673, None, 9006),
#  (701, ' ', 4000),
#  (701, 'PQRS', 5000),
#  (963, 'afc', 9000),
#  (968, 'zfc', 503),
#  (983, 'abc', 9376),
#  (993, 'akc', 9990)]

# %% [markdown]
# The SQL SELECT TOP CLAUSE (mysql Doesnt support)
# ### mysql supports Limit Clause

# %%
conn = connection.connect(host="localhost" , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("select * from practise.table1 order by id ASC LIMIT 10")
cur.fetchall()
# Out:
# [(1, 5.1, 3.5, 1.4, 0.2),
#  (2, 4.9, 3.0, 1.4, 0.2),
#  (3, 4.7, 3.2, 1.3, 0.2),
#  (4, 4.6, 3.1, 1.5, 0.2),
#  (7, 4.6, 3.4, 1.4, 0.3),
#  (11, 5.4, 3.7, 1.5, 0.2),
#  (13, 4.8, 3.0, 1.4, 0.1),
#  (19, 5.7, 3.8, 1.7, 0.3),
#  (21, 5.4, 3.4, 1.7, 0.2),
#  (22, 5.1, 3.7, 1.5, 0.4)]

# %% [markdown]
# ### The SQL MIN() AND MAX() FUNCTION

# %%
conn = connection.connect(host="localhost" , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("select min(id) , min(a)  from practise.table1 ")
cur.fetchall()
# Out:
# [(1, 4.4)]

# %%
conn = connection.connect(host="localhost" , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("select max(id) , max(a)  from practise.table1 ")
cur.fetchall()
# Out:
# [(149, 7.7)]

# %% [markdown]
# ### The SQL COUNT(), AVG() AND SUM() FUNCTION

# %%
conn = connection.connect(host="localhost" , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("select count(id) , max(a) , count(a) from practise.table1 ")
cur.fetchall()
# Out:
# [(75, 7.7, 75)]

# %%
conn = connection.connect(host="localhost" , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("select count(id)  , sum(id) , avg(id) , max(id) , min(id) from practise.table1 ")
cur.fetchall()
# Out:
# [(75, Decimal('5674'), Decimal('75.6533'), 149, 1)]

# %% [markdown]
# ### The SQL LIKE-OPERATOR
# The LIKE operator is used with the WHERE  clause
#
# The ‘%’ and the ‘_’ can also be used in combinations
#
# Starting , Ending , Middle

# %% [markdown]
# ### The SQL IN AND NOT IN OPERATORS
# The IN operator allows users to specify multiple values in a WHERE
# clause. The IN operator is a shorthand for various OR conditions.

# %%
conn = connection.connect(host="localhost" , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("select * from practise.table1 where d in (1,2,3) ")
cur.fetchall()
# Out:
# [(94, 5.0, 2.3, 3.3, 1.0),
#  (61, 5.0, 2.0, 3.5, 1.0),
#  (114, 5.7, 2.5, 5.0, 2.0),
#  (82, 5.5, 2.4, 3.7, 1.0),
#  (80, 5.7, 2.6, 3.5, 1.0),
#  (148, 6.5, 3.0, 5.2, 2.0)]

# %%
conn = connection.connect(host="localhost" , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("select * from practise.checktable where a not in (101 , 201 , 501 , 701) ")
cur.fetchall()
# Out:
# [(993, 'akc', 9990),
#  (963, 'afc', 9000),
#  (983, 'abc', 9376),
#  (968, 'zfc', 503),
#  (573, None, 9100),
#  (583, 'zgc', 9000),
#  (503, 'zfc', 9000),
#  (673, None, 9006),
#  (603, 'zgc', 1),
#  (601, None, 3000)]

# %% [markdown]
# ### The SQL BETWEEN OPERATOR

# %%
conn = connection.connect(host="localhost" , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("select * from practise.table1 where d between 1 and 1.3 ")
cur.fetchall()
# Out:
# [(88, 6.3, 2.3, 4.4, 1.3),
#  (56, 5.7, 2.8, 4.5, 1.3),
#  (99, 5.1, 2.5, 3.0, 1.1),
#  (94, 5.0, 2.3, 3.3, 1.0),
#  (61, 5.0, 2.0, 3.5, 1.0),
#  (83, 5.8, 2.7, 3.9, 1.2),
#  (74, 6.1, 2.8, 4.7, 1.2),
#  (82, 5.5, 2.4, 3.7, 1.0),
#  (98, 6.2, 2.9, 4.3, 1.3),
#  (81, 5.5, 2.4, 3.8, 1.1),
#  (70, 5.6, 2.5, 3.9, 1.1),
#  (80, 5.7, 2.6, 3.5, 1.0),
#  (95, 5.6, 2.7, 4.2, 1.3),
#  (72, 6.1, 2.8, 4.0, 1.3),
#  (59, 6.6, 2.9, 4.6, 1.3)]

# %% [markdown]
# ### The SQL ALIAS
# Alias Column Syntax
#
# Alias Table Syntax

# %%
conn = connection.connect(host="localhost" , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("select id as i from practise.table1 where d = 1 ")
#cur.execute("select i from practise.table1 where d = 1 ")
cur.fetchall()
# Out:
# [(94,), (61,), (82,), (80,)]

# %%
conn = connection.connect(host="localhost" , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("select id from practise.table1 as t1 where d = 1 ")
cur.fetchall()
# Out:
# [(94,), (61,), (82,), (80,)]

# %% [markdown]
# ### The SQL GROUP BY STATEMENT

# %%
conn = connection.connect(host="localhost" , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("select count(d) , d from practise.table1 group by(d)")
cur.fetchall()
# Out:
# [(6, 1.3),
#  (6, 1.8),
#  (4, 2.1),
#  (6, 1.5),
#  (2, 2.4),
#  (3, 0.1),
#  (2, 0.4),
#  (15, 0.2),
#  (3, 1.1),
#  (1, 2.5),
#  (2, 1.9),
#  (5, 0.3),
#  (4, 1.0),
#  (6, 2.3),
#  (3, 1.4),
#  (2, 1.2),
#  (2, 2.0),
#  (1, 2.2),
#  (1, 1.6),
#  (1, 0.6)]

# %% [markdown]
# ### The SQL HAVING CLAUSE
# The HAVING clause is added to SQL because the WHERE keyword can
# not be used with aggregate functions.

# %%
conn = connection.connect(host="localhost" , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("select * , count(d) from practise.table1 group by(d) ")
cur.fetchall()
# Out:
# [(88, 6.3, 2.3, 4.4, 1.3, 6),
#  (127, 6.2, 2.8, 4.8, 1.8, 6),
#  (113, 6.8, 3.0, 5.5, 2.1, 4),
#  (53, 6.9, 3.1, 4.9, 1.5, 6),
#  (115, 5.8, 2.8, 5.1, 2.4, 2),
#  (38, 4.9, 3.1, 1.5, 0.1, 3),
#  (45, 5.1, 3.8, 1.9, 0.4, 2),
#  (11, 5.4, 3.7, 1.5, 0.2, 15),
#  (99, 5.1, 2.5, 3.0, 1.1, 3),
#  (145, 6.7, 3.3, 5.7, 2.5, 1),
#  (143, 5.8, 2.7, 5.1, 1.9, 2),
#  (46, 4.8, 3.0, 1.4, 0.3, 5),
#  (94, 5.0, 2.3, 3.3, 1.0, 4),
#  (136, 7.7, 3.0, 6.1, 2.3, 6),
#  (77, 6.8, 2.8, 4.8, 1.4, 3),
#  (83, 5.8, 2.7, 3.9, 1.2, 2),
#  (114, 5.7, 2.5, 5.0, 2.0, 2),
#  (133, 6.4, 2.8, 5.6, 2.2, 1),
#  (57, 6.3, 3.3, 4.7, 1.6, 1),
#  (44, 5.0, 3.5, 1.6, 0.6, 1)]

# %% [markdown]
# ### The SQL UNION
# The UNION operator allows the user to combine the result-set of two or
# more SELECT statements in SQL. Each SELECT statement within UNION
# should have the same number of columns. The columns in each SELECT
# statement should also be in the same order. The columns should also have
# similar data types.

# %%
conn = connection.connect(host="localhost" , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("select d from practise.table1 UNION  select d from practise.table2")
cur.fetchall()
# Out:
# [(1.3,),
#  (1.8,),
#  (2.1,),
#  (1.5,),
#  (2.4,),
#  (0.1,),
#  (0.4,),
#  (0.2,),
#  (1.1,),
#  (2.5,),
#  (1.9,),
#  (0.3,),
#  (1.0,),
#  (2.3,),
#  (1.4,),
#  (1.2,),
#  (2.0,),
#  (2.2,),
#  (1.6,),
#  (0.6,)]

# %% [markdown]
# ### UNION ALL Query
# The UNION operator selects only different values by default. To allow
# duplicate values, the user can use UNION ALL operator

# %%
conn = connection.connect(host="localhost" , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("select d from practise.table1 UNION ALL  select d from practise.table2 LIMIT 20")
cur.fetchall()
# Out:
# [(1.3,),
#  (1.8,),
#  (2.1,),
#  (1.5,),
#  (2.4,),
#  (0.1,),
#  (2.1,),
#  (0.4,),
#  (0.2,),
#  (1.5,),
#  (1.3,),
#  (0.2,),
#  (1.1,),
#  (2.5,),
#  (1.8,),
#  (1.9,),
#  (0.3,),
#  (0.4,),
#  (1.0,),
#  (1.5,)]

# %% [markdown]
# ### The SQL STORED PROCEDURE
# What is a SQL Stored Procedure?
#
# The stored procedure is a prepared SQL query that you can save so that
# the query can be reused over and over again. So, if the user has an SQL
# query that you write over and over again, keep it as a stored procedure and
# execute it. Users can also pass parameters to a stored procedure so that
# the stored procedure can act based on the parameter value that is given.

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("SHOW TABLES")
cur.fetchall()
# Out:
# [('tab',), ('table1',), ('table2',)]

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("create table table3( a float(10 , 5 ) , b float(10 , 5 ) , c float(10 , 5 ) , d float(10 , 5 ) , e float(10 , 5 ) , f float(10 , 5 ) , g float(10 , 5 ) ,  h float(10 , 5 ) , i float(10 , 5 ) , j float(10 , 5 ) , k float(10 , 5 ) , l float(10 , 5 ) )")
cur.fetchall()
# Out:
# []

# %%
cd M:\01 FSDS ineuron\Python Module\Classes\0015 MySQL
# Out:
# M:\01 FSDS ineuron\Python Module\Classes\0015 MySQL

# %%
conn = connection.connect(host="localhost" , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
with open("practise3.csv" , "r") as data :
    next(data)
    data = csv.reader(data , delimiter ="\n")
    for i in data:
        #print(str(i[0]))
        cur.execute("insert into practise.table3 values({data})".format(data = str(i[0])))
conn.commit()

# %% [markdown]
# ### SQL JOIN
# The SQL Join help in retrieving data from two or more database tables. The
# tables are mutually related using primary keys and foreign keys.
# ### Type of Join
# ### INNER JOIN
# The INNER JOIN is used to print rows from both tables that satisfy the
# given condition. For example, the user wants to get a list of users who have
# rented movies together with titles of movies rented by them. Users can use
# an INNER JOIN for that, which returns rows from both tables that satisfy
# with given conditions.
# ![22.PNG](attachment:22.PNG)

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("select table2.a , table3.c from table2 INNER JOIN  table3 ON table2.a = table3.a LIMIT 10")
cur.fetchall()
# Out:
# [(7.4, 0.0),
#  (7.4, 0.0),
#  (7.4, 0.0),
#  (7.3, 0.0),
#  (6.7, 0.08),
#  (6.7, 0.08),
#  (5.6, 0.0),
#  (5.6, 0.0),
#  (7.4, 0.08),
#  (7.6, 0.31)]

# %% [markdown]
# ### LEFT JOIN
# The LEFT JOIN returns all the records from the table1 (left table) and the
# matched records from the table2 (right table). The output is NULL from the
# right side if there is no match.
# ![24.PNG](attachment:24.PNG)

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("select table3.a , table2.c from table3 LEFT JOIN  table2 ON table2.a = table3.a LIMIT 10")
cur.fetchall()
# Out:
# [(7.4, 6.1),
#  (7.8, None),
#  (7.8, None),
#  (11.2, None),
#  (7.4, 6.1),
#  (7.4, 6.1),
#  (7.9, None),
#  (7.3, 6.3),
#  (7.8, None),
#  (7.5, None)]

# %% [markdown]
# ### RIGHT JOIN
# The RIGHT JOIN is the opposite of LEFT JOIN. The RIGHT JOIN prints all
# the columns from the table2(right table) even if there no matching rows
# have been found in the table1 (left table). If there no matches have been
# found in the table (left table), NULL is returned.
# ![25.PNG](attachment:25.PNG)

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("select table2.id , table3.c from table2 RIGHT JOIN  table3 ON table2.a = table3.a LIMIT 10")
cur.fetchall()
# Out:
# [(131, 0.0),
#  (None, 0.0),
#  (None, 0.04),
#  (None, 0.56),
#  (131, 0.0),
#  (131, 0.0),
#  (None, 0.06),
#  (108, 0.0),
#  (None, 0.02),
#  (None, 0.36)]

# %% [markdown]
# ### Full OUTER JOIN
# The FULL OUTER JOIN keyword returns all records when there are a
# match in left (table1) or right (table2) table records.
# Note: FULL OUTER JOIN can potentially return very large result-sets!
#
# #### Note: MySQL does not support the Full Join, so we can perform left join and right join separately then take the union of them.
# ![26.PNG](attachment:26.PNG)

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("(select table2.id , table3.c from table2 RIGHT JOIN  table3 ON table2.a = table3.a LIMIT 10) UNION (select table2.id , table3.c from table2 LEFT JOIN  table3 ON table2.a = table3.a LIMIT 10)")
cur.fetchall()
# Out:
# [(131, 0.0),
#  (None, 0.0),
#  (None, 0.04),
#  (None, 0.56),
#  (None, 0.06),
#  (108, 0.0),
#  (None, 0.02),
#  (None, 0.36),
#  (88, 0.13),
#  (88, 0.15),
#  (88, 0.01),
#  (88, 0.1),
#  (88, 0.0),
#  (88, 0.28)]

# %% [markdown]
# ### SELF-JOIN
# A self-JOIN is a regular join, but the table is joined with itself.
# Self -JOIN Syntax

# %% [markdown]
# ### Describe DESC

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("DESC practise.table3")
cur.fetchall()
# Out:
# [('a', b'float(10,5)', 'YES', '', None, ''),
#  ('b', b'float(10,5)', 'YES', '', None, ''),
#  ('c', b'float(10,5)', 'YES', '', None, ''),
#  ('d', b'float(10,5)', 'YES', '', None, ''),
#  ('e', b'float(10,5)', 'YES', '', None, ''),
#  ('f', b'float(10,5)', 'YES', '', None, ''),
#  ('g', b'float(10,5)', 'YES', '', None, ''),
#  ('h', b'float(10,5)', 'YES', '', None, ''),
#  ('i', b'float(10,5)', 'YES', '', None, ''),
#  ('j', b'float(10,5)', 'YES', '', None, ''),
#  ('k', b'float(10,5)', 'YES', '', None, ''),
#  ('l', b'float(10,5)', 'YES', '', None, '')]

# %% [markdown]
# ### Insert the NULL values in tables

# %%
import mysql.connector as connection
import pandas as pd
import csv
cd M:\01 FSDS ineuron\Python Module\Classes\0015 MySQL

# %%
cd M:\01 FSDS ineuron\Python Module\Classes\0015 MySQL
# Out:
# M:\01 FSDS ineuron\Python Module\Classes\0015 MySQL

# %% [markdown]
# ### student Table in practise database

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("create table student( id INT(10) , name VARCHAR(10) , address VARCHAR(10) , phno INT(12))")
cur.fetchall()
# Out:
# []

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()

cur.execute("insert into practise.student values( 123 , 'abc' , 'xyz' , 9876  )")
cur.execute("insert into practise.student values( 143 , 'adc' ,   NULL  , 9076  )")
cur.execute("insert into practise.student values( 153 , 'aec' , 'xwz' ,  NULL )")
cur.execute("insert into practise.student values( 163 , 'afc' , 'xpz' , 9276  )")
cur.execute("insert into practise.student values( 173 ,   NULL   , 'ryz' , 9176  )")
cur.execute("insert into practise.student values( 183 , 'agc' , 'ayz' , 9376  )")
cur.execute("insert into practise.student values( 193 , 'hbc' , 'xkz' ,  NULL  )")
cur.execute("insert into practise.student values( 223 , 'aic' , 'iyz' , 9806  )")
cur.execute("insert into practise.student values(  NULL   , 'jbc' , 'xpz' , 9076  )")
cur.execute("insert into practise.student values( 423 , 'akc' ,  NULL   , 9870  )")

conn.commit()

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()

cur.execute("select * from practise.student")
cur.fetchall()
# Out:
# [(123, 'abc', 'xyz', 9876),
#  (143, 'adc', None, 9076),
#  (153, 'aec', 'xwz', None),
#  (163, 'afc', 'xpz', 9276),
#  (173, None, 'ryz', 9176),
#  (183, 'agc', 'ayz', 9376),
#  (193, 'hbc', 'xkz', None),
#  (223, 'aic', 'iyz', 9806),
#  (None, 'jbc', 'xpz', 9076),
#  (423, 'akc', None, 9870)]

# %% [markdown]
# ### College table in practise database

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("create table college( id INT(10) , name VARCHAR(10) , branch VARCHAR(10) , phno INT(12))")
cur.fetchall()
# Out:
# []

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()

cur.execute("insert into practise.college values( 163 , 'afc' , 'xpz' , 9276  )")
cur.execute("insert into practise.college values( 173 ,   NULL   , 'ryz' , 9176  )")
cur.execute("insert into practise.college values( 183 , 'agc' , 'ayz' , 9376  )")

cur.execute("insert into practise.college values( 563 , 'zfc' , 'xlz' , 9270  )")
cur.execute("insert into practise.college values( 573 ,   NULL   , 'rlz' , 9100  )")
cur.execute("insert into practise.college values( 583 , 'zgc' , 'alz' , 9000  )")
cur.execute("insert into practise.college values( 503 , 'zfc' , 'xll' , 9206  )")
cur.execute("insert into practise.college values( 673 ,   NULL   , 'ryl' , 9006  )")
cur.execute("insert into practise.college values( 683 , 'zgc' , 'akl' , 0006  )")
cur.execute("insert into practise.college values( 883 , 'zgc' , 'auh' , 6376  )")



conn.commit()

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()

cur.execute("select * from practise.college")
cur.fetchall()
# Out:
# [(163, 'afc', 'xpz', 9276),
#  (173, None, 'ryz', 9176),
#  (183, 'agc', 'ayz', 9376),
#  (563, 'zfc', 'xlz', 9270),
#  (573, None, 'rlz', 9100),
#  (583, 'zgc', 'alz', 9000),
#  (503, 'zfc', 'xll', 9206),
#  (673, None, 'ryl', 9006),
#  (683, 'zgc', 'akl', 6),
#  (883, 'zgc', 'auh', 6376)]

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()

cur.execute("DESC practise.college")
cur.fetchall()
# Out:
# [('id', b'int', 'YES', '', None, ''),
#  ('name', b'varchar(10)', 'YES', '', None, ''),
#  ('branch', b'varchar(10)', 'YES', '', None, ''),
#  ('phno', b'int', 'YES', '', None, '')]

# %% [markdown]
# ### How to check for NULL Values?
# ### IS  NULL Syntax

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()

cur.execute("select * from practise.student where address is NULL")
cur.fetchall()
# Out:
# [(143, 'adc', None, 9076), (423, 'akc', None, 9870)]

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()

cur.execute("select * from practise.college where name is NULL")
cur.fetchall()
# Out:
# [(173, None, 'ryz', 9176), (573, None, 'rlz', 9100), (673, None, 'ryl', 9006)]

# %% [markdown]
# ### IS NOT NULL Syntax

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()

cur.execute("select * from practise.college where name is NOT NULL")
cur.fetchall()
# Out:
# [(163, 'afc', 'xpz', 9276),
#  (183, 'agc', 'ayz', 9376),
#  (563, 'zfc', 'xlz', 9270),
#  (583, 'zgc', 'alz', 9000),
#  (503, 'zfc', 'xll', 9206),
#  (683, 'zgc', 'akl', 6),
#  (883, 'zgc', 'auh', 6376)]

# %% [markdown]
# ### The SQL UPDATE STATEMENT

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()

cur.execute("update practise.student set id = 243 where id = 143 ")
conn.commit()
cur.fetchall()
# Out:
# []

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()

cur.execute("select * from practise.student ")
cur.fetchall()
# Out:
# [(123, 'abc', 'xyz', 9876),
#  (243, 'adc', None, 9076),
#  (153, 'aec', 'xwz', None),
#  (163, 'afc', 'xpz', 9276),
#  (173, None, 'ryz', 9176),
#  (183, 'agc', 'ayz', 9376),
#  (193, 'hbc', 'xkz', None),
#  (223, 'aic', 'iyz', 9806),
#  (None, 'jbc', 'xpz', 9076),
#  (423, 'akc', None, 9870)]

# %% [markdown]
# ### The SQL DELETE STATEMENT

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()

cur.execute("delete from practise.student where id = 423  ")
conn.commit()
cur.fetchall()
# Out:
# []

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()

cur.execute("select * from practise.student ")
cur.fetchall()
# Out:
# [(123, 'abc', 'xyz', 9876),
#  (243, 'adc', None, 9076),
#  (153, 'aec', 'xwz', None),
#  (163, 'afc', 'xpz', 9276),
#  (173, None, 'ryz', 9176),
#  (183, 'agc', 'ayz', 9376),
#  (193, 'hbc', 'xkz', None),
#  (223, 'aic', 'iyz', 9806),
#  (None, 'jbc', 'xpz', 9076)]

# %% [markdown]
# ### The SQL ALTER TABLE STATEMENT
# #### ALTER TABLE - ADD COLUMN IN EXISTING TABLE

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()

cur.execute("alter table practise.student ADD column age INT(10)   ")
conn.commit()
cur.fetchall()
# Out:
# []

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("DESC practise.student  ")
cur.fetchall()
# Out:
# [('id', b'int', 'YES', '', None, ''),
#  ('name', b'varchar(10)', 'YES', '', None, ''),
#  ('address', b'varchar(10)', 'YES', '', None, ''),
#  ('phno', b'int', 'YES', '', None, ''),
#  ('age', b'int', 'YES', '', None, '')]

# %% [markdown]
# ### ALTER TABLE – MODIFY/ALTER COLUMN

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()

cur.execute("alter table practise.student modify column  age VARCHAR(10)    ")
conn.commit()
cur.fetchall()
# Out:
# []

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("DESC practise.student  ")
cur.fetchall()
# Out:
# [('id', b'int', 'YES', '', None, ''),
#  ('name', b'varchar(10)', 'YES', '', None, ''),
#  ('address', b'varchar(10)', 'YES', '', None, ''),
#  ('phno', b'int', 'YES', '', None, ''),
#  ('age', b'varchar(10)', 'YES', '', None, '')]

# %% [markdown]
# ### ALTER TABLE - DROP COLUMN

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("alter table practise.student modify column  age VARCHAR(10)    ")
conn.commit()
cur.fetchall()

# %%
cur.execute("alter table practise.student drop column age")
conn.commit()

# %%
cur.execute("DESC practise.student  ")
cur.fetchall()
# Out:
# [('id', b'int', 'YES', '', None, ''),
#  ('name', b'varchar(10)', 'YES', '', None, ''),
#  ('address', b'varchar(10)', 'YES', '', None, ''),
#  ('phno', b'int', 'YES', '', None, '')]

# %% [markdown]
# ### The SQL CONSTRAINTS
# ###  1. Not Null Constraint
# ### Create a table using SQL not null constraints

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("create table notnull( a INT(10) Not Null , b VARCHAR(10)  , c VARCHAR(10)  Not Null , d INT(12)) ")
cur.fetchall()
# Out:
# []

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("DESC practise.notnull")
cur.fetchall()
# Out:
# [('a', b'int', 'NO', '', None, ''),
#  ('b', b'varchar(10)', 'YES', '', None, ''),
#  ('c', b'varchar(10)', 'NO', '', None, ''),
#  ('d', b'int', 'YES', '', None, '')]

# %%
cur.execute("insert into practise.notnull values( 163 , 'afc' , 'xpz' , 9276  )")
cur.execute("insert into practise.notnull values( 173 ,   NULL   , 'ryz' , 9176  )")
cur.execute("insert into practise.notnull values( 183 , 'agc' , 'ayz' , 9376  )")

cur.execute("insert into practise.notnull values( 563 , 'zfc' , 'xlz' , 9270  )")
cur.execute("insert into practise.notnull values( 573 ,   NULL   , 'rlz' , 9100  )")
cur.execute("insert into practise.notnull values( 583 , 'zgc' , 'alz' , 9000  )")
cur.execute("insert into practise.notnull values( 503 , 'zfc' , NULL , 9206  )")
cur.execute("insert into practise.notnull values( 673 ,   NULL   , 'ryl' , 9006  )")
cur.execute("insert into practise.notnull values( 683 , 'zgc' , 'akl' , 0006  )")
cur.execute("insert into practise.notnull values( 883 , 'zgc' , 'auh' , 6376  )")
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-14-404957caff13> in <module>
#       6 cur.execute("insert into practise.notnull values( 573 ,   NULL   , 'rlz' , 9100  )")
#       7 cur.execute("insert into practise.notnull values( 583 , 'zgc' , 'alz' , 9000  )")
# ----> 8 cur.execute("insert into practise.notnull values( 503 , 'zfc' , NULL , 9206  )")
#       9 cur.execute("insert into practise.notnull values( 673 ,   NULL   , 'ryl' , 9006  )")
#      10 cur.execute("insert into practise.notnull values( 683 , 'zgc' , 'akl' , 0006  )")
#
# ~\.conda\envs\gputest\lib\site-packages\mysql\connector\cursor.py in execute(self, operation, params, multi)
#     566
#     567         try:
# --> 568             self._handle_result(self._connection.cmd_query(stmt))
#     569         except errors.InterfaceError:
# ...

# %%
cur.execute("insert into practise.notnull values( 163 , 'afc' , 'xpz' , 9276  )")
cur.execute("insert into practise.notnull values( 173 ,   NULL   , 'ryz' , 9176  )")
cur.execute("insert into practise.notnull values( 183 , 'agc' , 'ayz' , 9376  )")

cur.execute("insert into practise.notnull values( 563 , 'zfc' , 'xlz' , 9270  )")
cur.execute("insert into practise.notnull values( 573 ,   NULL   , 'rlz' , 9100  )")
cur.execute("insert into practise.notnull values( 583 , 'zgc' , 'alz' , 9000  )")
cur.execute("insert into practise.notnull values( 503 , 'zfc' , 'abr' , 9206  )")
cur.execute("insert into practise.notnull values( 673 ,   NULL   , 'ryl' , 9006  )")
cur.execute("insert into practise.notnull values( 683 , 'zgc' , 'akl' , 0006  )")
cur.execute("insert into practise.notnull values( 883 , 'zgc' , 'auh' , 6376  )")
conn.commit()

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("select * from practise.notnull")
cur.fetchall()
# Out:
# [(163, 'afc', 'xpz', 9276),
#  (173, None, 'ryz', 9176),
#  (183, 'agc', 'ayz', 9376),
#  (563, 'zfc', 'xlz', 9270),
#  (573, None, 'rlz', 9100),
#  (583, 'zgc', 'alz', 9000),
#  (503, 'zfc', 'abr', 9206),
#  (673, None, 'ryl', 9006),
#  (683, 'zgc', 'akl', 6),
#  (883, 'zgc', 'auh', 6376)]

# %% [markdown]
# ### SQL NOT NULL on ALTER table Statement

# %%
import mysql.connector as connection
import pandas as pd
import csv

# %%
cd M:\01 FSDS ineuron\Python Module\Classes\0015 MySQL
# Out:
# M:\01 FSDS ineuron\Python Module\Classes\0015 MySQL

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("alter table practise.notnull modify column c VARCHAR(10) NOT NULL ")
cur.fetchall()
# Out:
# []

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("DESC practise.notnull ")
cur.fetchall()
# Out:
# [('a', b'int', 'NO', '', None, ''),
#  ('b', b'varchar(10)', 'YES', '', None, ''),
#  ('c', b'varchar(10)', 'NO', '', None, ''),
#  ('d', b'int', 'YES', '', None, '')]

# %% [markdown]
# ### SQL UNIQUE CONSTRAINT

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("create table uniquetable( a INT(10) Not Null , b VARCHAR(10)  , c VARCHAR(10)  Not Null , d INT(12) , unique(a)) ")
cur.fetchall()
# Out:
# []

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("DESC practise.uniquetable ")
cur.fetchall()
# Out:
# [('a', b'int', 'NO', 'PRI', None, ''),
#  ('b', b'varchar(10)', 'YES', '', None, ''),
#  ('c', b'varchar(10)', 'NO', '', None, ''),
#  ('d', b'int', 'YES', '', None, '')]

# %%
cur.execute("insert into practise.uniquetable values( 163 , 'afc' , 'xpz' , 9276  )")
cur.execute("insert into practise.uniquetable values( 173 ,   NULL   , 'ryz' , 9176  )")
cur.execute("insert into practise.uniquetable values( 183 , 'agc' , 'ayz' , 9376  )")

cur.execute("insert into practise.uniquetable values( 163 , 'zfc' , 'xlz' , 9270  )")
cur.execute("insert into practise.uniquetable values( 573 ,   NULL   , 'rlz' , 9100  )")
cur.execute("insert into practise.uniquetable values( 583 , 'zgc' , 'alz' , 9000  )")
cur.execute("insert into practise.uniquetable values( 503 , 'zfc' , 'abr' , 9206  )")
cur.execute("insert into practise.uniquetable values( 673 ,   NULL   , 'ryl' , 9006  )")
cur.execute("insert into practise.uniquetable values( 683 , 'zgc' , 'akl' , 0006  )")
cur.execute("insert into practise.uniquetable values( 883 , 'zgc' , 'auh' , 6376  )")
conn.commit()
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-8-bc96e0eaa5b7> in <module>
#       3 cur.execute("insert into practise.uniquetable values( 183 , 'agc' , 'ayz' , 9376  )")
#       4
# ----> 5 cur.execute("insert into practise.uniquetable values( 163 , 'zfc' , 'xlz' , 9270  )")
#       6 cur.execute("insert into practise.uniquetable values( 573 ,   NULL   , 'rlz' , 9100  )")
#       7 cur.execute("insert into practise.uniquetable values( 583 , 'zgc' , 'alz' , 9000  )")
#
# ~\.conda\envs\gputest\lib\site-packages\mysql\connector\cursor.py in execute(self, operation, params, multi)
#     566
#     567         try:
# --> 568             self._handle_result(self._connection.cmd_query(stmt))
#     569         except errors.InterfaceError:
#     570             if self._connection._have_next_result:  # pylint: disable=W0212
#
# ...

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("insert into practise.uniquetable values( 963 , 'afc' , 'xpz' , 9276  )")
cur.execute("insert into practise.uniquetable values( 973 ,   NULL   , 'ryz' , 9176  )")
cur.execute("insert into practise.uniquetable values( 983 , 'agc' , 'ayz' , 9376  )")

cur.execute("insert into practise.uniquetable values( 863 , 'zfc' , 'xlz' , 9270  )")
cur.execute("insert into practise.uniquetable values( 573 ,   NULL   , 'rlz' , 9100  )")
cur.execute("insert into practise.uniquetable values( 583 , 'zgc' , 'alz' , 9000  )")
cur.execute("insert into practise.uniquetable values( 503 , 'zfc' , 'abr' , 9206  )")
cur.execute("insert into practise.uniquetable values( 673 ,   NULL   , 'ryl' , 9006  )")
cur.execute("insert into practise.uniquetable values( 683 , 'zgc' , 'akl' , 0006  )")
cur.execute("insert into practise.uniquetable values( 883 , 'zgc' , 'auh' , 6376  )")
conn.commit()

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("select * from  practise.uniquetable ")
cur.fetchall()
# Out:
# [(503, 'zfc', 'abr', 9206),
#  (573, None, 'rlz', 9100),
#  (583, 'zgc', 'alz', 9000),
#  (673, None, 'ryl', 9006),
#  (683, 'zgc', 'akl', 6),
#  (863, 'zfc', 'xlz', 9270),
#  (883, 'zgc', 'auh', 6376),
#  (963, 'afc', 'xpz', 9276),
#  (973, None, 'ryz', 9176),
#  (983, 'agc', 'ayz', 9376)]

# %% [markdown]
# ### ALTER SQL UNIQUE CONSTRAINT

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("alter table practise.uniquetable ADD unique(b) ")
cur.fetchall()
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-6-3fd0744996d2> in <module>
#       1 conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
#       2 cur = conn.cursor()
# ----> 3 cur.execute("alter table practise.uniquetable ADD unique(b) ")
#       4 cur.fetchall()
#
# ~\.conda\envs\gputest\lib\site-packages\mysql\connector\cursor.py in execute(self, operation, params, multi)
#     566
#     567         try:
# --> 568             self._handle_result(self._connection.cmd_query(stmt))
#     569         except errors.InterfaceError:
#     570             if self._connection._have_next_result:  # pylint: disable=W0212
#
# ~\.conda\envs\gputest\lib\site-packages\mysql\connector\connection.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     684             query = query.encode('utf-8')
# ...

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("alter table practise.uniquetable ADD unique(c) ")
cur.fetchall()
# Out:
# []

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("DESC practise.uniquetable ")
cur.fetchall()
# Out:
# [('a', b'int', 'NO', 'PRI', None, ''),
#  ('b', b'varchar(10)', 'YES', '', None, ''),
#  ('c', b'varchar(10)', 'NO', 'UNI', None, ''),
#  ('d', b'int', 'YES', '', None, '')]

# %% [markdown]
# ### ALTER TABLE person ADD CONSTRAINT UC_person UNIQUE (a,b);

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("create table uniquetable3( a INT(10) Not Null , b VARCHAR(10)  , c VARCHAR(10)  Not Null , d INT(12)) ")
cur.fetchall()
# Out:
# []

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("insert into practise.uniquetable3 values( 963 , 'afc' , 'xpz' , 9000  )")
cur.execute("insert into practise.uniquetable3 values(963 , 'afc' , 'xpz' , 9000  )")
cur.execute("insert into practise.uniquetable3 values( 983 , 'abc' , 'abz' , 9376  )")

cur.execute("insert into practise.uniquetable3 values( 963 , 'zfc' , 'rlz' , 503  )")
cur.execute("insert into practise.uniquetable3 values( 573 ,   NULL   , 'rlz' , 9100  )")
cur.execute("insert into practise.uniquetable3 values( 583 , 'zgc' , 'alz' , 9000  )")
cur.execute("insert into practise.uniquetable3 values( 503 , 'zfc' , 'abr' , 9000  )")
cur.execute("insert into practise.uniquetable3 values( 673 ,   NULL   , 'ryl' , 9006  )")
cur.execute("insert into practise.uniquetable3 values( 683 , 'zgc' , 'ryl' , 0006  )")
cur.execute("insert into practise.uniquetable3 values( 673 , 'zgc' , 'auh' , 6376  )")
conn.commit()

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("select * from  practise.uniquetable3 ")
cur.fetchall()
# Out:
# [(963, 'afc', 'xpz', 9000),
#  (963, 'afc', 'xpz', 9000),
#  (983, 'abc', 'abz', 9376),
#  (963, 'zfc', 'rlz', 503),
#  (573, None, 'rlz', 9100),
#  (583, 'zgc', 'alz', 9000),
#  (503, 'zfc', 'abr', 9000),
#  (673, None, 'ryl', 9006),
#  (683, 'zgc', 'ryl', 6),
#  (673, 'zgc', 'auh', 6376)]

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("  ALTER TABLE practise.uniquetable3 ADD CONSTRAINT k UNIQUE (a , c) ")
cur.fetchall()
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-28-f1b6d6c3effb> in <module>
#       1 conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
#       2 cur = conn.cursor()
# ----> 3 cur.execute("  ALTER TABLE practise.uniquetable3 ADD CONSTRAINT k UNIQUE (a , c) ")
#       4 cur.fetchall()
#
# ~\.conda\envs\gputest\lib\site-packages\mysql\connector\cursor.py in execute(self, operation, params, multi)
#     566
#     567         try:
# --> 568             self._handle_result(self._connection.cmd_query(stmt))
#     569         except errors.InterfaceError:
#     570             if self._connection._have_next_result:  # pylint: disable=W0212
#
# ~\.conda\envs\gputest\lib\site-packages\mysql\connector\connection.py in cmd_query(self, query, raw, buffered, raw_as_string)
# ...

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("insert into practise.uniquetable3 values( 993 , 'akc' , 'xbz' , 9990  )")
cur.execute("insert into practise.uniquetable3 values(963 , 'afc' , 'xpz' , 9000  )")
cur.execute("insert into practise.uniquetable3 values( 983 , 'abc' , 'abz' , 9376  )")

cur.execute("insert into practise.uniquetable3 values( 968 , 'zfc' , 'rlz' , 503  )")
cur.execute("insert into practise.uniquetable3 values( 573 ,   NULL   , 'rlz' , 9100  )")
cur.execute("insert into practise.uniquetable3 values( 583 , 'zgc' , 'alz' , 9000  )")
cur.execute("insert into practise.uniquetable3 values( 503 , 'zfc' , 'abr' , 9000  )")
cur.execute("insert into practise.uniquetable3 values( 673 ,   NULL   , 'ryl' , 9006  )")
cur.execute("insert into practise.uniquetable3 values( 683 , 'zgc' , 'ryl' , 0006  )")
cur.execute("insert into practise.uniquetable3 values( 673 , 'zgc' , 'auh' , 6376  )")
conn.commit()

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("  ALTER TABLE practise.uniquetable3 ADD CONSTRAINT k UNIQUE (a , c) ")
conn.commit()
cur.fetchall()
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-5-8416703271e0> in <module>
#       1 conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
#       2 cur = conn.cursor()
# ----> 3 cur.execute("  ALTER TABLE practise.uniquetable3 ADD CONSTRAINT k UNIQUE (a , c) ")
#       4 conn.commit()
#       5 cur.fetchall()
#
# ~\.conda\envs\gputest\lib\site-packages\mysql\connector\cursor.py in execute(self, operation, params, multi)
#     566
#     567         try:
# --> 568             self._handle_result(self._connection.cmd_query(stmt))
#     569         except errors.InterfaceError:
#     570             if self._connection._have_next_result:  # pylint: disable=W0212
#
# ~\.conda\envs\gputest\lib\site-packages\mysql\connector\connection.py in cmd_query(self, query, raw, buffered, raw_as_string)
# ...

# %% [markdown]
# ### DROP A UNIQUE CONSTRAINT

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("  DESC practise.uniquetable  ")
cur.fetchall()
# Out:
# [('a', b'int', 'NO', 'MUL', None, ''),
#  ('b', b'varchar(10)', 'YES', 'MUL', None, ''),
#  ('c', b'varchar(10)', 'NO', 'PRI', None, ''),
#  ('d', b'int', 'YES', '', None, '')]

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("  ALTER TABLE practise.uniquetable DROP INDEX c ")
cur.fetchall()
# Out:
# []

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("  DESC practise.uniquetable  ")
cur.fetchall()
# Out:
# [('a', b'int', 'NO', 'MUL', None, ''),
#  ('b', b'varchar(10)', 'YES', 'MUL', None, ''),
#  ('c', b'varchar(10)', 'NO', '', None, ''),
#  ('d', b'int', 'YES', '', None, '')]

# %% [markdown]
# ### SQL PRIMARY KEY CONSTRAINTS
# ### Both unique and Not null

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("create table primarytable( a INT(10) Not Null , b VARCHAR(10)  , c VARCHAR(10)  Not Null , d INT(12) , primary key(a)) ")
cur.fetchall()
# Out:
# []

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("  DESC practise.primarytable  ")
cur.fetchall()
# Out:
# [('a', b'int', 'NO', 'PRI', None, ''),
#  ('b', b'varchar(10)', 'YES', '', None, ''),
#  ('c', b'varchar(10)', 'NO', '', None, ''),
#  ('d', b'int', 'YES', '', None, '')]

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("insert into practise.primarytable values( 993 , 'akc' , 'xbz' , 9990  )")
cur.execute("insert into practise.primarytable values(963 , 'afc' , 'xpz' , 9000  )")
cur.execute("insert into practise.primarytable values( 983 , 'abc' , 'abz' , 9376  )")

cur.execute("insert into practise.primarytable values( 968 , 'zfc' , 'rlz' , 503  )")
cur.execute("insert into practise.primarytable values( 573 ,   NULL   , 'rlz' , 9100  )")
cur.execute("insert into practise.primarytable values( 583 , 'zgc' , 'alz' , 9000  )")
cur.execute("insert into practise.primarytable values( 503 , 'zfc' , 'abr' , 9000  )")
cur.execute("insert into practise.primarytable values( 673 ,   NULL   , 'ryl' , 9006  )")
cur.execute("insert into practise.primarytable values( 603 , 'zgc' , 'ryl' , 0006  )")
cur.execute("insert into practise.primarytable values( 173 , 'zgc' , 'auh' , 6376  )")
conn.commit()

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("  select * from practise.primarytable  ")
cur.fetchall()
# Out:
# [(173, 'zgc', 'auh', 6376),
#  (503, 'zfc', 'abr', 9000),
#  (573, None, 'rlz', 9100),
#  (583, 'zgc', 'alz', 9000),
#  (603, 'zgc', 'ryl', 6),
#  (673, None, 'ryl', 9006),
#  (963, 'afc', 'xpz', 9000),
#  (968, 'zfc', 'rlz', 503),
#  (983, 'abc', 'abz', 9376),
#  (993, 'akc', 'xbz', 9990)]

# %% [markdown]
# ### SQL PRIMARY KEY on ALTER TABLE

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("  select * from primarytable  ")
cur.fetchall()
# Out:
# [('zgc', 'auh', 6376),
#  ('zfc', 'abr', 9000),
#  (None, 'rlz', 9100),
#  ('zgc', 'alz', 9000),
#  ('zgc', 'ryl', 6),
#  (None, 'ryl', 9006),
#  ('afc', 'xpz', 9000),
#  ('zfc', 'rlz', 503),
#  ('abc', 'abz', 9376),
#  ('akc', 'xbz', 9990)]

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("  DESC primarytable  ")
cur.fetchall()
# Out:
# [('b', b'varchar(10)', 'YES', '', None, ''),
#  ('c', b'varchar(10)', 'NO', '', None, ''),
#  ('d', b'int', 'YES', '', None, '')]

# %% [markdown]
# ### CONSTRAINT PK_person PRIMARY KEY (id,last_name)
# ### SQL PRIMARY KEY on ALTER TABLE
# ### ALTER TABLE student ADD CONSTRAINT PK_student PRIMARY KEY (id,first_name);
# ### and Drop

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("  ALTER table practise.primarytable ADD CONSTRAINT P  primary key(c,d)  ")
cur.fetchall()
# Out:
# []

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("  DESC primarytable  ")
cur.fetchall()
# Out:
# [('b', b'varchar(10)', 'YES', '', None, ''),
#  ('c', b'varchar(10)', 'NO', 'PRI', None, ''),
#  ('d', b'int', 'NO', 'PRI', None, '')]

# %% [markdown]
# ### DROP PRIMARY KEY CONSTRAINTS

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("  DESC primarytable  ")
cur.fetchall()
# Out:
# [('b', b'varchar(10)', 'YES', '', None, ''),
#  ('c', b'varchar(10)', 'NO', 'PRI', None, ''),
#  ('d', b'int', 'NO', 'PRI', None, '')]

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("  ALTER table practise.primarytable DROP PRIMARY KEY  ")
cur.fetchall()
# Out:
# []

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("  DESC primarytable  ")
cur.fetchall()
# Out:
# [('b', b'varchar(10)', 'YES', '', None, ''),
#  ('c', b'varchar(10)', 'NO', '', None, ''),
#  ('d', b'int', 'NO', '', None, '')]

# %% [markdown]
# ### SQL FOREIGN KEY CONSTRAINT
# ### table1 with primary key and table2 with foregin key

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("create table foreignprimarytable( a INT(10) Not Null , b VARCHAR(10)  , c VARCHAR(10)  Not Null , d INT(12) , primary key(a)) ")
cur.fetchall()
# Out:
# []

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("insert into practise.foreignprimarytable values( 993 , 'akc' , 'xbz' , 9990  )")
cur.execute("insert into practise.foreignprimarytable values(963 , 'afc' , 'xpz' , 9000  )")
cur.execute("insert into practise.foreignprimarytable values( 983 , 'abc' , 'abz' , 9376  )")

cur.execute("insert into practise.foreignprimarytable values( 968 , 'zfc' , 'rlz' , 503  )")
cur.execute("insert into practise.foreignprimarytable values( 573 ,   NULL   , 'rlz' , 9100  )")
cur.execute("insert into practise.foreignprimarytable values( 583 , 'zgc' , 'alz' , 9000  )")
cur.execute("insert into practise.foreignprimarytable values( 503 , 'zfc' , 'abr' , 9000  )")
cur.execute("insert into practise.foreignprimarytable values( 673 ,   NULL   , 'ryl' , 9006  )")
cur.execute("insert into practise.foreignprimarytable values( 603 , 'zgc' , 'ryl' , 0006  )")
cur.execute("insert into practise.foreignprimarytable values( 173 , 'zgc' , 'auh' , 6376  )")
conn.commit()

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("DESC foreignprimarytable ")
cur.fetchall()
# Out:
# [('a', b'int', 'NO', 'PRI', None, ''),
#  ('b', b'varchar(10)', 'YES', '', None, ''),
#  ('c', b'varchar(10)', 'NO', '', None, ''),
#  ('d', b'int', 'YES', '', None, '')]

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("create table foreigntable( a INT(10) Not Null , b VARCHAR(10)  , c VARCHAR(10)  Not Null , d INT(12))")
cur.fetchall()
# Out:
# []

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("insert into practise.foreigntable values( 993 , 'akc' , 'xbz' , 9990  )")
cur.execute("insert into practise.foreigntable values(963 , 'afc' , 'xpz' , 9000  )")
cur.execute("insert into practise.foreigntable values( 983 , 'abc' , 'abz' , 9376  )")

cur.execute("insert into practise.foreigntable values( 968 , 'zfc' , 'rlz' , 503  )")
cur.execute("insert into practise.foreigntable values( 573 ,   NULL   , 'rlz' , 9100  )")
cur.execute("insert into practise.foreigntable values( 583 , 'zgc' , 'alz' , 9000  )")
cur.execute("insert into practise.foreigntable values( 503 , 'zfc' , 'abr' , 9000  )")
cur.execute("insert into practise.foreigntable values( 673 ,   NULL   , 'ryl' , 9006  )")
cur.execute("insert into practise.foreigntable values( 603 , 'zgc' , 'ryl' , 0006  )")
cur.execute("insert into practise.foreigntable values( 173 , 'zgc' , 'auh' , 6376  )")
conn.commit()

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("  select * from foreigntable  ")
cur.fetchall()
# Out:
# [(993, 'akc', 'xbz', 9990),
#  (963, 'afc', 'xpz', 9000),
#  (983, 'abc', 'abz', 9376),
#  (968, 'zfc', 'rlz', 503),
#  (573, None, 'rlz', 9100),
#  (583, 'zgc', 'alz', 9000),
#  (503, 'zfc', 'abr', 9000),
#  (673, None, 'ryl', 9006),
#  (603, 'zgc', 'ryl', 6),
#  (173, 'zgc', 'auh', 6376)]

# %% [markdown]
# ### FOREIGN KEY on ALTER TABLE

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("  DESC foreigntable  ")
cur.fetchall()
# Out:
# [('a', b'int', 'NO', '', None, ''),
#  ('b', b'varchar(10)', 'YES', '', None, ''),
#  ('c', b'varchar(10)', 'NO', '', None, ''),
#  ('d', b'int', 'YES', '', None, '')]

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("  ALTER table foreigntable ADD FOREIGN KEY (a) REFERENCES foreignprimarytable(a)  ")
cur.fetchall()
# Out:
# []

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("  DESC foreigntable  ")
cur.fetchall()
# Out:
# [('a', b'int', 'NO', 'MUL', None, ''),
#  ('b', b'varchar(10)', 'YES', '', None, ''),
#  ('c', b'varchar(10)', 'NO', '', None, ''),
#  ('d', b'int', 'YES', '', None, '')]

# %% [markdown]
# ### DROP A FOREIGN KEY CONSTRAINT
# ### ALTER TABLE Orders DROP FOREIGN KEY FK_PersonOrder;

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("  DESC foreigntable  ")
cur.fetchall()
# Out:
# [('a', b'int', 'NO', 'MUL', None, ''),
#  ('b', b'varchar(10)', 'YES', '', None, ''),
#  ('c', b'varchar(10)', 'NO', '', None, ''),
#  ('d', b'int', 'YES', '', None, '')]

# %% [markdown]
# ### SQL CHECK CONSTRAINTS
# ### SQL CHECK on CREATE TABLE

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("create table checktable( a INT(10) Not Null , b VARCHAR(10)  , c VARCHAR(10)  Not Null , d INT(12) , CHECK(a>=200))")
cur.fetchall()
# Out:
# []

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("insert into practise.checktable values( 993 , 'akc' , 'xbz' , 9990  )")
cur.execute("insert into practise.checktable values(963 , 'afc' , 'xpz' , 9000  )")
cur.execute("insert into practise.checktable values( 983 , 'abc' , 'abz' , 9376  )")

cur.execute("insert into practise.checktable values( 968 , 'zfc' , 'rlz' , 503  )")
cur.execute("insert into practise.checktable values( 573 ,   NULL   , 'rlz' , 9100  )")
cur.execute("insert into practise.checktable values( 583 , 'zgc' , 'alz' , 9000  )")
cur.execute("insert into practise.checktable values( 503 , 'zfc' , 'abr' , 9000  )")
cur.execute("insert into practise.checktable values( 673 ,   NULL   , 'ryl' , 9006  )")
cur.execute("insert into practise.checktable values( 603 , 'zgc' , 'ryl' , 0006  )")
cur.execute("insert into practise.checktable values( 173 , 'zgc' , 'auh' , 6376  )")
conn.commit()
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-73-b2e17a9c6b85> in <module>
#      11 cur.execute("insert into practise.checktable values( 673 ,   NULL   , 'ryl' , 9006  )")
#      12 cur.execute("insert into practise.checktable values( 603 , 'zgc' , 'ryl' , 0006  )")
# ---> 13 cur.execute("insert into practise.checktable values( 173 , 'zgc' , 'auh' , 6376  )")
#      14 conn.commit()
#
# ~\.conda\envs\gputest\lib\site-packages\mysql\connector\cursor.py in execute(self, operation, params, multi)
#     566
#     567         try:
# --> 568             self._handle_result(self._connection.cmd_query(stmt))
#     569         except errors.InterfaceError:
#     570             if self._connection._have_next_result:  # pylint: disable=W0212
#
# ~\.conda\envs\gputest\lib\site-packages\mysql\connector\connection.py in cmd_query(self, query, raw, buffered, raw_as_string)
# ...

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("insert into practise.checktable values( 993 , 'akc' , 'xbz' , 9990  )")
cur.execute("insert into practise.checktable values(963 , 'afc' , 'xpz' , 9000  )")
cur.execute("insert into practise.checktable values( 983 , 'abc' , 'abz' , 9376  )")

cur.execute("insert into practise.checktable values( 968 , 'zfc' , 'rlz' , 503  )")
cur.execute("insert into practise.checktable values( 573 ,   NULL   , 'rlz' , 9100  )")
cur.execute("insert into practise.checktable values( 583 , 'zgc' , 'alz' , 9000  )")
cur.execute("insert into practise.checktable values( 503 , 'zfc' , 'abr' , 9000  )")
cur.execute("insert into practise.checktable values( 673 ,   NULL   , 'ryl' , 9006  )")
cur.execute("insert into practise.checktable values( 603 , 'zgc' , 'ryl' , 0006  )")
cur.execute("insert into practise.checktable values( 201 , 'zgc' , 'auh' , 6376  )")
conn.commit()

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("  select * from checktable  ")
cur.fetchall()
# Out:
# [(993, 'akc', 'xbz', 9990),
#  (963, 'afc', 'xpz', 9000),
#  (983, 'abc', 'abz', 9376),
#  (968, 'zfc', 'rlz', 503),
#  (573, None, 'rlz', 9100),
#  (583, 'zgc', 'alz', 9000),
#  (503, 'zfc', 'abr', 9000),
#  (673, None, 'ryl', 9006),
#  (603, 'zgc', 'ryl', 6),
#  (201, 'zgc', 'auh', 6376)]

# %% [markdown]
# ### For creating a CHECK constraint on multiple columns in the table, use the SQL syntax:
# ### CHECK on ALTER TABLE

# %%
import mysql.connector as connection
import pandas as pd
import csv

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("  ALTER table  checktable ADD CONSTRAINT C CHECK(a>=200 AND d>=10) ")
cur.fetchall()
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-2-bad9515ba7ea> in <module>
#       1 conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
#       2 cur = conn.cursor()
# ----> 3 cur.execute("  ALTER table  checktable ADD CONSTRAINT C CHECK(a>=200 AND d>=10) ")
#       4 cur.fetchall()
#
# ~\.conda\envs\gputest\lib\site-packages\mysql\connector\cursor.py in execute(self, operation, params, multi)
#     566
#     567         try:
# --> 568             self._handle_result(self._connection.cmd_query(stmt))
#     569         except errors.InterfaceError:
#     570             if self._connection._have_next_result:  # pylint: disable=W0212
#
# ~\.conda\envs\gputest\lib\site-packages\mysql\connector\connection.py in cmd_query(self, query, raw, buffered, raw_as_string)
# ...

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("  UPDATE  checktable  SET d = 0011 WHERE a = 603 ")
conn.commit()
cur.fetchall()
# Out:
# []

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("  select * from checktable  ")
cur.fetchall()
# Out:
# [(993, 'akc', 'xbz', 9990),
#  (963, 'afc', 'xpz', 9000),
#  (983, 'abc', 'abz', 9376),
#  (968, 'zfc', 'rlz', 503),
#  (573, None, 'rlz', 9100),
#  (583, 'zgc', 'alz', 9000),
#  (503, 'zfc', 'abr', 9000),
#  (673, None, 'ryl', 9006),
#  (603, 'zgc', 'ryl', 11),
#  (201, 'zgc', 'auh', 6376)]

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("  ALTER table  checktable ADD CONSTRAINT C CHECK(a>=200 AND d>=10) ")
cur.fetchall()

# %% [markdown]
# ### DROP A CHECK CONSTRAINT

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("  DESC checktable  ")
cur.fetchall()
# Out:
# [('a', b'int', 'NO', '', None, ''),
#  ('b', b'varchar(10)', 'YES', '', None, ''),
#  ('c', b'varchar(10)', 'NO', '', None, ''),
#  ('d', b'int', 'YES', '', None, '')]

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("  ALTER table  checktable DROP CHECK C  ")
cur.fetchall()

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("  UPDATE  checktable  SET d = 0001 WHERE a = 603 ")
conn.commit()
cur.fetchall()
# Out:
# []

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("  select * from checktable  ")
cur.fetchall()
# Out:
# [(993, 'akc', 9990),
#  (963, 'afc', 9000),
#  (983, 'abc', 9376),
#  (968, 'zfc', 503),
#  (573, None, 9100),
#  (583, 'zgc', 9000),
#  (503, 'zfc', 9000),
#  (673, None, 9006),
#  (603, 'zgc', 1),
#  (201, 'zgc', 6376)]

# %% [markdown]
# ### SQL DEFAULT CONSTRAINT
# CREATE TABLE Persons (
#  ID int NOT NULL,
#  LastName varchar(255) NOT NULL,
#  FirstName varchar(255),
#  Age int,
#  City varchar(255) DEFAULT 'Sandnes'
# )
# ### SQL DEFAULT on ALTER TABLE

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("  ALTER table checktable ALTER b SET DEFAULT 'PQRS'  ")
conn.commit()
cur.fetchall()
# Out:
# []

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("  DESC checktable  ")
cur.fetchall()
# Out:
# [('a', b'int', 'NO', '', None, ''),
#  ('b', b'varchar(10)', 'YES', '', b'PQRS', ''),
#  ('d', b'int', 'YES', '', None, '')]

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("  select * from checktable  ")
cur.fetchall()
# Out:
# [(993, 'akc', 9990),
#  (963, 'afc', 9000),
#  (983, 'abc', 9376),
#  (968, 'zfc', 503),
#  (573, None, 9100),
#  (583, 'zgc', 9000),
#  (503, 'zfc', 9000),
#  (673, None, 9006),
#  (603, 'zgc', 1),
#  (201, 'zgc', 6376),
#  (101, 'abc', 1000),
#  (501, None, 2000),
#  (601, None, 3000)]

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("  insert into checktable values( 701  , DEFAULT ,5000 )")
conn.commit()
cur.fetchall()
# Out:
# []

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("  select * from checktable  ")
cur.fetchall()
# Out:
# [(993, 'akc', 9990),
#  (963, 'afc', 9000),
#  (983, 'abc', 9376),
#  (968, 'zfc', 503),
#  (573, None, 9100),
#  (583, 'zgc', 9000),
#  (503, 'zfc', 9000),
#  (673, None, 9006),
#  (603, 'zgc', 1),
#  (201, 'zgc', 6376),
#  (101, 'abc', 1000),
#  (501, None, 2000),
#  (601, None, 3000),
#  (701, ' ', 4000),
#  (701, 'PQRS', 5000)]

# %% [markdown]
# ### SQL CREATE INDEX STATEMENT
# CREATE INDEX statement in SQL is used to create indexes in tables. The
# indexes are used to retrieve data from the database more quickly than
# others. The user can not see the indexes, and they are just used to speed
# up queries /searches.
#
# Note: Updating the table with indexes takes a lot of time than updating a
# table without indexes. It is because the indexes also need an update. So,
# only create indexes on those columns that will be frequently searched
# against

# %%
import mysql.connector as connection
import pandas as pd
import csv

# %% [markdown]
# ### SQL VIEWS STATEMENT

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("  CREATE VIEW V AS select * from checktable where b is NULL  ")
cur.fetchall()
# Out:
# []

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute(" select * from V  ")
cur.fetchall()
# Out:
# [(573, None, 9100), (673, None, 9006), (501, None, 2000), (601, None, 3000)]

# %% [markdown]
# ### SQL VIEWS STATEMENT WITH CHECK OPTION

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute("  CREATE VIEW W AS select * from checktable where b is NULL WITH CHECK OPTION  ")
cur.fetchall()
# Out:
# []

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute(" select * from W  ")
cur.fetchall()
# Out:
# [(573, None, 9100), (673, None, 9006), (501, None, 2000), (601, None, 3000)]

# %% [markdown]
# ### DELETING ROWS INTO A VIEW
# DELETE FROM CUSTOMER_VIEW
#  WHERE age = 25;

# %% [markdown]
# ### DROPPING VIEWS

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute(" DROP VIEW W  ")
cur.fetchall()
# Out:
# []

# %%
conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
cur = conn.cursor()
cur.execute(" select * from W  ")
cur.fetchall()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-29-4bd642c267ad> in <module>
#       1 conn = connection.connect(host="localhost" , database = 'practise' , user= "root" , passwd = "Bharadwaja01" )
#       2 cur = conn.cursor()
# ----> 3 cur.execute(" select * from W  ")
#       4 cur.fetchall()
#
# ~\.conda\envs\gputest\lib\site-packages\mysql\connector\cursor.py in execute(self, operation, params, multi)
#     566
#     567         try:
# --> 568             self._handle_result(self._connection.cmd_query(stmt))
#     569         except errors.InterfaceError:
#     570             if self._connection._have_next_result:  # pylint: disable=W0212
#
# ~\.conda\envs\gputest\lib\site-packages\mysql\connector\connection.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     684             query = query.encode('utf-8')
#     685         try:
# ...

# %% [markdown]
# ### STORED PROCEDURE AND FUNCTIONS
