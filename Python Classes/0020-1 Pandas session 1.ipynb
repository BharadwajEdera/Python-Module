# %% [markdown]
# ## Importing pandas

# %%
import pandas as pd

# %% [markdown]
# ## Reading csv file

# %%
pd = pd.read_csv('E:/Downloads/Player.csv')

# %%
pd
# Out:
#      Player_Id      Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 0            1       SC Ganguly   8-Jul-72    Left_Hand    Right-arm medium
# 1            2      BB McCullum  27-Sep-81   Right_Hand    Right-arm medium
# 2            3       RT Ponting  19-Dec-74   Right_Hand    Right-arm medium
# 3            4        DJ Hussey  15-Jul-77   Right_Hand  Right-arm offbreak
# 4            5  Mohammad Hafeez  17-Oct-80   Right_Hand  Right-arm offbreak
# ..         ...              ...        ...          ...                 ...
# 518        519      Subroto Das        NaN          NaN                 NaN
# 519        520     K Srinivasan        NaN          NaN                 NaN
# 520        521        VK Sharma        NaN          NaN                 NaN
# 521        523      AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522        524      B Aparajith   8-Jul-94   Right_Hand  Right-arm offbreak
#
#          Country  Is_Umpire  Unnamed: 7
# 0          India          0         NaN
# 1    New Zealand          0         NaN
# 2      Australia          0         NaN
# 3      Australia          0         NaN
# 4       Pakistan          0         NaN
# ..           ...        ...         ...
# 518        India          1         NaN
# 519        India          1         NaN
# 520        India          1         NaN
# 521        India          0         NaN
# 522        India          0         NaN
#
# [523 rows x 8 columns]

# %% [markdown]
# ## Print top 20 rows :
#
# #### By default head() will give top 5 records

# %%
pd.head(20)
# Out:
#     Player_Id      Player_Name        DOB Batting_Hand  \
# 0           1       SC Ganguly   8-Jul-72    Left_Hand
# 1           2      BB McCullum  27-Sep-81   Right_Hand
# 2           3       RT Ponting  19-Dec-74   Right_Hand
# 3           4        DJ Hussey  15-Jul-77   Right_Hand
# 4           5  Mohammad Hafeez  17-Oct-80   Right_Hand
# 5           6         R Dravid  11-Jan-73   Right_Hand
# 6           7         W Jaffer  16-Feb-78   Right_Hand
# 7           8          V Kohli   5-Nov-88   Right_Hand
# 8           9        JH Kallis  16-Oct-75   Right_Hand
# 9          10         CL White  18-Aug-83   Right_Hand
# 10         11       MV Boucher   3-Dec-76   Right_Hand
# 11         12          B Akhil   7-Oct-77   Right_Hand
# 12         13        AA Noffke  30-Apr-77   Right_Hand
# 13         14          P Kumar   2-Oct-86   Right_Hand
# 14         15           Z Khan   7-Oct-78   Right_Hand
# 15         16         SB Joshi   6-Jun-70    Left_Hand
# 16         17         PA Patel   9-Mar-85    Left_Hand
# 17         18        ML Hayden  29-Oct-71    Left_Hand
# 18         19       MEK Hussey  27-May-75    Left_Hand
# 19         20         MS Dhoni   7-Jul-81   Right_Hand
#
#              Bowling_Skill       Country  Is_Umpire  Unnamed: 7
# 0         Right-arm medium         India          0         NaN
# 1         Right-arm medium   New Zealand          0         NaN
# 2         Right-arm medium     Australia          0         NaN
# 3       Right-arm offbreak     Australia          0         NaN
# 4       Right-arm offbreak      Pakistan          0         NaN
# 5       Right-arm offbreak         India          0         NaN
# 6       Right-arm offbreak         India          0         NaN
# 7         Right-arm medium         India          0         NaN
# 8    Right-arm fast-medium  South Africa          0         NaN
# 9          Legbreak googly     Australia          0         NaN
# 10        Right-arm medium  South Africa          0         NaN
# 11   Right-arm medium-fast         India          0         NaN
# 12   Right-arm fast-medium     Australia          0         NaN
# 13        Right-arm medium         India          0         NaN
# 14    Left-arm fast-medium         India          0         NaN
# 15  Slow left-arm orthodox         India          0         NaN
# 16                     NaN         India          0         NaN
# 17        Right-arm medium     Australia          0         NaN
# 18        Right-arm medium     Australia          0         NaN
# 19        Right-arm medium         India          0         NaN

# %% [markdown]
# ## Print last 5 records :

# %%
pd.tail()
# Out:
#      Player_Id   Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 518        519   Subroto Das        NaN          NaN                 NaN
# 519        520  K Srinivasan        NaN          NaN                 NaN
# 520        521     VK Sharma        NaN          NaN                 NaN
# 521        523   AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522        524   B Aparajith   8-Jul-94   Right_Hand  Right-arm offbreak
#
#     Country  Is_Umpire  Unnamed: 7
# 518   India          1         NaN
# 519   India          1         NaN
# 520   India          1         NaN
# 521   India          0         NaN
# 522   India          0         NaN

# %%
df = pd.read_csv('E:/Downloads/Player.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Storing top 5 records of previous file into another csv file

# %%
df1  =  df.head()

# %%
df.tail()
# Out:
#      Player_Id   Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 518        519   Subroto Das        NaN          NaN                 NaN
# 519        520  K Srinivasan        NaN          NaN                 NaN
# 520        521     VK Sharma        NaN          NaN                 NaN
# 521        523   AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522        524   B Aparajith   8-Jul-94   Right_Hand  Right-arm offbreak
#
#     Country  Is_Umpire  Unnamed: 7
# 518   India          1         NaN
# 519   India          1         NaN
# 520   India          1         NaN
# 521   India          0         NaN
# 522   India          0         NaN

# %%
df1.to_csv("test.csv")

# %%
pd.read_csv('test.csv')
# Out:
#    Unnamed: 0  Player_Id      Player_Name        DOB Batting_Hand  \
# 0           0          1       SC Ganguly   8-Jul-72    Left_Hand
# 1           1          2      BB McCullum  27-Sep-81   Right_Hand
# 2           2          3       RT Ponting  19-Dec-74   Right_Hand
# 3           3          4        DJ Hussey  15-Jul-77   Right_Hand
# 4           4          5  Mohammad Hafeez  17-Oct-80   Right_Hand
#
#         Bowling_Skill      Country  Is_Umpire  Unnamed: 7
# 0    Right-arm medium        India          0         NaN
# 1    Right-arm medium  New Zealand          0         NaN
# 2    Right-arm medium    Australia          0         NaN
# 3  Right-arm offbreak    Australia          0         NaN
# 4  Right-arm offbreak     Pakistan          0         NaN

# %% [markdown]
# ### By default read_csv will read comma seperated files. If we want to read data which is sepetated by any other delimiter we have to specify explicitly
#
# ### If we mention header=none then it won't read header. Instead it will print indexes as header
#
# ### If we don't want the inbuilt header we can specify our own column names by using 'names'
#
# ### To skip the unwanted rows we can delete them by using  'skiprows'

# %%
df = pd.read_csv('E:/Downloads/Player.csv',sep='#',header=None,names=['a','b','c','d','e','f','g','h'],skiprows=[0,4,6,8])

# %%
df
# Out:
#        a                b          c           d                   e  \
# 0      1       SC Ganguly   8-Jul-72   Left_Hand    Right-arm medium
# 1      2      BB McCullum  27-Sep-81  Right_Hand    Right-arm medium
# 2      3       RT Ponting  19-Dec-74  Right_Hand    Right-arm medium
# 3      5  Mohammad Hafeez  17-Oct-80  Right_Hand  Right-arm offbreak
# 4      7         W Jaffer  16-Feb-78  Right_Hand  Right-arm offbreak
# ..   ...              ...        ...         ...                 ...
# 515  519      Subroto Das        NaN         NaN                 NaN
# 516  520     K Srinivasan        NaN         NaN                 NaN
# 517  521        VK Sharma        NaN         NaN                 NaN
# 518  523      AV Wankhade  14-Mar-92  Right_Hand                 NaN
# 519  524      B Aparajith   8-Jul-94  Right_Hand  Right-arm offbreak
#
#                f  g   h
# 0          India  0 NaN
# 1    New Zealand  0 NaN
# 2      Australia  0 NaN
# 3       Pakistan  0 NaN
# 4          India  0 NaN
# ..           ... ..  ..
# 515        India  1 NaN
# 516        India  1 NaN
# 517        India  1 NaN
# 518        India  0 NaN
# 519        India  0 NaN
#
# [520 rows x 8 columns]

# %% [markdown]
# ### To covert any value into NaN value we can use 'na_values'

# %%
df = pd.read_csv('E:/Downloads/Player.csv',sep='#',na_values=['SC Ganguly',"BB McCullum"])

# %%
df
# Out:
#      Player_Id      Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 0            1              NaN   8-Jul-72    Left_Hand    Right-arm medium
# 1            2              NaN  27-Sep-81   Right_Hand    Right-arm medium
# 2            3       RT Ponting  19-Dec-74   Right_Hand    Right-arm medium
# 3            4        DJ Hussey  15-Jul-77   Right_Hand  Right-arm offbreak
# 4            5  Mohammad Hafeez  17-Oct-80   Right_Hand  Right-arm offbreak
# ..         ...              ...        ...          ...                 ...
# 518        519      Subroto Das        NaN          NaN                 NaN
# 519        520     K Srinivasan        NaN          NaN                 NaN
# 520        521        VK Sharma        NaN          NaN                 NaN
# 521        523      AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522        524      B Aparajith   8-Jul-94   Right_Hand  Right-arm offbreak
#
#          Country  Is_Umpire  Unnamed: 7
# 0          India          0         NaN
# 1    New Zealand          0         NaN
# 2      Australia          0         NaN
# 3      Australia          0         NaN
# 4       Pakistan          0         NaN
# ..           ...        ...         ...
# 518        India          1         NaN
# 519        India          1         NaN
# 520        India          1         NaN
# 521        India          0         NaN
# 522        India          0         NaN
#
# [523 rows x 8 columns]

# %%
df = pd.read_csv('E:/Downloads/Player.csv',sep='#')

# %%
df
# Out:
#      Player_Id      Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 0            1       SC Ganguly   8-Jul-72    Left_Hand    Right-arm medium
# 1            2      BB McCullum  27-Sep-81   Right_Hand    Right-arm medium
# 2            3       RT Ponting  19-Dec-74   Right_Hand    Right-arm medium
# 3            4        DJ Hussey  15-Jul-77   Right_Hand  Right-arm offbreak
# 4            5  Mohammad Hafeez  17-Oct-80   Right_Hand  Right-arm offbreak
# ..         ...              ...        ...          ...                 ...
# 518        519      Subroto Das        NaN          NaN                 NaN
# 519        520     K Srinivasan        NaN          NaN                 NaN
# 520        521        VK Sharma        NaN          NaN                 NaN
# 521        523      AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522        524      B Aparajith   8-Jul-94   Right_Hand  Right-arm offbreak
#
#          Country  Is_Umpire  Unnamed: 7
# 0          India          0         NaN
# 1    New Zealand          0         NaN
# 2      Australia          0         NaN
# 3      Australia          0         NaN
# 4       Pakistan          0         NaN
# ..           ...        ...         ...
# 518        India          1         NaN
# 519        India          1         NaN
# 520        India          1         NaN
# 521        India          0         NaN
# 522        India          0         NaN
#
# [523 rows x 8 columns]

# %%
df1 = pd.read_csv('E:/Downloads/Player.csv',sep='#',skiprows=[0,1,2])

# %%
df1
# Out:
#        3       RT Ponting  19-Dec-74  Right_Hand    Right-arm medium  \
# 0      4        DJ Hussey  15-Jul-77  Right_Hand  Right-arm offbreak
# 1      5  Mohammad Hafeez  17-Oct-80  Right_Hand  Right-arm offbreak
# 2      6         R Dravid  11-Jan-73  Right_Hand  Right-arm offbreak
# 3      7         W Jaffer  16-Feb-78  Right_Hand  Right-arm offbreak
# 4      8          V Kohli   5-Nov-88  Right_Hand    Right-arm medium
# ..   ...              ...        ...         ...                 ...
# 515  519      Subroto Das        NaN         NaN                 NaN
# 516  520     K Srinivasan        NaN         NaN                 NaN
# 517  521        VK Sharma        NaN         NaN                 NaN
# 518  523      AV Wankhade  14-Mar-92  Right_Hand                 NaN
# 519  524      B Aparajith   8-Jul-94  Right_Hand  Right-arm offbreak
#
#      Australia  0  Unnamed: 7
# 0    Australia  0         NaN
# 1     Pakistan  0         NaN
# 2        India  0         NaN
# 3        India  0         NaN
# 4        India  0         NaN
# ..         ... ..         ...
# 515      India  1         NaN
# 516      India  1         NaN
# 517      India  1         NaN
# 518      India  0         NaN
# 519      India  0         NaN
#
# [520 rows x 8 columns]

# %%
df
# Out:
#      Player_Id      Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 0            1       SC Ganguly   8-Jul-72    Left_Hand    Right-arm medium
# 1            2      BB McCullum  27-Sep-81   Right_Hand    Right-arm medium
# 2            3       RT Ponting  19-Dec-74   Right_Hand    Right-arm medium
# 3            4        DJ Hussey  15-Jul-77   Right_Hand  Right-arm offbreak
# 4            5  Mohammad Hafeez  17-Oct-80   Right_Hand  Right-arm offbreak
# ..         ...              ...        ...          ...                 ...
# 518        519      Subroto Das        NaN          NaN                 NaN
# 519        520     K Srinivasan        NaN          NaN                 NaN
# 520        521        VK Sharma        NaN          NaN                 NaN
# 521        523      AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522        524      B Aparajith   8-Jul-94   Right_Hand  Right-arm offbreak
#
#          Country  Is_Umpire  Unnamed: 7
# 0          India          0         NaN
# 1    New Zealand          0         NaN
# 2      Australia          0         NaN
# 3      Australia          0         NaN
# 4       Pakistan          0         NaN
# ..           ...        ...         ...
# 518        India          1         NaN
# 519        India          1         NaN
# 520        India          1         NaN
# 521        India          0         NaN
# 522        India          0         NaN
#
# [523 rows x 8 columns]

# %%
df.head()
# Out:
#    Player_Id      Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 0          1       SC Ganguly   8-Jul-72    Left_Hand    Right-arm medium
# 1          2      BB McCullum  27-Sep-81   Right_Hand    Right-arm medium
# 2          3       RT Ponting  19-Dec-74   Right_Hand    Right-arm medium
# 3          4        DJ Hussey  15-Jul-77   Right_Hand  Right-arm offbreak
# 4          5  Mohammad Hafeez  17-Oct-80   Right_Hand  Right-arm offbreak
#
#        Country  Is_Umpire  Unnamed: 7
# 0        India          0         NaN
# 1  New Zealand          0         NaN
# 2    Australia          0         NaN
# 3    Australia          0         NaN
# 4     Pakistan          0         NaN

# %% [markdown]
# ## Gives all the info about the dataset :

# %%
df.describe()
# Out:
#         Player_Id   Is_Umpire  Unnamed: 7
# count  523.000000  523.000000   12.000000
# mean   262.003824    0.099426    6.500000
# std    151.127981    0.299520    3.605551
# min      1.000000    0.000000    1.000000
# 25%    131.500000    0.000000    3.750000
# 50%    262.000000    0.000000    6.500000
# 75%    392.500000    0.000000    9.250000
# max    524.000000    1.000000   12.000000

# %% [markdown]
# ## Gives all the datatypes in out dataset :

# %%
df1.dtypes
# Out:
# 3                     int64
# RT Ponting           object
# 19-Dec-74            object
# Right_Hand           object
# Right-arm medium     object
# Australia            object
# 0                     int64
# Unnamed: 7          float64
# dtype: object

# %%
df1 = pd.read_csv('E:/Downloads/Player.csv',sep='#')

# %%
df1
# Out:
#      Player_Id      Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 0            1       SC Ganguly   8-Jul-72    Left_Hand    Right-arm medium
# 1            2      BB McCullum  27-Sep-81   Right_Hand    Right-arm medium
# 2            3       RT Ponting  19-Dec-74   Right_Hand    Right-arm medium
# 3            4        DJ Hussey  15-Jul-77   Right_Hand  Right-arm offbreak
# 4            5  Mohammad Hafeez  17-Oct-80   Right_Hand  Right-arm offbreak
# ..         ...              ...        ...          ...                 ...
# 518        519      Subroto Das        NaN          NaN                 NaN
# 519        520     K Srinivasan        NaN          NaN                 NaN
# 520        521        VK Sharma        NaN          NaN                 NaN
# 521        523      AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522        524      B Aparajith   8-Jul-94   Right_Hand  Right-arm offbreak
#
#          Country  Is_Umpire  Unnamed: 7
# 0          India          0         NaN
# 1    New Zealand          0         NaN
# 2      Australia          0         NaN
# 3      Australia          0         NaN
# 4       Pakistan          0         NaN
# ..           ...        ...         ...
# 518        India          1         NaN
# 519        India          1         NaN
# 520        India          1         NaN
# 521        India          0         NaN
# 522        India          0         NaN
#
# [523 rows x 8 columns]

# %%
df1.to_csv("result3.csv",index=False,sep = "#", columns=['Player_Id','DOB'])

# %%
df = pd.read_csv('E:/Downloads/Player.csv',sep='#')

# %%
df
# Out:
#      Player_Id      Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 0            1       SC Ganguly   8-Jul-72    Left_Hand    Right-arm medium
# 1            2      BB McCullum  27-Sep-81   Right_Hand    Right-arm medium
# 2            3       RT Ponting  19-Dec-74   Right_Hand    Right-arm medium
# 3            4        DJ Hussey  15-Jul-77   Right_Hand  Right-arm offbreak
# 4            5  Mohammad Hafeez  17-Oct-80   Right_Hand  Right-arm offbreak
# ..         ...              ...        ...          ...                 ...
# 518        519      Subroto Das        NaN          NaN                 NaN
# 519        520     K Srinivasan        NaN          NaN                 NaN
# 520        521        VK Sharma        NaN          NaN                 NaN
# 521        523      AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522        524      B Aparajith   8-Jul-94   Right_Hand  Right-arm offbreak
#
#          Country  Is_Umpire  Unnamed: 7
# 0          India          0         NaN
# 1    New Zealand          0         NaN
# 2      Australia          0         NaN
# 3      Australia          0         NaN
# 4       Pakistan          0         NaN
# ..           ...        ...         ...
# 518        India          1         NaN
# 519        India          1         NaN
# 520        India          1         NaN
# 521        India          0         NaN
# 522        India          0         NaN
#
# [523 rows x 8 columns]

# %%
df.tail()
# Out:
#      Player_Id   Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 518        519   Subroto Das        NaN          NaN                 NaN
# 519        520  K Srinivasan        NaN          NaN                 NaN
# 520        521     VK Sharma        NaN          NaN                 NaN
# 521        523   AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522        524   B Aparajith   8-Jul-94   Right_Hand  Right-arm offbreak
#
#     Country  Is_Umpire  Unnamed: 7
# 518   India          1         NaN
# 519   India          1         NaN
# 520   India          1         NaN
# 521   India          0         NaN
# 522   India          0         NaN

# %% [markdown]
# ## Print only column names

# %%
df.columns
# Out:
# Index(['Player_Id', 'Player_Name', 'DOB', 'Batting_Hand', 'Bowling_Skill',
#        'Country', 'Is_Umpire', 'Unnamed: 7'],
#       dtype='object')

# %% [markdown]
# ### If we pass the column name normally it will return in terms of series

# %%
type(df['Player_Id'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### If we pass the column name in a list then it will return in terms a dataframe

# %%
type(df[['Player_Id']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Slicing
#
# ### If there is more than one columns then we should pass the column names in a list otherwise it will throw an error

# %%
df[['Player_Id', 'Batting_Hand']]
# Out:
#      Player_Id Batting_Hand
# 0            1    Left_Hand
# 1            2   Right_Hand
# 2            3   Right_Hand
# 3            4   Right_Hand
# 4            5   Right_Hand
# ..         ...          ...
# 518        519          NaN
# 519        520          NaN
# 520        521          NaN
# 521        523   Right_Hand
# 522        524   Right_Hand
#
# [523 rows x 2 columns]

# %%
df[['Is_Umpire' , 'Player_Id' , 'Batting_Hand']]
# Out:
#      Is_Umpire  Player_Id Batting_Hand
# 0            0          1    Left_Hand
# 1            0          2   Right_Hand
# 2            0          3   Right_Hand
# 3            0          4   Right_Hand
# 4            0          5   Right_Hand
# ..         ...        ...          ...
# 518          1        519          NaN
# 519          1        520          NaN
# 520          1        521          NaN
# 521          0        523   Right_Hand
# 522          0        524   Right_Hand
#
# [523 rows x 3 columns]

# %% [markdown]
# ## Reading an excel sheet

# %%
df2 = pd.read_excel('E:/Downloads/sample-excel-master/LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx',sheet_name='Create your instrument universe')

# %% [markdown]
# ## Reading html page

# %%
# !pip install html5lib
# !pip install lxml
# !pip install beautifulSoup4
# Out:
# Requirement already satisfied: html5lib in c:\users\bharadwaj\.conda\envs\gputest\lib\site-packages (1.1)
# Requirement already satisfied: six>=1.9 in c:\users\bharadwaj\appdata\roaming\python\python36\site-packages (from html5lib) (1.12.0)
# Requirement already satisfied: webencodings in c:\users\bharadwaj\appdata\roaming\python\python36\site-packages (from html5lib) (0.5.1)
# WARNING: Error parsing requirements for tensorflow: [Errno 2] No such file or directory: 'c:\\users\\bharadwaj\\appdata\\roaming\\python\\python36\\site-packages\\tensorflow-1.15.0.dist-info\\METADATA'
# Requirement already satisfied: lxml in c:\users\bharadwaj\.conda\envs\gputest\lib\site-packages (4.6.2)
# WARNING: Error parsing requirements for tensorflow: [Errno 2] No such file or directory: 'c:\\users\\bharadwaj\\appdata\\roaming\\python\\python36\\site-packages\\tensorflow-1.15.0.dist-info\\METADATA'
# Requirement already satisfied: beautifulSoup4 in c:\users\bharadwaj\.conda\envs\gputest\lib\site-packages (4.9.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\bharadwaj\.conda\envs\gputest\lib\site-packages (from beautifulSoup4) (2.1)
# WARNING: Error parsing requirements for tensorflow: [Errno 2] No such file or directory: 'c:\\users\\bharadwaj\\appdata\\roaming\\python\\python36\\site-packages\\tensorflow-1.15.0.dist-info\\METADATA'

# %%
import html5lib
import lxml
from bs4 import BeautifulSoup

# %%
pip install html5lib
# Out:
# Collecting html5lib
#   Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Requirement already satisfied: six>=1.9 in c:\users\bharadwaj\appdata\roaming\python\python36\site-packages (from html5lib) (1.12.0)
# Requirement already satisfied: webencodings in c:\users\bharadwaj\appdata\roaming\python\python36\site-packages (from html5lib) (0.5.1)
# Installing collected packages: html5lib
# Successfully installed html5lib-1.1
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Error parsing requirements for tensorflow: [Errno 2] No such file or directory: 'c:\\users\\bharadwaj\\appdata\\roaming\\python\\python36\\site-packages\\tensorflow-1.15.0.dist-info\\METADATA'

# %%
https://www.kaggle.com/alampalsingh/qualification-status-dataset

# %%
df5 = pd.read_html("https://pbpython.com/pandas-html-table.html")

# %%
df4 = pd.read_html("https://www.basketball-reference.com/players/i/ibakase01.html?utm_source=direct&utm_medium=Share&utm_campaign=ShareTool")

# %%
df4
# Out:
# [       Season   Age                                   Team  \
#  0     2008-09  19.0  Did Not Play (other pro league—Spain)
#  1     2009-10  20.0                                    OKC
#  2     2010-11  21.0                                    OKC
#  3     2011-12  22.0                                    OKC
#  4     2012-13  23.0                                    OKC
#  5     2013-14  24.0                                    OKC
#  6     2014-15  25.0                                    OKC
#  7     2015-16  26.0                                    OKC
#  8     2016-17  27.0                                    TOT
#  9     2016-17  27.0                                    ORL
#  10    2016-17  27.0                                    TOR
#  11    2017-18  28.0                                    TOR
#  12    2018-19  29.0                                    TOR
#  13    2019-20  30.0                                    TOR
#  14    2020-21  31.0                                    LAC
#  15     Career   NaN                                    NaN
#  16        NaN   NaN                                    NaN
#  17  7 seasons   NaN                                    OKC
#  18  4 seasons   NaN                                    TOR
#  19   1 season   NaN                                    ORL
#  20   1 season   NaN                                    LAC
#
#                                         Lg  \
#  0   Did Not Play (other pro league—Spain)
#  1                                     NBA
#  2                                     NBA
#  3                                     NBA
#  4                                     NBA
#  5                                     NBA
#  6                                     NBA
#  7                                     NBA
#  8                                     NBA
#  9                                     NBA
#  10                                    NBA
#  11                                    NBA
#  12                                    NBA
#  13                                    NBA
#  14                                    NBA
#  15                                    NBA
#  16                                    NaN
#  17                                    NBA
#  18                                    NBA
#  19                                    NBA
#  20                                    NBA
#
#                                        Pos  \
#  0   Did Not Play (other pro league—Spain)
#  1                                      PF
#  2                                      PF
#  3                                      PF
#  4                                      PF
#  5                                      PF
#  6                                      PF
#  7                                      PF
#  8                                      PF
#  9                                      PF
#  10                                     PF
#  11                                     PF
#  12                                      C
#  13                                      C
#  14                                      C
#  15                                    NaN
#  16                                    NaN
#  17                                    NaN
#  18                                    NaN
#  19                                    NaN
#  20                                    NaN
#
#                                          G  \
#  0   Did Not Play (other pro league—Spain)
#  1                                      73
#  2                                      82
#  3                                      66
#  4                                      80
#  5                                      81
#  6                                      64
#  7                                      78
#  8                                      79
#  9                                      56
#  10                                     23
#  11                                     76
#  12                                     74
#  13                                     55
#  14                                     41
#  15                                    849
#  16                                    NaN
#  17                                    524
#  18                                    228
#  19                                     56
#  20                                     41
#
#                                         GS  \
#  0   Did Not Play (other pro league—Spain)
#  1                                       0
#  2                                      44
#  3                                      66
#  4                                      80
#  5                                      81
#  6                                      64
#  7                                      78
#  8                                      79
#  9                                      56
#  10                                     23
#  11                                     76
#  12                                     51
#  13                                     27
#  14                                     39
#  15                                    685
#  16                                    NaN
#  17                                    413
#  18                                    177
#  19                                     56
#  20                                     39
#
#                                         MP  \
#  0   Did Not Play (other pro league—Spain)
#  1                                    18.1
#  2                                    27.0
#  3                                    27.2
#  4                                    31.1
#  5                                    32.9
#  6                                    33.1
#  7                                    32.1
#  8                                    30.7
#  9                                    30.5
#  10                                   31.0
#  11                                   27.5
#  12                                   27.2
#  13                                   27.0
#  14                                   23.3
#  15                                   28.3
#  16                                    NaN
#  17                                   28.8
#  18                                   27.6
#  19                                   30.5
#  20                                   23.3
#
#                                         FG  \
#  0   Did Not Play (other pro league—Spain)
#  1                                     2.8
#  2                                     4.1
#  3                                     4.0
#  4                                     5.6
#  5                                     6.5
#  6                                     5.8
#  7                                     5.3
#  8                                     6.0
#  9                                     6.1
#  10                                    5.6
#  11                                    5.0
#  12                                    6.3
#  13                                    6.2
#  14                                    4.5
#  15                                    5.2
#  16                                    NaN
#  17                                    4.9
#  18                                    5.8
#  19                                    6.1
#  20                                    4.5
#
#                                        FGA  ...  \
#  0   Did Not Play (other pro league—Spain)  ...
#  1                                     5.1  ...
#  2                                     7.5  ...
#  3                                     7.4  ...
#  4                                     9.7  ...
#  5                                    12.1  ...
#  6                                    12.3  ...
#  7                                    11.1  ...
#  8                                    12.4  ...
#  9                                    12.6  ...
#  10                                   12.1  ...
#  11                                   10.3  ...
#  12                                   11.9  ...
#  13                                   12.2  ...
#  14                                    8.9  ...
#  15                                   10.1  ...
#  16                                    NaN  ...
#  17                                    9.3  ...
#  18                                   11.4  ...
#  19                                   12.6  ...
#  20                                    8.9  ...
#
#                                        FT%  \
#  0   Did Not Play (other pro league—Spain)
#  1                                    .630
#  2                                    .750
#  3                                    .661
#  4                                    .749
#  5                                    .784
#  6                                    .836
#  7                                    .752
#  8                                    .856
#  9                                    .846
#  10                                   .882
#  11                                   .797
#  12                                   .763
#  13                                   .718
#  14                                   .811
#  15                                   .759
#  16                                    NaN
#  17                                   .745
#  18                                   .768
#  19                                   .846
#  20                                   .811
#
#                                        ORB  \
#  0   Did Not Play (other pro league—Spain)
#  1                                     1.9
#  2                                     2.6
#  3                                     2.9
#  4                                     2.8
#  5                                     2.8
#  6                                     2.1
#  7                                     1.8
#  8                                     1.6
#  9                                     1.8
#  10                                    1.3
#  11                                    1.0
#  12                                    2.1
#  13                                    2.1
#  14                                    1.8
#  15                                    2.1
#  16                                    NaN
#  17                                    2.4
#  18                                    1.7
#  19                                    1.8
#  20                                    1.8
#
#                                        DRB  \
#  0   Did Not Play (other pro league—Spain)
#  1                                     3.5
#  2                                     5.0
#  3                                     4.6
#  4                                     4.9
#  5                                     6.0
#  6                                     5.7
#  7                                     5.0
#  8                                     5.2
#  9                                     5.0
#  10                                    5.5
#  11                                    5.3
#  12                                    6.0
#  13                                    6.1
#  14                                    4.9
#  15                                    5.2
#  16                                    NaN
#  17                                    5.0
#  18                                    5.7
#  19                                    5.0
#  20                                    4.9
#
#                                        TRB  \
#  0   Did Not Play (other pro league—Spain)
#  1                                     5.4
#  2                                     7.6
#  3                                     7.5
#  4                                     7.7
#  5                                     8.8
#  6                                     7.8
#  7                                     6.8
#  8                                     6.8
#  9                                     6.8
#  10                                    6.8
#  11                                    6.3
#  12                                    8.1
#  13                                    8.2
#  14                                    6.7
#  15                                    7.3
#  16                                    NaN
#  17                                    7.4
#  18                                    7.4
#  19                                    6.8
#  20                                    6.7
#
#                                        AST  \
#  0   Did Not Play (other pro league—Spain)
#  1                                     0.1
#  2                                     0.3
#  3                                     0.4
#  4                                     0.5
#  5                                     1.0
#  6                                     0.9
#  7                                     0.8
#  8                                     0.9
#  9                                     1.1
#  10                                    0.7
#  11                                    0.8
#  12                                    1.3
#  13                                    1.4
#  14                                    1.8
#  15                                    0.8
#  16                                    NaN
#  17                                    0.6
#  18                                    1.1
#  19                                    1.1
#  20                                    1.8
#
#                                        STL  \
#  0   Did Not Play (other pro league—Spain)
#  1                                     0.3
#  2                                     0.4
#  3                                     0.5
#  4                                     0.4
#  5                                     0.5
#  6                                     0.5
#  7                                     0.5
#  8                                     0.5
#  9                                     0.6
#  10                                    0.3
#  11                                    0.4
#  12                                    0.4
#  13                                    0.5
#  14                                    0.2
#  15                                    0.4
#  16                                    NaN
#  17                                    0.4
#  18                                    0.4
#  19                                    0.6
#  20                                    0.2
#
#                                        BLK  \
#  0   Did Not Play (other pro league—Spain)
#  1                                     1.3
#  2                                     2.4
#  3                                     3.7
#  4                                     3.0
#  5                                     2.7
#  6                                     2.4
#  7                                     1.9
#  8                                     1.6
#  9                                     1.6
#  10                                    1.4
#  11                                    1.3
#  12                                    1.4
#  13                                    0.8
#  14                                    1.1
#  15                                    2.0
#  16                                    NaN
#  17                                    2.5
#  18                                    1.2
#  19                                    1.6
#  20                                    1.1
#
#                                        TOV  \
#  0   Did Not Play (other pro league—Spain)
#  1                                     0.9
#  2                                     0.9
#  3                                     1.2
#  4                                     1.6
#  5                                     1.5
#  6                                     1.5
#  7                                     1.4
#  8                                     1.3
#  9                                     1.2
#  10                                    1.7
#  11                                    1.2
#  12                                    1.5
#  13                                    2.0
#  14                                    1.1
#  15                                    1.3
#  16                                    NaN
#  17                                    1.3
#  18                                    1.5
#  19                                    1.2
#  20                                    1.1
#
#                                         PF  \
#  0   Did Not Play (other pro league—Spain)
#  1                                     2.7
#  2                                     3.3
#  3                                     2.7
#  4                                     2.7
#  5                                     2.9
#  6                                     3.0
#  7                                     2.7
#  8                                     2.7
#  9                                     2.5
#  10                                    3.3
#  11                                    2.8
#  12                                    2.9
#  13                                    2.8
#  14                                    1.9
#  15                                    2.8
#  16                                    NaN
#  17                                    2.8
#  18                                    2.8
#  19                                    2.5
#  20                                    1.9
#
#                                        PTS
#  0   Did Not Play (other pro league—Spain)
#  1                                     6.3
#  2                                     9.9
#  3                                     9.1
#  4                                    13.2
#  5                                    15.1
#  6                                    14.3
#  7                                    12.6
#  8                                    14.8
#  9                                    15.1
#  10                                   14.2
#  11                                   12.6
#  12                                   15.0
#  13                                   15.4
#  14                                   11.1
#  15                                   12.5
#  16                                    NaN
#  17                                   11.6
#  18                                   14.2
#  19                                   15.1
#  20                                   11.1
#
#  [21 rows x 30 columns],
#         Season   Age Team   Lg  Pos      G     GS    MP   FG   FGA  ...    FT%  \
#  0     2009-10  20.0  OKC  NBA   PF    6.0    0.0  25.5  3.3   5.8  ...  0.700
#  1     2010-11  21.0  OKC  NBA   PF   17.0   17.0  28.8  3.9   8.5  ...  0.825
#  2     2011-12  22.0  OKC  NBA   PF   20.0   20.0  28.5  4.2   8.0  ...  0.722
#  3     2012-13  23.0  OKC  NBA   PF   11.0   11.0  33.3  5.4  12.3  ...  0.792
#  4     2013-14  24.0  OKC  NBA   PF   17.0   17.0  34.2  5.1   8.6  ...  0.765
#  5     2015-16  26.0  OKC  NBA   PF   18.0   18.0  33.4  4.7   9.1  ...  0.750
#  6     2016-17  27.0  TOR  NBA   PF   10.0   10.0  30.7  6.0  13.0  ...  0.846
#  7     2017-18  28.0  TOR  NBA   PF   10.0    9.0  26.0  3.0   7.2  ...  0.818
#  8     2018-19  29.0  TOR  NBA    C   24.0    0.0  20.8  3.8   8.0  ...  0.762
#  9     2019-20  30.0  TOR  NBA    C   11.0    0.0  22.8  5.7  10.0  ...  1.000
#  10    2020-21  31.0  LAC  NBA    C    2.0    0.0   9.0  1.5   3.0  ...  1.000
#  11     Career   NaN  NaN  NBA  NaN  146.0  102.0  28.1  4.5   8.9  ...  0.792
#  12        NaN   NaN  NaN  NaN  NaN    NaN    NaN   NaN  Na
#  13          NaN  5.0  3.2   8.2  0.142          NaN   0.7   1.2   1.9   2.7
#  14          NaN  1.0  2.0   3.0  0.110          NaN  -0.1   1.0   1.0   1.0
#  15          NaN  0.1  0.0   0.1  0.294          NaN   5.0   7.0  12.0   0.1
#
#  [16 rows x 29 columns]]

# %%
type(df4)
# Out:
# list

# %% [markdown]
# ## Gives numbers of tables in the html page that we have read

# %%
len(df4)
# Out:
# 6

# %%
df5[0]
# Out:
#    Unnamed: 0  Year     Office    GOP    DFL Others
# 0           0  2018   Governor  42.4%  53.9%   3.7%
# 1           1  2018    Senator  36.2%  60.3%   3.4%
# 2           2  2018    Senator  42.4%  53.0%   4.6%
# 3           3  2016  President  44.9%  46.4%   8.6%
# 4           4  2014   Governor  44.5%  50.1%   5.4%

# %%
df4[3].to_csv("players_data.csv")

# %%
df9=pd.read_html('''https://www.basketball-reference.com/players/i/ibakase01.html?utm_source=direct&utm_medium=Share&utm_campaign=ShareTool
''')

# %%
df9[0]
# Out:
#        Season   Age                                   Team  \
# 0     2008-09  19.0  Did Not Play (other pro league—Spain)
# 1     2009-10  20.0                                    OKC
# 2     2010-11  21.0                                    OKC
# 3     2011-12  22.0                                    OKC
# 4     2012-13  23.0                                    OKC
# 5     2013-14  24.0                                    OKC
# 6     2014-15  25.0                                    OKC
# 7     2015-16  26.0                                    OKC
# 8     2016-17  27.0                                    TOT
# 9     2016-17  27.0                                    ORL
# 10    2016-17  27.0                                    TOR
# 11    2017-18  28.0                                    TOR
# 12    2018-19  29.0                                    TOR
# 13    2019-20  30.0                                    TOR
# 14    2020-21  31.0                                    LAC
# 15     Career   NaN                                    NaN
# 16        NaN   NaN                                    NaN
# 17  7 seasons   NaN                                    OKC
# 18  4 seasons   NaN                                    TOR
# 19   1 season   NaN                                    ORL
# 20   1 season   NaN                                    LAC
#
#                                        Lg  \
# 0   Did Not Play (other pro league—Spain)
# 1                                     NBA
# 2                                     NBA
# 3                                     NBA
# 4                                     NBA
# 5                                     NBA
# 6                                     NBA
# 7                                     NBA
# 8                                     NBA
# 9                                     NBA
# 10                                    NBA
# 11                                    NBA
# 12                                    NBA
# 13                                    NBA
# 14                                    NBA
# 15                                    NBA
# 16                                    NaN
# 17                                    NBA
# 18                                    NBA
# 19                                    NBA
# 20                                    NBA
#
#                                       Pos  \
# 0   Did Not Play (other pro league—Spain)
# 1                                      PF
# 2                                      PF
# 3                                      PF
# 4                                      PF
# 5                                      PF
# 6                                      PF
# 7                                      PF
# 8                                      PF
# 9                                      PF
# 10                                     PF
# 11                                     PF
# 12                                      C
# 13                                      C
# 14                                      C
# 15                                    NaN
# 16                                    NaN
# 17                                    NaN
# 18                                    NaN
# 19                                    NaN
# 20                                    NaN
#
#                                         G  \
# 0   Did Not Play (other pro league—Spain)
# 1                                      73
# 2                                      82
# 3                                      66
# 4                                      80
# 5                                      81
# 6                                      64
# 7                                      78
# 8                                      79
# 9                                      56
# 10                                     23
# 11                                     76
# 12                                     74
# 13                                     55
# 14                                     41
# 15                                    849
# 16                                    NaN
# 17                                    524
# 18                                    228
# 19                                     56
# 20                                     41
#
#                                        GS  \
# 0   Did Not Play (other pro league—Spain)
# 1                                       0
# 2                                      44
# 3                                      66
# 4                                      80
# 5                                      81
# 6                                      64
# 7                                      78
# 8                                      79
# 9                                      56
# 10                                     23
# 11                                     76
# 12                                     51
# 13                                     27
# 14                                     39
# 15                                    685
# 16                                    NaN
# 17                                    413
# 18                                    177
# 19                                     56
# 20                                     39
#
#                                        MP  \
# 0   Did Not Play (other pro league—Spain)
# 1                                    18.1
# 2                                    27.0
# 3                                    27.2
# 4                                    31.1
# 5                                    32.9
# 6                                    33.1
# 7                                    32.1
# 8                                    30.7
# 9                                    30.5
# 10                                   31.0
# 11                                   27.5
# 12                                   27.2
# 13                                   27.0
# 14                                   23.3
# 15                                   28.3
# 16                                    NaN
# 17                                   28.8
# 18                                   27.6
# 19                                   30.5
# 20                                   23.3
#
#                                        FG  \
# 0   Did Not Play (other pro league—Spain)
# 1                                     2.8
# 2                                     4.1
# 3                                     4.0
# 4                                     5.6
# 5                                     6.5
# 6                                     5.8
# 7                                     5.3
# 8                                     6.0
# 9                                     6.1
# 10                                    5.6
# 11                                    5.0
# 12                                    6.3
# 13                                    6.2
# 14                                    4.5
# 15                                    5.2
# 16                                    NaN
# 17                                    4.9
# 18                                    5.8
# 19                                    6.1
# 20                                    4.5
#
#                                       FGA  ...  \
# 0   Did Not Play (other pro league—Spain)  ...
# 1                                     5.1  ...
# 2                                     7.5  ...
# 3                                     7.4  ...
# 4                                     9.7  ...
# 5                                    12.1  ...
# 6                                    12.3  ...
# 7                                    11.1  ...
# 8                                    12.4  ...
# 9                                    12.6  ...
# 10                                   12.1  ...
# 11                                   10.3  ...
# 12                                   11.9  ...
# 13                                   12.2  ...
# 14                                    8.9  ...
# 15                                   10.1  ...
# 16                                    NaN  ...
# 17                                    9.3  ...
# 18                                   11.4  ...
# 19                                   12.6  ...
# 20                                    8.9  ...
#
#                                       FT%  \
# 0   Did Not Play (other pro league—Spain)
# 1                                    .630
# 2                                    .750
# 3                                    .661
# 4                                    .749
# 5                                    .784
# 6                                    .836
# 7                                    .752
# 8                                    .856
# 9                                    .846
# 10                                   .882
# 11                                   .797
# 12                                   .763
# 13                                   .718
# 14                                   .811
# 15                                   .759
# 16                                    NaN
# 17                                   .745
# 18                                   .768
# 19                                   .846
# 20                                   .811
#
#                                       ORB  \
# 0   Did Not Play (other pro league—Spain)
# 1                                     1.9
# 2                                     2.6
# 3                                     2.9
# 4                                     2.8
# 5                                     2.8
# 6                                     2.1
# 7                                     1.8
# 8                                     1.6
# 9                                     1.8
# 10                                    1.3
# 11                                    1.0
# 12                                    2.1
# 13                                    2.1
# 14                                    1.8
# 15                                    2.1
# 16                                    NaN
# 17                                    2.4
# 18                                    1.7
# 19                                    1.8
# 20                                    1.8
#
#                                       DRB  \
# 0   Did Not Play (other pro league—Spain)
# 1                                     3.5
# 2                                     5.0
# 3                                     4.6
# 4                                     4.9
# 5                                     6.0
# 6                                     5.7
# 7                                     5.0
# 8                                     5.2
# 9                                     5.0
# 10                                    5.5
# 11                                    5.3
# 12                                    6.0
# 13                                    6.1
# 14                                    4.9
# 15                                    5.2
# 16                                    NaN
# 17                                    5.0
# 18                                    5.7
# 19                                    5.0
# 20                                    4.9
#
#                                       TRB  \
# 0   Did Not Play (other pro league—Spain)
# 1                                     5.4
# 2                                     7.6
# 3                                     7.5
# 4                                     7.7
# 5                                     8.8
# 6                                     7.8
# 7                                     6.8
# 8                                     6.8
# 9                                     6.8
# 10                                    6.8
# 11                                    6.3
# 12                                    8.1
# 13                                    8.2
# 14                                    6.7
# 15                                    7.3
# 16                                    NaN
# 17                                    7.4
# 18                                    7.4
# 19                                    6.8
# 20                                    6.7
#
#                                       AST  \
# 0   Did Not Play (other pro league—Spain)
# 1                                     0.1
# 2                                     0.3
# 3                                     0.4
# 4                                     0.5
# 5                                     1.0
# 6                                     0.9
# 7                                     0.8
# 8                                     0.9
# 9                                     1.1
# 10                                    0.7
# 11                                    0.8
# 12                                    1.3
# 13                                    1.4
# 14                                    1.8
# 15                                    0.8
# 16                                    NaN
# 17                                    0.6
# 18                                    1.1
# 19                                    1.1
# 20                                    1.8
#
#                                       STL  \
# 0   Did Not Play (other pro league—Spain)
# 1                                     0.3
# 2                                     0.4
# 3                                     0.5
# 4                                     0.4
# 5                                     0.5
# 6                                     0.5
# 7                                     0.5
# 8                                     0.5
# 9                                     0.6
# 10                                    0.3
# 11                                    0.4
# 12                                    0.4
# 13                                    0.5
# 14                                    0.2
# 15                                    0.4
# 16                                    NaN
# 17                                    0.4
# 18                                    0.4
# 19                                    0.6
# 20                                    0.2
#
#                                       BLK  \
# 0   Did Not Play (other pro league—Spain)
# 1                                     1.3
# 2                                     2.4
# 3                                     3.7
# 4                                     3.0
# 5                                     2.7
# 6                                     2.4
# 7                                     1.9
# 8                                     1.6
# 9                                     1.6
# 10                                    1.4
# 11                                    1.3
# 12                                    1.4
# 13                                    0.8
# 14                                    1.1
# 15                                    2.0
# 16                                    NaN
# 17                                    2.5
# 18                                    1.2
# 19                                    1.6
# 20                                    1.1
#
#                                       TOV  \
# 0   Did Not Play (other pro league—Spain)
# 1                                     0.9
# 2                                     0.9
# 3                                     1.2
# 4                                     1.6
# 5                                     1.5
# 6                                     1.5
# 7                                     1.4
# 8                                     1.3
# 9                                     1.2
# 10                                    1.7
# 11                                    1.2
# 12                                    1.5
# 13                                    2.0
# 14                                    1.1
# 15                                    1.3
# 16                                    NaN
# 17                                    1.3
# 18                                    1.5
# 19                                    1.2
# 20                                    1.1
#
#                                        PF  \
# 0   Did Not Play (other pro league—Spain)
# 1                                     2.7
# 2                                     3.3
# 3                                     2.7
# 4                                     2.7
# 5                                     2.9
# 6                                     3.0
# 7                                     2.7
# 8                                     2.7
# 9                                     2.5
# 10                                    3.3
# 11                                    2.8
# 12                                    2.9
# 13                                    2.8
# 14                                    1.9
# 15                                    2.8
# 16                                    NaN
# 17                                    2.8
# 18                                    2.8
# 19                                    2.5
# 20                                    1.9
#
#                                       PTS
# 0   Did Not Play (other pro league—Spain)
# 1                                     6.3
# 2                                     9.9
# 3                                     9.1
# 4                                    13.2
# 5                                    15.1
# 6                                    14.3
# 7                                    12.6
# 8                                    14.8
# 9                                    15.1
# 10                                   14.2
# 11                                   12.6
# 12                                   15.0
# 13                                   15.4
# 14                                   11.1
# 15                                   12.5
# 16                                    NaN
# 17                                   11.6
# 18                                   14.2
# 19                                   15.1
# 20                                   11.1
#
# [21 rows x 30 columns]

# %% [markdown]
# ## To create different CSV files corresponding to each table in html page

# %%
html_data = pd.read_html("https://www.basketball-reference.com/players/i/ibakase01.html?utm_source=direct&utm_medium=Share&utm_campaign=ShareTool")
for i in range(len(html_data)):
    html_data[i].to_csv(f"html_data{i}.csv", index=False)

# %% [markdown]
# ## How to read a github dataset (it should be in raw format)

# %%
https://raw.githubusercontent.com/BharadwajEdera/Python-Module/master/Python%20Classes/Fruits.csv

# %%
pd.read_csv("https://raw.githubusercontent.com/BharadwajEdera/Python-Module/master/Python%20Classes/Fruits.csv")
# Out:
#    Id        Name  Price  Stock
# 0   1       Apple    0.4     30
# 1   2     Avacado    0.5     25
# 2   3      Banana    0.6     20
# 3   4  Blackberry    0.4     50
# 4   5      Cherry    0.5     40
# 5   6       Grape    0.7     15
# 6   7        Kiwi    0.6     15
# 7   8       Lemon    0.4     25
# 8   9       Mango    0.5     30
# 9  10      Orange    0.6     10

# %%
pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# ## Reading json data

# %% [markdown]
# #### We can cross verify our json data format by checking it on json viewer !!!!
#
# http://jsonviewer.stack.hu/

# %%
s = """{
"name" :"sudh",
"phone_no" : 45454545,
"comp":["iNeuron", "EY" , "unilver" , "verizon" , "deloitte" , "wipro"]
}
"""

# %%
s
# Out:
# '{\n"name" :"sudh",\n"phone_no" : 45454545,\n"comp":["iNeuron", "EY" , "unilver" , "verizon" , "deloitte" , "wipro"]\n}\n'

# %%
import json

# %%
s1 = json.loads(s)

# %%
s1
# Out:
# {'name': 'sudh',
#  'phone_no': 45454545,
#  'comp': ['iNeuron', 'EY', 'unilver', 'verizon', 'deloitte', 'wipro']}

# %% [markdown]
# ## Converting json data into tabular format using pandas

# %%
pd.DataFrame(s1)
# Out:
#    name  phone_no      comp
# 0  sudh  45454545   iNeuron
# 1  sudh  45454545        EY
# 2  sudh  45454545   unilver
# 3  sudh  45454545   verizon
# 4  sudh  45454545  deloitte
# 5  sudh  45454545     wipro

# %%
pd.DataFrame(s1,columns=['comp'])
# Out:
#        comp
# 0   iNeuron
# 1        EY
# 2   unilver
# 3   verizon
# 4  deloitte
# 5     wipro

# %% [markdown]
# ## Loading complex json data

# %%
import requests

# %%
res = requests.get('https://api.github.com/repos/pandas-dev/pandas/issues')

# %%
res
# Out:
# <Response [200]>

# %%
js = res.json()

# %%
js
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41838',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41838/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41838/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41838/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/41838',
#   'id': 912722673,
#   'node_id': 'MDU6SXNzdWU5MTI3MjI2NzM=',
#   'number': 41838,
#   'title': 'ENH: Using transparentpath in read_csv',
#   'user': {'login': 'michaelshekasta',
#    'id': 41590425,
#    'node_id': 'MDQ6VXNlcjQxNTkwNDI1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41590425?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/michaelshekasta',
#    'html_url': 'https://github.com/michaelshekasta',
#    'followers_url': 'https://api.github.com/users/michaelshekasta/followers',
#    'following_url': 'https://api.github.com/users/michaelshekasta/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/michaelshekasta/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/michaelshekasta/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/michaelshekasta/subscriptions',
#    'organizations_url': 'https://api.github.com/users/michaelshekasta/orgs',
#    'repos_url': 'https://api.github.com/users/michaelshekasta/repos',
#    'events_url': 'https://api.github.com/users/michaelshekasta/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/michaelshekasta/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2021-06-06T08:41:07Z',
#   'updated_at': '2021-06-06T11:29:45Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': 'Hi Guys,\r\n\r\nFirst of all, Thanks for your work!  I wish I could use pandas with transparentpath in read_csv function.\r\nIn short, transparentpath can contain gscfs paths and local paths.\r\nfor more information see [this example](https://towardsdatascience.com/transparentpath-a-python-package-to-manage-paths-on-google-cloud-storage-ae25a15a44d5)\r\n\r\nThanks,\r\nMichael',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41837',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41837/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41837/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41837/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/41837',
#   'id': 912620024,
#   'node_id': 'MDU6SXNzdWU5MTI2MjAwMjQ=',
#   'number': 41837,
#   'title': 'ENH: DataFrame.to_expr() method',
#   'user': {'login': 'kerrickstaley',
#    'id': 184773,
#    'node_id': 'MDQ6VXNlcjE4NDc3Mw==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/184773?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kerrickstaley',
#    'html_url': 'https://github.com/kerrickstaley',
#    'followers_url': 'https://api.github.com/users/kerrickstaley/followers',
#    'following_url': 'https://api.github.com/users/kerrickstaley/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/kerrickstaley/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/kerrickstaley/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/kerrickstaley/subscriptions',
#    'organizations_url': 'https://api.github.com/users/kerrickstaley/orgs',
#    'repos_url': 'https://api.github.com/users/kerrickstaley/repos',
#    'events_url': 'https://api.github.com/users/kerrickstaley/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/kerrickstaley/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-06-06T04:48:43Z',
#   'updated_at': '2021-06-06T04:48:43Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "#### Is your feature request related to a problem?\r\n\r\nI would like to write some unit tests for my Pandas code. I want to test that some `DataFrame` is equal to an expected value. The expected value is complicated and I would like an easy way to get the Python code to construct it. My program already computes the expected `DataFrame` value but I need a way to serialize/deserialize it for use in my test code.\r\n\r\n[Here is a StackOverflow question with more detail](https://stackoverflow.com/questions/67845199/how-can-i-get-a-repr-of-a-dataframe-that-is-a-valid-python-expression).\r\n\r\n#### Describe the solution you'd like\r\n\r\nI would like there to be a `DataFrame.to_expr()` method. It should return a `str` containing valid Python code that can be used to re-construct the `DataFrame`.\r\n\r\nTo the greatest extent possible, it should be true that `pd.testing.assert_frame_equal(df1, eval(df2.to_expr()))` throws an `AssertionError` if and only if `pd.testing.assert_frame_equal(df1, df2)` throws an `AssertionError`. I am using `assert_frame_equal` because it checks column dtypes, whereas `DataFrame.equals()` does not.\r\n\r\nConcretely, I think the return value of `.to_expr()` should be something like\r\n```\r\npandas.DataFrame({'column_1': pandas.Series([1, 2, 3], dtype='int64'), 'column_2': pandas.Series([1.0, 2.0, 3.0], dtype='float64')})\r\n```\r\n\r\nNote that on many Python objects, this `.to_expr()` method is called `__repr__()`. [The Python docs state:](https://docs.python.org/3/library/functions.html#repr)\r\n> For many types, [`__repr__`] makes an attempt to return a string that would yield an object with the same value when passed to `eval()`...\r\n\r\nHowever, `DataFrame.__repr__` is already defined to print a different representation (which **is** arguably more useful in an interactive environment).\r\n\r\n#### API breaking implications\r\n\r\nThis is a backwards-compatible change.\r\n\r\n#### Describe alternatives you've considered\r\n\r\nI've used `DataFrame.to_dict()` and `DataFrame.from_dict()` for this purpose in the past. However, this doesn't preserve the type, and so it doesn't work if you're working with an empty `DataFrame`. I also worry that `from_dict` will sometimes fail to infer the original type even for non-empty `DataFrame`s.\r\n",
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41836',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41836/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41836/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41836/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/41836',
#   'id': 912602114,
#   'node_id': 'MDU6SXNzdWU5MTI2MDIxMTQ=',
#   'number': 41836,
#   'title': '_libs.hashtable.ismember incorrect with tuples containing nan',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-06-06T04:02:39Z',
#   'updated_at': '2021-06-06T04:02:39Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': 'It looks like the equality check being done on tuples is checking NA values for identity, so separately instantiated `float("nan")` objects aren\'t considered matching.\r\n\r\n```\r\nfrom pandas.core.algorithms import isin\r\n\r\nvalues = [("a", float("nan")), ("b", 1)]\r\ncomps = [("a", float("nan"))]\r\nalt = ("a", values[0][1])\r\n\r\n>>> isin(values, comps)\r\narray([False, False])\r\n\r\n>>> isin(values, [alt])\r\narray([ True, False])\r\n```\r\n\r\n\r\ncc @realead ',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41834',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41834/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41834/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41834/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/41834',
#   'id': 912490754,
#   'node_id': 'MDU6SXNzdWU5MTI0OTA3NTQ=',
#   'number': 41834,
#   'title': 'BUG: Odd timezone offset change with old datetimes with tz_convert',
#   'user': {'login': 'rok',
#    'id': 54589,
#    'node_id': 'MDQ6VXNlcjU0NTg5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54589?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rok',
#    'html_url': 'https://github.com/rok',
#    'followers_url': 'https://api.github.com/users/rok/followers',
#    'following_url': 'https://api.github.com/users/rok/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rok/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rok/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rok/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rok/orgs',
#    'repos_url': 'https://api.github.com/users/rok/repos',
#    'events_url': 'https://api.github.com/users/rok/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rok/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-06-05T23:02:57Z',
#   'updated_at': '2021-06-05T23:02:57Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '- [x] I have checked that this issue has not already been reported.\r\n\r\n- [x] I have confirmed this bug exists on the latest version of pandas.\r\n\r\n- [ ] (optional) I have confirmed this bug exists on the master branch of pandas.\r\n\r\n---\r\n\r\n**Note**: Please read [this guide](https://matthewrocklin.com/blog/work/2018/02/28/minimal-bug-reports) detailing how to provide the necessary information for us to reproduce your bug.\r\n\r\n#### Code Sample, a copy-pastable example\r\n\r\n```python\r\nimport pandas as pd\r\n[\r\n    pd.to_datetime(["1900-01-01"]).tz_localize("UTC").tz_convert("Australia/Broken_Hill"),\r\n    pd.to_datetime(["1900-01-01"]).tz_localize("UTC").tz_convert("Pacific/Marquesas"),\r\n    pd.to_datetime(["2000-01-01"]).tz_localize("UTC").tz_convert("Pacific/Marquesas"),\r\n    pd.to_datetime(["2000-01-01"]).tz_localize("UTC").tz_convert("Australia/Broken_Hill"),\r\n    pd.to_datetime(["1900-01-01"]).tz_localize("UTC").tz_convert("Etc/GMT-9"),\r\n    pd.to_datetime(["2000-01-01"]).tz_localize("UTC").tz_convert("Etc/GMT-9"),\r\n]\r\n```\r\nReturns:\r\n```\r\n[DatetimeIndex([\'1900-01-01 09:26:00+09:26\'], dtype=\'datetime64[ns, Australia/Broken_Hill]\', freq=None),\r\n DatetimeIndex([\'1899-12-31 14:42:00-09:18\'], dtype=\'datetime64[ns, Pacific/Marquesas]\', freq=None),\r\n DatetimeIndex([\'1999-12-31 14:30:00-09:30\'], dtype=\'datetime64[ns, Pacific/Marquesas]\', freq=None),\r\n DatetimeIndex([\'2000-01-01 10:30:00+10:30\'], dtype=\'datetime64[ns, Australia/Broken_Hill]\', freq=None),\r\n DatetimeIndex([\'1900-01-01 09:00:00+09:00\'], dtype=\'datetime64[ns, Etc/GMT-9]\', freq=None),\r\n DatetimeIndex([\'2000-01-01 09:00:00+09:00\'], dtype=\'datetime64[ns, Etc/GMT-9]\', freq=None)]\r\n```\r\n\r\n#### Problem description\r\n\r\nTimezone offset seems to change when it shouldn\'t? I\'m not 100% this is not the correct behavior but it seems odd.\r\nI hope this is known behavior and not something esoteric.\r\n\r\n#### Expected Output\r\n\r\nProbably this:\r\n```\r\n[DatetimeIndex([\'1900-01-01 10:30:00+10:30\'], dtype=\'datetime64[ns, Australia/Broken_Hill]\', freq=None),\r\n DatetimeIndex([\'1899-12-31 14:30:00-09:30\'], dtype=\'datetime64[ns, Pacific/Marquesas]\', freq=None),\r\n DatetimeIndex([\'1999-12-31 14:30:00-09:30\'], dtype=\'datetime64[ns, Pacific/Marquesas]\', freq=None),\r\n DatetimeIndex([\'2000-01-01 10:30:00+10:30\'], dtype=\'datetime64[ns, Australia/Broken_Hill]\', freq=None),\r\n DatetimeIndex([\'1900-01-01 09:00:00+09:00\'], dtype=\'datetime64[ns, Etc/GMT-9]\', freq=None),\r\n DatetimeIndex([\'2000-01-01 09:00:00+09:00\'], dtype=\'datetime64[ns, Etc/GMT-9]\', freq=None)]\r\n```\r\n\r\nI\'m not sure these timezones even existed then so this might be an invalid calculation.\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 2cb96529396d93b46abab7bbc73a208e708c642e\r\npython           : 3.7.0.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 5.4.0-73-lowlatency\r\nVersion          : #82-Ubuntu SMP PREEMPT Wed Apr 14 19:19:50 UTC 2021\r\nmachine          : x86_64\r\nprocessor        : x86_64\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 1.2.4\r\nnumpy            : 1.19.1\r\npytz             : 2020.5\r\ndateutil         : 2.8.1\r\npip              : 20.2.3\r\nsetuptools       : 50.3.0.post20201006\r\nCython           : None\r\npytest           : 6.2.1\r\nhypothesis       : None\r\nsphinx           : 2.4.4\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : 4.6.2\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : 2.8.6 (dt dec pq3 ext lo64)\r\njinja2           : 2.11.2\r\nIPython          : 7.18.1\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nfsspec          ...
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41833',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41833/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41833/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41833/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/41833',
#   'id': 912417260,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NjYyNTc3ODA5',
#   'number': 41833,
#   'title': 'REF: de-duplicate symmetric_difference, _union',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-06-05T19:53:54Z',
#   'updated_at': '2021-06-05T19:53:54Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/41833',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/41833',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/41833.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/41833.patch'},
#   'body': 'Also fixes buglet in CategoricalIndex.equals(MultiIndex)',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41832',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41832/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41832/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41832/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/41832',
#   'id': 912416299,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NjYyNTc2OTYy',
#   'number': 41832,
#   'title': 'REF: de-duplicate IntervalIndex setops',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-06-05T19:51:30Z',
#   'updated_at': '2021-06-05T19:51:30Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/41832',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/41832',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/41832.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/41832.patch'},
#   'body': "I expect we'll be able to get rid of the last ones once #41831 is fixed",
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41831',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41831/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41831/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41831/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/41831',
#   'id': 912406932,
#   'node_id': 'MDU6SXNzdWU5MTI0MDY5MzI=',
#   'number': 41831,
#   'title': 'BUG: IntervalIndex([np.nan, np.nan]).is_monotonic returns True',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-06-05T19:24:41Z',
#   'updated_at': '2021-06-05T19:24:41Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': "I'm pretty sure this is related to other questionable behavior:\r\n\r\n```\r\nindex = pd.IntervalIndex([np.nan, np.nan])\r\nother = pd.IntervalIndex([np.nan])\r\n\r\nIn [4]: index.is_monotonic  # should be False\r\nOut[4]: True\r\n\r\nIn [5]: index._index_as_unique  # should be False\r\nOut[5]: True\r\n\r\nIn [6]: index.get_indexer_for(other)  # shouldn't raise\r\nInvalidIndexError: Reindexing only valid with uniquely valued Index objects\r\n```",
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41830',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41830/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41830/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41830/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/41830',
#   'id': 912393075,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NjYyNTU1OTMy',
#   'number': 41830,
#   'title': 'TYP: datetimelike',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-06-05T18:50:56Z',
#   'updated_at': '2021-06-05T19:31:48Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/41830',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/41830',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/41830.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/41830.patch'},
#   'body': '- [ ] closes #xxxx\r\n- [ ] tests added / passed\r\n- [ ] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing.html#code-standards) for how to run them\r\n- [ ] whatsnew entry\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41829',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41829/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41829/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41829/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/41829',
#   'id': 912363631,
#   'node_id': 'MDU6SXNzdWU5MTIzNjM2MzE=',
#   'number': 41829,
#   'title': 'CI: Re-enable Circle CI',
#   'user': {'login': 'lithomas1',
#    'id': 47963215,
#    'node_id': 'MDQ6VXNlcjQ3OTYzMjE1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47963215?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lithomas1',
#    'html_url': 'https://github.com/lithomas1',
#    'followers_url': 'https://api.github.com/users/lithomas1/followers',
#    'following_url': 'https://api.github.com/users/lithomas1/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lithomas1/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lithomas1/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lithomas1/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lithomas1/orgs',
#    'repos_url': 'https://api.github.com/users/lithomas1/repos',
#    'events_url': 'https://api.github.com/users/lithomas1/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lithomas1/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 48070600,
#     'node_id': 'MDU6TGFiZWw0ODA3MDYwMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI',
#     'name': 'CI',
#     'color': 'a2bca7',
#     'default': False,
#     'description': 'Related to Continuous Integration'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-06-05T17:38:50Z',
#   'updated_at': '2021-06-05T17:41:45Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': 'I contacted CircleCI to check if they could be interested in sponsoring our ARM builds. Will update if I hear from them. For now looks like we\'re getting the 2,500 credits that @lithomas1 mentioned (not the 400,000 for open source projects for Linux builds). So, not much we can do with those.\r\n\r\nI updated this PR so we don\'t add the CircleCI build, but still, it has everything else so the build passes when it can be added wherever. Only thing is that we now need to disable Circle CI, so the build doesn\'t fail after we remove the configuration. But only an admin of the pandas-dev organization can do it. @jreback do you mind going to https://app.circleci.com/settings/project/github/pandas-dev/pandas?return-to=https%3A%2F%2Fapp.circleci.com%2Fpipelines%2Fgithub%2Fpandas-dev%2Fpandas%2F30%2Fworkflows%2Ff9a6db17-510a-4eaf-a10c-b3a800e0a6c4%2Fjobs%2F30872 and clickig on "Stop builds" please?\r\n\r\n_Originally posted by @datapythonista in https://github.com/pandas-dev/pandas/issues/41739#issuecomment-852446796_\r\n\r\nWe should re-enable Circle CI if we receive the Circle CI credits. \r\ncc @datapythonista for updates on this',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41828',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41828/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41828/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41828/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/41828',
#   'id': 912347856,
#   'node_id': 'MDU6SXNzdWU5MTIzNDc4NTY=',
#   'number': 41828,
#   'title': 'ENH: retain attrs when concat dataframes',
#   'user': {'login': 'xiki-tempula',
#    'id': 6242032,
#    'node_id': 'MDQ6VXNlcjYyNDIwMzI=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6242032?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/xiki-tempula',
#    'html_url': 'https://github.com/xiki-tempula',
#    'followers_url': 'https://api.github.com/users/xiki-tempula/followers',
#    'following_url': 'https://api.github.com/users/xiki-tempula/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/xiki-tempula/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/xiki-tempula/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/xiki-tempula/subscriptions',
#    'organizations_url': 'https://api.github.com/users/xiki-tempula/orgs',
#    'repos_url': 'https://api.github.com/users/xiki-tempula/repos',
#    'events_url': 'https://api.github.com/users/xiki-tempula/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/xiki-tempula/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 13098779,
#     'node_id': 'MDU6TGFiZWwxMzA5ODc3OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Reshaping',
#     'name': 'Reshaping',
#     'color': '02d7e1',
#     'default': False,
#     'description': 'Concat, Merge/Join, Stack/Unstack'},
#    {'id': 1539579994,
#     'node_id': 'MDU6TGFiZWwxNTM5NTc5OTk0',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/metadata',
#     'name': 'metadata',
#     'color': '56efc9',
#     'default': False,
#     'description': '_metadata attribute'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/32',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/32',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/32/labels',
#    'id': 933188,
#    'node_id': 'MDk6TWlsZXN0b25lOTMzMTg4',
#    'number': 32,
#    'title': 'Contributions Welcome',
#    'description': 'Changes that would be nice to have in the next release. These issues are not blocking. They will be pushed to the next release if no one has time to fix them.',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 1068,
#    'closed_issues': 719,
#    'state': 'open',
#    'created_at': '2015-01-13T10:53:19Z',
#    'updated_at': '2021-06-06T04:00:29Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 3,
#   'created_at': '2021-06-05T16:59:07Z',
#   'updated_at': '2021-06-06T11:28:24Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "#### Is your feature request related to a problem?\r\n\r\nI wish the attrs could be retained when concat data frames.\r\n\r\n```\r\nd = {'col1': [1, 2], 'col2': [3, 4]}\r\ndf1 = pd.DataFrame(data=d)\r\ndf1.attrs = {1:1}\r\ndf2 = pd.DataFrame(data=d)\r\ndf2.attrs = {1:1}\r\npd.concat([df1, df2]).attrs\r\n{}\r\n```\r\n\r\n#### Describe the solution you'd like\r\n\r\n```\r\nd = {'col1': [1, 2], 'col2': [3, 4]}\r\ndf1 = pd.DataFrame(data=d)\r\ndf1.attrs = {1:1}\r\ndf2 = pd.DataFrame(data=d)\r\ndf2.attrs = {1:1}\r\npd.concat([df1, df2]).attrs\r\n{1: 1}\r\n```\r\n\r\n#### API breaking implications\r\n\r\nN/A\r\n\r\n#### Describe alternatives you've considered\r\n\r\nN/A",
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41827',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41827/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41827/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41827/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/41827',
#   'id': 912342186,
#   'node_id': 'MDU6SXNzdWU5MTIzNDIxODY=',
#   'number': 41827,
#   'title': 'BUG: DataFrame `isin` function randomly selects values (instead of using them all) when on Intel CPU and input is a torch Tensor',
#   'user': {'login': 'SamuelTrew',
#    'id': 31927714,
#    'node_id': 'MDQ6VXNlcjMxOTI3NzE0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/31927714?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/SamuelTrew',
#    'html_url': 'https://github.com/SamuelTrew',
#    'followers_url': 'https://api.github.com/users/SamuelTrew/followers',
#    'following_url': 'https://api.github.com/users/SamuelTrew/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/SamuelTrew/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/SamuelTrew/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/SamuelTrew/subscriptions',
#    'organizations_url': 'https://api.github.com/users/SamuelTrew/orgs',
#    'repos_url': 'https://api.github.com/users/SamuelTrew/repos',
#    'events_url': 'https://api.github.com/users/SamuelTrew/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/SamuelTrew/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-06-05T16:44:35Z',
#   'updated_at': '2021-06-05T16:44:35Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '- [x ] I have checked that this issue has not already been reported.\r\n\r\n- [x ] I have confirmed this bug exists on the latest version of pandas.\r\n\r\n---\r\n\r\n#### Code Sample, a copy-pastable example\r\n\r\n```python\r\nfrom typing import Tuple\r\n\r\nimport numpy as np\r\nfrom pandas import DataFrame\r\nfrom torch.tensor import Tensor\r\nfrom torchvision import transforms, datasets\r\nimport torch\r\n\r\ndef __loadMNISTData() -> Tuple[DataFrame, DataFrame]:\r\n    trans = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (1.0,))])\r\n  \r\n    # if not exist, download mnist dataset\r\n    trainSet = datasets.MNIST("data", train=True, transform=trans, download=True)\r\n    testSet = datasets.MNIST("data", train=False, transform=trans, download=True)\r\n  \r\n    # Scale pixel intensities to [-1, 1]\r\n    xTrain: Tensor = trainSet.train_data\r\n    xTrain = 2 * (xTrain.float() / 255.0) - 1\r\n    # list of 2D images to 1D pixel intensities\r\n    xTrain = xTrain.flatten(1, 2).numpy()\r\n    yTrain = trainSet.train_labels.numpy()\r\n  \r\n    # Scale pixel intensities to [-1, 1]\r\n    xtest: Tensor = testSet.test_data.clone().detach()\r\n    xtest = 2 * (xtest.float() / 255.0) - 1\r\n    # list of 2D images to 1D pixel intensities\r\n    xTest: np.ndarray = xtest.flatten(1, 2).numpy()\r\n    yTest: np.ndarray = testSet.test_labels.numpy()\r\n  \r\n    trainDataframe = DataFrame(zip(xTrain, yTrain))\r\n    testDataframe = DataFrame(zip(xTest, yTest))\r\n    trainDataframe.columns = testDataframe.columns = ["data", "labels"]\r\n\r\n    return trainDataframe, testDataframe\r\n\r\ndef _filterDataByLabel( \r\n    labels: Tensor, trainDataframe: DataFrame, testDataframe: DataFrame\r\n) -> Tuple[DataFrame, DataFrame]:\r\n    print("\\nEntering _filterDataByLabel()")\r\n    print(f"labels: {labels}")\r\n    print(f"Lengths: {len(trainDataframe)}, {len(testDataframe)}")\r\n    trainDataframe = trainDataframe[trainDataframe["labels"].isin(labels)]\r\n    testDataframe = testDataframe[testDataframe["labels"].isin(labels)]\r\n    print(f"Lengths: {len(trainDataframe)}, {len(testDataframe)}")\r\n    print(f"Unique values: {trainDataframe[\'labels\'].unique()}")\r\n    print("Exiting _filterDataByLabel()\\n")\r\n    return trainDataframe, testDataframe\r\n\r\n\r\ndata = __loadMNISTData()\r\nlabels = torch.tensor(range(10))\r\ntrainDataframe, testDataframe = self._filterDataByLabel(labels, *data)\r\n```\r\n\r\n#### Problem description\r\n\r\nSo for some reason, the labels that are passed into the `isin` function, aren\'t the same as the unique values.\r\nE.g. I\'ll put 0-9 in and get back a random amount each time even though I set the seeds for python, np, torch and cuda.\r\nIf I change labels from a Tensor into a list then this no longer happens.\r\n\r\nThe weirdest part is that this doesn\'t happen on my AMD Ryzen 5600x but it does happen on 6th and 8th gen Intel i7 laptop CPUs.\r\n\r\n#### Expected Output\r\n\r\nThe unique values should always be the same as the labels going in even if it\'s a tensor and no matter what CPU is used.\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\nThese are the details from my laptop containing the 8th gen i7 cpu\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 2cb96529396d93b46abab7bbc73a208e708c642e\r\npython           : 3.8.8.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 5.11.0-17-generic\r\nVersion          : #18-Ubuntu SMP Thu May 6 20:10:11 UTC 2021\r\nmachine          : x86_64\r\nprocessor        : x86_64\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_GB.UTF-8\r\nLOCALE           : en_GB.UTF-8\r\npandas           : 1.2.4\r\nnumpy            : 1.19.4\r\npytz             : 2021.1\r\ndateutil         : 2.8.1\r\npip              : 21.0.1\r\nsetuptools       : 52.0.0.post20210125\r\nCython           : 0.29.23\r\npytest           : 6.2.3\r\nhypothesis   ...
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41826',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41826/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41826/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41826/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/41826',
#   'id': 912311880,
#   'node_id': 'MDU6SXNzdWU5MTIzMTE4ODA=',
#   'number': 41826,
#   'title': 'ENH: Allow different senses of "distance" for method=nearest indexing',
#   'user': {'login': 'WardBrian',
#    'id': 31640292,
#    'node_id': 'MDQ6VXNlcjMxNjQwMjky',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/31640292?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/WardBrian',
#    'html_url': 'https://github.com/WardBrian',
#    'followers_url': 'https://api.github.com/users/WardBrian/followers',
#    'following_url': 'https://api.github.com/users/WardBrian/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/WardBrian/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/WardBrian/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/WardBrian/subscriptions',
#    'organizations_url': 'https://api.github.com/users/WardBrian/orgs',
#    'repos_url': 'https://api.github.com/users/WardBrian/repos',
#    'events_url': 'https://api.github.com/users/WardBrian/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/WardBrian/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2021-06-05T15:26:36Z',
#   'updated_at': '2021-06-05T17:37:57Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '#### Is your feature request related to a problem?\r\n\r\n`Index.get_loc` with the method keyword has been quite useful for me, but I often find myself using data (e.g. atmospheric pressure levels) where the truest sense of the word \'nearest\' is actually the closest value in log(p), not the normal number line. \r\n\r\n#### Describe the solution you\'d like\r\n\r\nMy first thought was to simply request a "log_nearest" option to the method parameter, but I think it is easier to get much more functionality essentially "for free" with a different construction:\r\n\r\nIndex.get_loc (and subsequently Index._get_nearest_indexer) could accept a parameter (Let\'s call it "pre", but I think there are certainly better options I haven\'t thought of) which is a ufunc of one variable, and apply that to the target values and left and right indexed values before calculating their distances.\r\n\r\ne.g.:\r\n\r\n\r\n```python\r\n>>> idx = pd.Index([10, 0.1, 0.01])\r\n>>> idx.get_loc(2.0, method=\'nearest\')\r\n1\r\n>>> idx.get_loc(2.0, method=\'nearest\', pre=np.log)\r\n0\r\n```\r\n\r\n#### API breaking implications\r\n\r\nThis should not affect any existing usages of the API\r\n\r\n#### Describe alternatives you\'ve considered\r\n\r\nAn alternative solution to my specific problem is to store the index in the log-space version, but this is considerably less human-readable in general.\r\n\r\n#### Additional context\r\n\r\nBesides changing the signatures and documentation, I believe this change can primarily be implemented with edits to this section of the indexing code\r\n\r\nhttps://github.com/pandas-dev/pandas/blob/2cb96529396d93b46abab7bbc73a208e708c642e/pandas/core/indexes/base.py#L3269-L3277\r\n\r\nThere may also need to be some additional code added to the higher-up functions to produce errors if this parameter is passed when method != "nearest", as I don\'t believe it makes sense in that context.\r\n\r\nIt is also worth noting that this has the potential to fail (e.g, if a point in the indexer is 0 or negative, the log function will not work). Pandas may want to trap those errors and report them differently, but a garbage-in-garbage-out disclaimer may be helpful in general',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41825',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41825/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41825/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41825/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/41825',
#   'id': 912116016,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NjYyMzEwNDI2',
#   'number': 41825,
#   'title': 'REF: share wrapping in MultiIndex setops',
#   'user': {'login': 'jbrockmendel',
# ...
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2021-06-03T07:33:43Z',
#   'updated_at': '2021-06-03T12:44:44Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '- [x] I have checked that this issue has not already been reported.\r\n\r\n- [x] I have confirmed this bug exists on the latest version of pandas.\r\n\r\n- [ ] (optional) I have confirmed this bug exists on the master branch of pandas.\r\n\r\n---\r\n\r\n#### Code Sample, a copy-pastable example\r\n\r\n```python\r\nimport pandas as pd\r\ntest_time = pd.to_datetime(\'2020-06-09 00:01:14.500000\')\r\nprint(pd.Series(test_time).dt.round("S"))\r\n```\r\n\r\n#### Problem description\r\n\r\nIf the ms is 5e5, the method of round is floor, but it should be ceil.\r\n\r\n#### Expected Output\r\n```\r\n2020-06-09 00:01:15\r\n```\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 2cb96529396d93b46abab7bbc73a208e708c642e\r\npython           : 3.8.8.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 3.10.0-957.el7.x86_64\r\nVersion          : #1 SMP Thu Nov 8 23:39:32 UTC 2018\r\nmachine          : x86_64\r\nprocessor        : x86_64\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 1.2.4\r\nnumpy            : 1.20.2\r\npytz             : 2021.1\r\ndateutil         : 2.8.1\r\npip              : 21.1.1\r\nsetuptools       : 49.6.0.post20210108\r\nCython           : None\r\npytest           : 6.2.4\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 2.11.3\r\nIPython          : 7.23.1\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nfsspec           : 2021.04.0\r\nfastparquet      : None\r\ngcsfs            : None\r\nmatplotlib       : 3.3.4\r\nnumexpr          : 2.7.3\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.6.3\r\nsqlalchemy       : None\r\ntables           : 3.6.1\r\ntabulate         : None\r\nxarray           : 0.18.0\r\nxlrd             : None\r\nxlwt             : None\r\nnumba            : None\r\n</details>\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41792',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41792/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41792/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41792/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/41792',
#   'id': 909986934,
#   'node_id': 'MDU6SXNzdWU5MDk5ODY5MzQ=',
#   'number': 41792,
#   'title': "BUG: Broken bool supports in pandas' quantile by NumPy's percentile behaviour change",
#   'user': {'login': 'HyukjinKwon',
#    'id': 6477701,
#    'node_id': 'MDQ6VXNlcjY0Nzc3MDE=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6477701?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/HyukjinKwon',
#    'html_url': 'https://github.com/HyukjinKwon',
#    'followers_url': 'https://api.github.com/users/HyukjinKwon/followers',
#    'following_url': 'https://api.github.com/users/HyukjinKwon/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/HyukjinKwon/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/HyukjinKwon/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/HyukjinKwon/subscriptions',
#    'organizations_url': 'https://api.github.com/users/HyukjinKwon/orgs',
#    'repos_url': 'https://api.github.com/users/HyukjinKwon/repos',
#    'events_url': 'https://api.github.com/users/HyukjinKwon/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/HyukjinKwon/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-06-03T00:36:07Z',
#   'updated_at': '2021-06-03T03:53:02Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '- [x] I have checked that this issue has not already been reported.\r\n\r\n- [x] I have confirmed this bug exists on the latest version of pandas.\r\n\r\n- [ ] (optional) I have confirmed this bug exists on the master branch of pandas.\r\n\r\n---\r\n\r\n**Note**: Please read [this guide](https://matthewrocklin.com/blog/work/2018/02/28/minimal-bug-reports) detailing how to provide the necessary information for us to reproduce your bug.\r\n\r\n#### Code Sample, a copy-pastable example\r\n\r\n```python\r\nimport pandas as pd\r\npd.DataFrame({"i": [0, 1, 2], "b": [False, False, True], "s": ["x", "y", "z"]}).quantile(q=0.5, numeric_only=True)\r\n```\r\n\r\n#### Problem description\r\n\r\nhttps://github.com/numpy/numpy/pull/16273#discussion_r641264085  broke the case of NumPy\'s `percentile` with bools which causes to break pandas pandas\' `quantile` too. If this is considered as not a bug, I would expect pandas to handle it with `numeric_only`. Cross filed issue in NumPy: https://github.com/numpy/numpy/issues/19154\r\n\r\nCurrently it throws an exception as below:\r\n\r\n```\r\nTraceback (most recent call last):\r\n  File "<stdin>", line 1, in <module>\r\n  File "/.../python3.8/site-packages/pandas/core/frame.py", line 9266, in quantile\r\n    result = data._mgr.quantile(\r\n  File "/.../python3.8/site-packages/pandas/core/internals/managers.py", line 491, in quantile\r\n    block = b.quantile(axis=axis, qs=qs, interpolation=interpolation)\r\n  File "/.../python3.8/site-packages/pandas/core/internals/blocks.py", line 1592, in quantile\r\n    result = nanpercentile(\r\n  File "/.../python3.8/site-packages/pandas/core/nanops.py", line 1675, in nanpercentile\r\n    return np.percentile(values, q, axis=axis, interpolation=interpolation)\r\n  File "<__array_function__ internals>", line 5, in percentile\r\n  File "/.../python3.8/site-packages/numpy/lib/function_base.py", line 3818, in percentile\r\n    return _quantile_unchecked(\r\n  File "/.../python3.8/site-packages/numpy/lib/function_base.py", line 3937, in _quantile_unchecked\r\n    r, k = _ureduce(a, func=_quantile_ureduce_func, q=q, axis=axis, out=out,\r\n  File "/.../python3.8/site-packages/numpy/lib/function_base.py", line 3515, in _ureduce\r\n    r = func(a, **kwargs)\r\n  File "/.../python3.8/site-packages/numpy/lib/function_base.py", line 4064, in _quantile_ureduce_func\r\n    r = _lerp(x_below, x_above, weights_above, out=out)\r\n  File "/.../python3.8/site-packages/numpy/lib/function_base.py", line 3961, in _lerp\r\n    diff_b_a = subtract(b, a)\r\nTypeError: numpy boolean subtract, the `-` operator, is not supported, use the bitwise_xor, the `^` operator, or the logical_xor function instead.\r\n```\r\n\r\n#### Expected Output\r\n\r\n```\r\ni    1.0\r\nb    0.0\r\nName: 0.5, dtype: float64\r\n```\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\n\r\n```\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 2cb96529396d93b46abab7bbc73a208e708c642e\r\npython           : 3.8.8.final.0\r\npython-bits      : 64\r\nOS               : Darwin\r\nOS-release       : 20.4.0\r\nVersion          : Darwin Kernel Version 20.4.0: Thu Apr 22 21:46:47 PDT 2021; root:xnu-7195.101.2~1/RELEASE_X86_64\r\nmachine          : x86_64\r\nprocessor        : i386\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 1.2.4\r\nnumpy            : 1.20.3\r\npytz             : 2021.1\r\ndateutil         : 2.8.1\r\npip              : 21.0.1\r\nsetuptools       : 52.0.0.post20210125\r\nCython           : None\r\npytest           : 6.2.4\r\nhypothesis       : None\r\nsphinx           : 3.0.4\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 2.11.3\r\nIPython          : 7.23.1\r\npandas_datareader: None\r\nbs4             ...
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41788',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41788/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41788/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41788/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/41788',
#   'id': 909859476,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NjYwMzcxMzcw',
#   'number': 41788,
#   'title': 'BLD: Adjust Numpy Minimum Versions for aarch64/arm64 compatibility',
#   'user': {'login': 'lithomas1',
#    'id': 47963215,
#    'node_id': 'MDQ6VXNlcjQ3OTYzMjE1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47963215?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lithomas1',
#    'html_url': 'https://github.com/lithomas1',
#    'followers_url': 'https://api.github.com/users/lithomas1/followers',
#    'following_url': 'https://api.github.com/users/lithomas1/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lithomas1/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lithomas1/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lithomas1/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lithomas1/orgs',
#    'repos_url': 'https://api.github.com/users/lithomas1/repos',
#    'events_url': 'https://api.github.com/users/lithomas1/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lithomas1/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 2628846204,
#     'node_id': 'MDU6TGFiZWwyNjI4ODQ2MjA0',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/ARM',
#     'name': 'ARM',
#     'color': 'c2e0c6',
#     'default': False,
#     'description': 'aarch64 architecture'},
#    {'id': 129350,
#     'node_id': 'MDU6TGFiZWwxMjkzNTA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Build',
#     'name': 'Build',
#     'color': '75507B',
#     'default': False,
#     'description': 'Library building on various platforms'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-06-02T20:29:46Z',
#   'updated_at': '2021-06-05T17:46:07Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/41788',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/41788',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/41788.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/41788.patch'},
#   'body': '- [ ] closes #xxxx\r\n- [ ] tests added / passed\r\n- [ ] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing.html#code-standards) for how to run them\r\n- [ ] whatsnew entry\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41787',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41787/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41787/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41787/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/41787',
#   'id': 909654771,
#   'node_id': 'MDU6SXNzdWU5MDk2NTQ3NzE=',
#   'number': 41787,
#   'title': 'QST: Apple M1, arm64',
#   'user': {'login': 'beaverden',
#    'id': 10908270,
#    'node_id': 'MDQ6VXNlcjEwOTA4Mjcw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10908270?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/beaverden',
#    'html_url': 'https://github.com/beaverden',
#    'followers_url': 'https://api.github.com/users/beaverden/followers',
#    'following_url': 'https://api.github.com/users/beaverden/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/beaverden/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/beaverden/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/beaverden/subscriptions',
#    'organizations_url': 'https://api.github.com/users/beaverden/orgs',
#    'repos_url': 'https://api.github.com/users/beaverden/repos',
#    'events_url': 'https://api.github.com/users/beaverden/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/beaverden/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 2628846204,
#     'node_id': 'MDU6TGFiZWwyNjI4ODQ2MjA0',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/ARM',
#     'name': 'ARM',
#     'color': 'c2e0c6',
#     'default': False,
#     'description': 'aarch64 architecture'},
#    {'id': 129350,
#     'node_id': 'MDU6TGFiZWwxMjkzNTA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Build',
#     'name': 'Build',
#     'color': '75507B',
#     'default': False,
#     'description': 'Library building on various platforms'},
#    {'id': 34444536,
#     'node_id': 'MDU6TGFiZWwzNDQ0NDUzNg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Usage%20Question',
#     'name': 'Usage Question',
#     'color': '0052cc',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2021-06-02T16:01:23Z',
#   'updated_at': '2021-06-02T19:47:32Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "- [X] I have searched the [[pandas] tag](https://stackoverflow.com/questions/tagged/pandas) on StackOverflow for similar questions.\r\n\r\n- [X] I have asked my usage related question on [StackOverflow](https://stackoverflow.com).\r\n\r\n---\r\n\r\nWhat is the current state of amd64 compilation? Docker pip installation takes ages and I'm having trouble installing it on my macos with apple m1 chip.\r\n\r\nIs there anything I can do to help provide precompiled binaries for release on this platform?\r\n",
#   'performed_via_github_app': None}]

# %%
js[0]['title']
# Out:
# 'ENH: Using transparentpath in read_csv'

# %%
for i in range(len(js)):
    print(js[i]['title'])
# Out:
# ENH: Using transparentpath in read_csv
# ENH: DataFrame.to_expr() method
# _libs.hashtable.ismember incorrect with tuples containing nan
# BUG: Odd timezone offset change with old datetimes with tz_convert
# REF: de-duplicate symmetric_difference, _union
# REF: de-duplicate IntervalIndex setops
# BUG: IntervalIndex([np.nan, np.nan]).is_monotonic returns True
# TYP: datetimelike
# CI: Re-enable Circle CI
# ENH: retain attrs when concat dataframes
# BUG: DataFrame `isin` function randomly selects values (instead of using them all) when on Intel CPU and input is a torch Tensor
# ENH: Allow different senses of "distance" for method=nearest indexing
# REF: share wrapping in MultiIndex setops
# REF: de-duplicate Index._intersection + MultiIndex._intersection
# BUG: MultiIndex.unique incorrect when NA value is present
# DOC: Whatsnew1.3 grammar
# BUG: wrong exception when slicing on TimedeltaIndex
# BUG: read_csv does not read double double quotes in pipe delimited txt file
# DOC/BLD: update README.md, list setuptools as dependency
# BUG: pd.util.hash_array fails on DatetimeIndex with tz specified
# DEPS: clarifying setuptools's status as a dependency
# Axis behaviour not consistent for df.interpolate for pad with `limit_area` passed.
# TYP: Numpy compatibility of definition of "array like"
# BUG:
# BUG: combine_first fails when one series is timezone-aware and the other is emtpy.
# BUG: undocumented astype("category").astype(str) type inconsistency between pandas 1.1 & 1.2
# BUG: `round()` for 5e5 ms should be `ceil()`
# BUG: Broken bool supports in pandas' quantile by NumPy's percentile behaviour change
# BLD: Adjust Numpy Minimum Versions for aarch64/arm64 compatibility
# QST: Apple M1, arm64

# %%
len(js)
# Out:
# 30

# %%
js
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41838',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41838/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41838/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41838/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/41838',
#   'id': 912722673,
#   'node_id': 'MDU6SXNzdWU5MTI3MjI2NzM=',
#   'number': 41838,
#   'title': 'ENH: Using transparentpath in read_csv',
#   'user': {'login': 'michaelshekasta',
#    'id': 41590425,
#    'node_id': 'MDQ6VXNlcjQxNTkwNDI1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41590425?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/michaelshekasta',
#    'html_url': 'https://github.com/michaelshekasta',
#    'followers_url': 'https://api.github.com/users/michaelshekasta/followers',
#    'following_url': 'https://api.github.com/users/michaelshekasta/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/michaelshekasta/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/michaelshekasta/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/michaelshekasta/subscriptions',
#    'organizations_url': 'https://api.github.com/users/michaelshekasta/orgs',
#    'repos_url': 'https://api.github.com/users/michaelshekasta/repos',
#    'events_url': 'https://api.github.com/users/michaelshekasta/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/michaelshekasta/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2021-06-06T08:41:07Z',
#   'updated_at': '2021-06-06T11:29:45Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': 'Hi Guys,\r\n\r\nFirst of all, Thanks for your work!  I wish I could use pandas with transparentpath in read_csv function.\r\nIn short, transparentpath can contain gscfs paths and local paths.\r\nfor more information see [this example](https://towardsdatascience.com/transparentpath-a-python-package-to-manage-paths-on-google-cloud-storage-ae25a15a44d5)\r\n\r\nThanks,\r\nMichael',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41837',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41837/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41837/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41837/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/41837',
#   'id': 912620024,
#   'node_id': 'MDU6SXNzdWU5MTI2MjAwMjQ=',
#   'number': 41837,
#   'title': 'ENH: DataFrame.to_expr() method',
#   'user': {'login': 'kerrickstaley',
#    'id': 184773,
#    'node_id': 'MDQ6VXNlcjE4NDc3Mw==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/184773?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kerrickstaley',
#    'html_url': 'https://github.com/kerrickstaley',
#    'followers_url': 'https://api.github.com/users/kerrickstaley/followers',
#    'following_url': 'https://api.github.com/users/kerrickstaley/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/kerrickstaley/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/kerrickstaley/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/kerrickstaley/subscriptions',
#    'organizations_url': 'https://api.github.com/users/kerrickstaley/orgs',
#    'repos_url': 'https://api.github.com/users/kerrickstaley/repos',
#    'events_url': 'https://api.github.com/users/kerrickstaley/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/kerrickstaley/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-06-06T04:48:43Z',
#   'updated_at': '2021-06-06T04:48:43Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "#### Is your feature request related to a problem?\r\n\r\nI would like to write some unit tests for my Pandas code. I want to test that some `DataFrame` is equal to an expected value. The expected value is complicated and I would like an easy way to get the Python code to construct it. My program already computes the expected `DataFrame` value but I need a way to serialize/deserialize it for use in my test code.\r\n\r\n[Here is a StackOverflow question with more detail](https://stackoverflow.com/questions/67845199/how-can-i-get-a-repr-of-a-dataframe-that-is-a-valid-python-expression).\r\n\r\n#### Describe the solution you'd like\r\n\r\nI would like there to be a `DataFrame.to_expr()` method. It should return a `str` containing valid Python code that can be used to re-construct the `DataFrame`.\r\n\r\nTo the greatest extent possible, it should be true that `pd.testing.assert_frame_equal(df1, eval(df2.to_expr()))` throws an `AssertionError` if and only if `pd.testing.assert_frame_equal(df1, df2)` throws an `AssertionError`. I am using `assert_frame_equal` because it checks column dtypes, whereas `DataFrame.equals()` does not.\r\n\r\nConcretely, I think the return value of `.to_expr()` should be something like\r\n```\r\npandas.DataFrame({'column_1': pandas.Series([1, 2, 3], dtype='int64'), 'column_2': pandas.Series([1.0, 2.0, 3.0], dtype='float64')})\r\n```\r\n\r\nNote that on many Python objects, this `.to_expr()` method is called `__repr__()`. [The Python docs state:](https://docs.python.org/3/library/functions.html#repr)\r\n> For many types, [`__repr__`] makes an attempt to return a string that would yield an object with the same value when passed to `eval()`...\r\n\r\nHowever, `DataFrame.__repr__` is already defined to print a different representation (which **is** arguably more useful in an interactive environment).\r\n\r\n#### API breaking implications\r\n\r\nThis is a backwards-compatible change.\r\n\r\n#### Describe alternatives you've considered\r\n\r\nI've used `DataFrame.to_dict()` and `DataFrame.from_dict()` for this purpose in the past. However, this doesn't preserve the type, and so it doesn't work if you're working with an empty `DataFrame`. I also worry that `from_dict` will sometimes fail to infer the original type even for non-empty `DataFrame`s.\r\n",
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41836',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41836/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41836/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41836/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/41836',
#   'id': 912602114,
#   'node_id': 'MDU6SXNzdWU5MTI2MDIxMTQ=',
#   'number': 41836,
#   'title': '_libs.hashtable.ismember incorrect with tuples containing nan',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-06-06T04:02:39Z',
#   'updated_at': '2021-06-06T04:02:39Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': 'It looks like the equality check being done on tuples is checking NA values for identity, so separately instantiated `float("nan")` objects aren\'t considered matching.\r\n\r\n```\r\nfrom pandas.core.algorithms import isin\r\n\r\nvalues = [("a", float("nan")), ("b", 1)]\r\ncomps = [("a", float("nan"))]\r\nalt = ("a", values[0][1])\r\n\r\n>>> isin(values, comps)\r\narray([False, False])\r\n\r\n>>> isin(values, [alt])\r\narray([ True, False])\r\n```\r\n\r\n\r\ncc @realead ',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41834',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41834/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41834/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41834/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/41834',
#   'id': 912490754,
#   'node_id': 'MDU6SXNzdWU5MTI0OTA3NTQ=',
#   'number': 41834,
#   'title': 'BUG: Odd timezone offset change with old datetimes with tz_convert',
#   'user': {'login': 'rok',
#    'id': 54589,
#    'node_id': 'MDQ6VXNlcjU0NTg5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54589?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rok',
#    'html_url': 'https://github.com/rok',
#    'followers_url': 'https://api.github.com/users/rok/followers',
#    'following_url': 'https://api.github.com/users/rok/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rok/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rok/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rok/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rok/orgs',
#    'repos_url': 'https://api.github.com/users/rok/repos',
#    'events_url': 'https://api.github.com/users/rok/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rok/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-06-05T23:02:57Z',
#   'updated_at': '2021-06-05T23:02:57Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '- [x] I have checked that this issue has not already been reported.\r\n\r\n- [x] I have confirmed this bug exists on the latest version of pandas.\r\n\r\n- [ ] (optional) I have confirmed this bug exists on the master branch of pandas.\r\n\r\n---\r\n\r\n**Note**: Please read [this guide](https://matthewrocklin.com/blog/work/2018/02/28/minimal-bug-reports) detailing how to provide the necessary information for us to reproduce your bug.\r\n\r\n#### Code Sample, a copy-pastable example\r\n\r\n```python\r\nimport pandas as pd\r\n[\r\n    pd.to_datetime(["1900-01-01"]).tz_localize("UTC").tz_convert("Australia/Broken_Hill"),\r\n    pd.to_datetime(["1900-01-01"]).tz_localize("UTC").tz_convert("Pacific/Marquesas"),\r\n    pd.to_datetime(["2000-01-01"]).tz_localize("UTC").tz_convert("Pacific/Marquesas"),\r\n    pd.to_datetime(["2000-01-01"]).tz_localize("UTC").tz_convert("Australia/Broken_Hill"),\r\n    pd.to_datetime(["1900-01-01"]).tz_localize("UTC").tz_convert("Etc/GMT-9"),\r\n    pd.to_datetime(["2000-01-01"]).tz_localize("UTC").tz_convert("Etc/GMT-9"),\r\n]\r\n```\r\nReturns:\r\n```\r\n[DatetimeIndex([\'1900-01-01 09:26:00+09:26\'], dtype=\'datetime64[ns, Australia/Broken_Hill]\', freq=None),\r\n DatetimeIndex([\'1899-12-31 14:42:00-09:18\'], dtype=\'datetime64[ns, Pacific/Marquesas]\', freq=None),\r\n DatetimeIndex([\'1999-12-31 14:30:00-09:30\'], dtype=\'datetime64[ns, Pacific/Marquesas]\', freq=None),\r\n DatetimeIndex([\'2000-01-01 10:30:00+10:30\'], dtype=\'datetime64[ns, Australia/Broken_Hill]\', freq=None),\r\n DatetimeIndex([\'1900-01-01 09:00:00+09:00\'], dtype=\'datetime64[ns, Etc/GMT-9]\', freq=None),\r\n DatetimeIndex([\'2000-01-01 09:00:00+09:00\'], dtype=\'datetime64[ns, Etc/GMT-9]\', freq=None)]\r\n```\r\n\r\n#### Problem description\r\n\r\nTimezone offset seems to change when it shouldn\'t? I\'m not 100% this is not the correct behavior but it seems odd.\r\nI hope this is known behavior and not something esoteric.\r\n\r\n#### Expected Output\r\n\r\nProbably this:\r\n```\r\n[DatetimeIndex([\'1900-01-01 10:30:00+10:30\'], dtype=\'datetime64[ns, Australia/Broken_Hill]\', freq=None),\r\n DatetimeIndex([\'1899-12-31 14:30:00-09:30\'], dtype=\'datetime64[ns, Pacific/Marquesas]\', freq=None),\r\n DatetimeIndex([\'1999-12-31 14:30:00-09:30\'], dtype=\'datetime64[ns, Pacific/Marquesas]\', freq=None),\r\n DatetimeIndex([\'2000-01-01 10:30:00+10:30\'], dtype=\'datetime64[ns, Australia/Broken_Hill]\', freq=None),\r\n DatetimeIndex([\'1900-01-01 09:00:00+09:00\'], dtype=\'datetime64[ns, Etc/GMT-9]\', freq=None),\r\n DatetimeIndex([\'2000-01-01 09:00:00+09:00\'], dtype=\'datetime64[ns, Etc/GMT-9]\', freq=None)]\r\n```\r\n\r\nI\'m not sure these timezones even existed then so this might be an invalid calculation.\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 2cb96529396d93b46abab7bbc73a208e708c642e\r\npython           : 3.7.0.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 5.4.0-73-lowlatency\r\nVersion          : #82-Ubuntu SMP PREEMPT Wed Apr 14 19:19:50 UTC 2021\r\nmachine          : x86_64\r\nprocessor        : x86_64\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 1.2.4\r\nnumpy            : 1.19.1\r\npytz             : 2020.5\r\ndateutil         : 2.8.1\r\npip              : 20.2.3\r\nsetuptools       : 50.3.0.post20201006\r\nCython           : None\r\npytest           : 6.2.1\r\nhypothesis       : None\r\nsphinx           : 2.4.4\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : 4.6.2\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : 2.8.6 (dt dec pq3 ext lo64)\r\njinja2           : 2.11.2\r\nIPython          : 7.18.1\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nfsspec          ...
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41833',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41833/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41833/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41833/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/41833',
#   'id': 912417260,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NjYyNTc3ODA5',
#   'number': 41833,
#   'title': 'REF: de-duplicate symmetric_difference, _union',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-06-05T19:53:54Z',
#   'updated_at': '2021-06-05T19:53:54Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/41833',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/41833',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/41833.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/41833.patch'},
#   'body': 'Also fixes buglet in CategoricalIndex.equals(MultiIndex)',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41832',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41832/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41832/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41832/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/41832',
#   'id': 912416299,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NjYyNTc2OTYy',
#   'number': 41832,
#   'title': 'REF: de-duplicate IntervalIndex setops',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-06-05T19:51:30Z',
#   'updated_at': '2021-06-05T19:51:30Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/41832',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/41832',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/41832.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/41832.patch'},
#   'body': "I expect we'll be able to get rid of the last ones once #41831 is fixed",
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41831',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41831/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41831/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41831/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/41831',
#   'id': 912406932,
#   'node_id': 'MDU6SXNzdWU5MTI0MDY5MzI=',
#   'number': 41831,
#   'title': 'BUG: IntervalIndex([np.nan, np.nan]).is_monotonic returns True',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-06-05T19:24:41Z',
#   'updated_at': '2021-06-05T19:24:41Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': "I'm pretty sure this is related to other questionable behavior:\r\n\r\n```\r\nindex = pd.IntervalIndex([np.nan, np.nan])\r\nother = pd.IntervalIndex([np.nan])\r\n\r\nIn [4]: index.is_monotonic  # should be False\r\nOut[4]: True\r\n\r\nIn [5]: index._index_as_unique  # should be False\r\nOut[5]: True\r\n\r\nIn [6]: index.get_indexer_for(other)  # shouldn't raise\r\nInvalidIndexError: Reindexing only valid with uniquely valued Index objects\r\n```",
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41830',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41830/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41830/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41830/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/41830',
#   'id': 912393075,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NjYyNTU1OTMy',
#   'number': 41830,
#   'title': 'TYP: datetimelike',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-06-05T18:50:56Z',
#   'updated_at': '2021-06-05T19:31:48Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/41830',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/41830',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/41830.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/41830.patch'},
#   'body': '- [ ] closes #xxxx\r\n- [ ] tests added / passed\r\n- [ ] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing.html#code-standards) for how to run them\r\n- [ ] whatsnew entry\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41829',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41829/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41829/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41829/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/41829',
#   'id': 912363631,
#   'node_id': 'MDU6SXNzdWU5MTIzNjM2MzE=',
#   'number': 41829,
#   'title': 'CI: Re-enable Circle CI',
#   'user': {'login': 'lithomas1',
#    'id': 47963215,
#    'node_id': 'MDQ6VXNlcjQ3OTYzMjE1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47963215?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lithomas1',
#    'html_url': 'https://github.com/lithomas1',
#    'followers_url': 'https://api.github.com/users/lithomas1/followers',
#    'following_url': 'https://api.github.com/users/lithomas1/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lithomas1/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lithomas1/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lithomas1/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lithomas1/orgs',
#    'repos_url': 'https://api.github.com/users/lithomas1/repos',
#    'events_url': 'https://api.github.com/users/lithomas1/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lithomas1/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 48070600,
#     'node_id': 'MDU6TGFiZWw0ODA3MDYwMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI',
#     'name': 'CI',
#     'color': 'a2bca7',
#     'default': False,
#     'description': 'Related to Continuous Integration'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-06-05T17:38:50Z',
#   'updated_at': '2021-06-05T17:41:45Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': 'I contacted CircleCI to check if they could be interested in sponsoring our ARM builds. Will update if I hear from them. For now looks like we\'re getting the 2,500 credits that @lithomas1 mentioned (not the 400,000 for open source projects for Linux builds). So, not much we can do with those.\r\n\r\nI updated this PR so we don\'t add the CircleCI build, but still, it has everything else so the build passes when it can be added wherever. Only thing is that we now need to disable Circle CI, so the build doesn\'t fail after we remove the configuration. But only an admin of the pandas-dev organization can do it. @jreback do you mind going to https://app.circleci.com/settings/project/github/pandas-dev/pandas?return-to=https%3A%2F%2Fapp.circleci.com%2Fpipelines%2Fgithub%2Fpandas-dev%2Fpandas%2F30%2Fworkflows%2Ff9a6db17-510a-4eaf-a10c-b3a800e0a6c4%2Fjobs%2F30872 and clickig on "Stop builds" please?\r\n\r\n_Originally posted by @datapythonista in https://github.com/pandas-dev/pandas/issues/41739#issuecomment-852446796_\r\n\r\nWe should re-enable Circle CI if we receive the Circle CI credits. \r\ncc @datapythonista for updates on this',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41828',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41828/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41828/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41828/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/41828',
#   'id': 912347856,
#   'node_id': 'MDU6SXNzdWU5MTIzNDc4NTY=',
#   'number': 41828,
#   'title': 'ENH: retain attrs when concat dataframes',
#   'user': {'login': 'xiki-tempula',
#    'id': 6242032,
#    'node_id': 'MDQ6VXNlcjYyNDIwMzI=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6242032?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/xiki-tempula',
#    'html_url': 'https://github.com/xiki-tempula',
#    'followers_url': 'https://api.github.com/users/xiki-tempula/followers',
#    'following_url': 'https://api.github.com/users/xiki-tempula/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/xiki-tempula/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/xiki-tempula/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/xiki-tempula/subscriptions',
#    'organizations_url': 'https://api.github.com/users/xiki-tempula/orgs',
#    'repos_url': 'https://api.github.com/users/xiki-tempula/repos',
#    'events_url': 'https://api.github.com/users/xiki-tempula/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/xiki-tempula/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 13098779,
#     'node_id': 'MDU6TGFiZWwxMzA5ODc3OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Reshaping',
#     'name': 'Reshaping',
#     'color': '02d7e1',
#     'default': False,
#     'description': 'Concat, Merge/Join, Stack/Unstack'},
#    {'id': 1539579994,
#     'node_id': 'MDU6TGFiZWwxNTM5NTc5OTk0',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/metadata',
#     'name': 'metadata',
#     'color': '56efc9',
#     'default': False,
#     'description': '_metadata attribute'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/32',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/32',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/32/labels',
#    'id': 933188,
#    'node_id': 'MDk6TWlsZXN0b25lOTMzMTg4',
#    'number': 32,
#    'title': 'Contributions Welcome',
#    'description': 'Changes that would be nice to have in the next release. These issues are not blocking. They will be pushed to the next release if no one has time to fix them.',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 1068,
#    'closed_issues': 719,
#    'state': 'open',
#    'created_at': '2015-01-13T10:53:19Z',
#    'updated_at': '2021-06-06T04:00:29Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 3,
#   'created_at': '2021-06-05T16:59:07Z',
#   'updated_at': '2021-06-06T11:28:24Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "#### Is your feature request related to a problem?\r\n\r\nI wish the attrs could be retained when concat data frames.\r\n\r\n```\r\nd = {'col1': [1, 2], 'col2': [3, 4]}\r\ndf1 = pd.DataFrame(data=d)\r\ndf1.attrs = {1:1}\r\ndf2 = pd.DataFrame(data=d)\r\ndf2.attrs = {1:1}\r\npd.concat([df1, df2]).attrs\r\n{}\r\n```\r\n\r\n#### Describe the solution you'd like\r\n\r\n```\r\nd = {'col1': [1, 2], 'col2': [3, 4]}\r\ndf1 = pd.DataFrame(data=d)\r\ndf1.attrs = {1:1}\r\ndf2 = pd.DataFrame(data=d)\r\ndf2.attrs = {1:1}\r\npd.concat([df1, df2]).attrs\r\n{1: 1}\r\n```\r\n\r\n#### API breaking implications\r\n\r\nN/A\r\n\r\n#### Describe alternatives you've considered\r\n\r\nN/A",
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41827',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41827/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41827/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41827/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/41827',
#   'id': 912342186,
#   'node_id': 'MDU6SXNzdWU5MTIzNDIxODY=',
#   'number': 41827,
#   'title': 'BUG: DataFrame `isin` function randomly selects values (instead of using them all) when on Intel CPU and input is a torch Tensor',
#   'user': {'login': 'SamuelTrew',
#    'id': 31927714,
#    'node_id': 'MDQ6VXNlcjMxOTI3NzE0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/31927714?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/SamuelTrew',
#    'html_url': 'https://github.com/SamuelTrew',
#    'followers_url': 'https://api.github.com/users/SamuelTrew/followers',
#    'following_url': 'https://api.github.com/users/SamuelTrew/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/SamuelTrew/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/SamuelTrew/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/SamuelTrew/subscriptions',
#    'organizations_url': 'https://api.github.com/users/SamuelTrew/orgs',
#    'repos_url': 'https://api.github.com/users/SamuelTrew/repos',
#    'events_url': 'https://api.github.com/users/SamuelTrew/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/SamuelTrew/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-06-05T16:44:35Z',
#   'updated_at': '2021-06-05T16:44:35Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '- [x ] I have checked that this issue has not already been reported.\r\n\r\n- [x ] I have confirmed this bug exists on the latest version of pandas.\r\n\r\n---\r\n\r\n#### Code Sample, a copy-pastable example\r\n\r\n```python\r\nfrom typing import Tuple\r\n\r\nimport numpy as np\r\nfrom pandas import DataFrame\r\nfrom torch.tensor import Tensor\r\nfrom torchvision import transforms, datasets\r\nimport torch\r\n\r\ndef __loadMNISTData() -> Tuple[DataFrame, DataFrame]:\r\n    trans = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (1.0,))])\r\n  \r\n    # if not exist, download mnist dataset\r\n    trainSet = datasets.MNIST("data", train=True, transform=trans, download=True)\r\n    testSet = datasets.MNIST("data", train=False, transform=trans, download=True)\r\n  \r\n    # Scale pixel intensities to [-1, 1]\r\n    xTrain: Tensor = trainSet.train_data\r\n    xTrain = 2 * (xTrain.float() / 255.0) - 1\r\n    # list of 2D images to 1D pixel intensities\r\n    xTrain = xTrain.flatten(1, 2).numpy()\r\n    yTrain = trainSet.train_labels.numpy()\r\n  \r\n    # Scale pixel intensities to [-1, 1]\r\n    xtest: Tensor = testSet.test_data.clone().detach()\r\n    xtest = 2 * (xtest.float() / 255.0) - 1\r\n    # list of 2D images to 1D pixel intensities\r\n    xTest: np.ndarray = xtest.flatten(1, 2).numpy()\r\n    yTest: np.ndarray = testSet.test_labels.numpy()\r\n  \r\n    trainDataframe = DataFrame(zip(xTrain, yTrain))\r\n    testDataframe = DataFrame(zip(xTest, yTest))\r\n    trainDataframe.columns = testDataframe.columns = ["data", "labels"]\r\n\r\n    return trainDataframe, testDataframe\r\n\r\ndef _filterDataByLabel( \r\n    labels: Tensor, trainDataframe: DataFrame, testDataframe: DataFrame\r\n) -> Tuple[DataFrame, DataFrame]:\r\n    print("\\nEntering _filterDataByLabel()")\r\n    print(f"labels: {labels}")\r\n    print(f"Lengths: {len(trainDataframe)}, {len(testDataframe)}")\r\n    trainDataframe = trainDataframe[trainDataframe["labels"].isin(labels)]\r\n    testDataframe = testDataframe[testDataframe["labels"].isin(labels)]\r\n    print(f"Lengths: {len(trainDataframe)}, {len(testDataframe)}")\r\n    print(f"Unique values: {trainDataframe[\'labels\'].unique()}")\r\n    print("Exiting _filterDataByLabel()\\n")\r\n    return trainDataframe, testDataframe\r\n\r\n\r\ndata = __loadMNISTData()\r\nlabels = torch.tensor(range(10))\r\ntrainDataframe, testDataframe = self._filterDataByLabel(labels, *data)\r\n```\r\n\r\n#### Problem description\r\n\r\nSo for some reason, the labels that are passed into the `isin` function, aren\'t the same as the unique values.\r\nE.g. I\'ll put 0-9 in and get back a random amount each time even though I set the seeds for python, np, torch and cuda.\r\nIf I change labels from a Tensor into a list then this no longer happens.\r\n\r\nThe weirdest part is that this doesn\'t happen on my AMD Ryzen 5600x but it does happen on 6th and 8th gen Intel i7 laptop CPUs.\r\n\r\n#### Expected Output\r\n\r\nThe unique values should always be the same as the labels going in even if it\'s a tensor and no matter what CPU is used.\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\nThese are the details from my laptop containing the 8th gen i7 cpu\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 2cb96529396d93b46abab7bbc73a208e708c642e\r\npython           : 3.8.8.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 5.11.0-17-generic\r\nVersion          : #18-Ubuntu SMP Thu May 6 20:10:11 UTC 2021\r\nmachine          : x86_64\r\nprocessor        : x86_64\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_GB.UTF-8\r\nLOCALE           : en_GB.UTF-8\r\npandas           : 1.2.4\r\nnumpy            : 1.19.4\r\npytz             : 2021.1\r\ndateutil         : 2.8.1\r\npip              : 21.0.1\r\nsetuptools       : 52.0.0.post20210125\r\nCython           : 0.29.23\r\npytest           : 6.2.3\r\nhypothesis   ...
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41826',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41826/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41826/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41826/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/41826',
#   'id': 912311880,
#   'node_id': 'MDU6SXNzdWU5MTIzMTE4ODA=',
#   'number': 41826,
#   'title': 'ENH: Allow different senses of "distance" for method=nearest indexing',
#   'user': {'login': 'WardBrian',
#    'id': 31640292,
#    'node_id': 'MDQ6VXNlcjMxNjQwMjky',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/31640292?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/WardBrian',
#    'html_url': 'https://github.com/WardBrian',
#    'followers_url': 'https://api.github.com/users/WardBrian/followers',
#    'following_url': 'https://api.github.com/users/WardBrian/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/WardBrian/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/WardBrian/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/WardBrian/subscriptions',
#    'organizations_url': 'https://api.github.com/users/WardBrian/orgs',
#    'repos_url': 'https://api.github.com/users/WardBrian/repos',
#    'events_url': 'https://api.github.com/users/WardBrian/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/WardBrian/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2021-06-05T15:26:36Z',
#   'updated_at': '2021-06-05T17:37:57Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '#### Is your feature request related to a problem?\r\n\r\n`Index.get_loc` with the method keyword has been quite useful for me, but I often find myself using data (e.g. atmospheric pressure levels) where the truest sense of the word \'nearest\' is actually the closest value in log(p), not the normal number line. \r\n\r\n#### Describe the solution you\'d like\r\n\r\nMy first thought was to simply request a "log_nearest" option to the method parameter, but I think it is easier to get much more functionality essentially "for free" with a different construction:\r\n\r\nIndex.get_loc (and subsequently Index._get_nearest_indexer) could accept a parameter (Let\'s call it "pre", but I think there are certainly better options I haven\'t thought of) which is a ufunc of one variable, and apply that to the target values and left and right indexed values before calculating their distances.\r\n\r\ne.g.:\r\n\r\n\r\n```python\r\n>>> idx = pd.Index([10, 0.1, 0.01])\r\n>>> idx.get_loc(2.0, method=\'nearest\')\r\n1\r\n>>> idx.get_loc(2.0, method=\'nearest\', pre=np.log)\r\n0\r\n```\r\n\r\n#### API breaking implications\r\n\r\nThis should not affect any existing usages of the API\r\n\r\n#### Describe alternatives you\'ve considered\r\n\r\nAn alternative solution to my specific problem is to store the index in the log-space version, but this is considerably less human-readable in general.\r\n\r\n#### Additional context\r\n\r\nBesides changing the signatures and documentation, I believe this change can primarily be implemented with edits to this section of the indexing code\r\n\r\nhttps://github.com/pandas-dev/pandas/blob/2cb96529396d93b46abab7bbc73a208e708c642e/pandas/core/indexes/base.py#L3269-L3277\r\n\r\nThere may also need to be some additional code added to the higher-up functions to produce errors if this parameter is passed when method != "nearest", as I don\'t believe it makes sense in that context.\r\n\r\nIt is also worth noting that this has the potential to fail (e.g, if a point in the indexer is 0 or negative, the log function will not work). Pandas may want to trap those errors and report them differently, but a garbage-in-garbage-out disclaimer may be helpful in general',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41825',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41825/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41825/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41825/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/41825',
#   'id': 912116016,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NjYyMzEwNDI2',
#   'number': 41825,
#   'title': 'REF: share wrapping in MultiIndex setops',
#   'user': {'login': 'jbrockmendel',
# ...
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2021-06-03T07:33:43Z',
#   'updated_at': '2021-06-03T12:44:44Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '- [x] I have checked that this issue has not already been reported.\r\n\r\n- [x] I have confirmed this bug exists on the latest version of pandas.\r\n\r\n- [ ] (optional) I have confirmed this bug exists on the master branch of pandas.\r\n\r\n---\r\n\r\n#### Code Sample, a copy-pastable example\r\n\r\n```python\r\nimport pandas as pd\r\ntest_time = pd.to_datetime(\'2020-06-09 00:01:14.500000\')\r\nprint(pd.Series(test_time).dt.round("S"))\r\n```\r\n\r\n#### Problem description\r\n\r\nIf the ms is 5e5, the method of round is floor, but it should be ceil.\r\n\r\n#### Expected Output\r\n```\r\n2020-06-09 00:01:15\r\n```\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 2cb96529396d93b46abab7bbc73a208e708c642e\r\npython           : 3.8.8.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 3.10.0-957.el7.x86_64\r\nVersion          : #1 SMP Thu Nov 8 23:39:32 UTC 2018\r\nmachine          : x86_64\r\nprocessor        : x86_64\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 1.2.4\r\nnumpy            : 1.20.2\r\npytz             : 2021.1\r\ndateutil         : 2.8.1\r\npip              : 21.1.1\r\nsetuptools       : 49.6.0.post20210108\r\nCython           : None\r\npytest           : 6.2.4\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 2.11.3\r\nIPython          : 7.23.1\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nfsspec           : 2021.04.0\r\nfastparquet      : None\r\ngcsfs            : None\r\nmatplotlib       : 3.3.4\r\nnumexpr          : 2.7.3\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.6.3\r\nsqlalchemy       : None\r\ntables           : 3.6.1\r\ntabulate         : None\r\nxarray           : 0.18.0\r\nxlrd             : None\r\nxlwt             : None\r\nnumba            : None\r\n</details>\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41792',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41792/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41792/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41792/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/41792',
#   'id': 909986934,
#   'node_id': 'MDU6SXNzdWU5MDk5ODY5MzQ=',
#   'number': 41792,
#   'title': "BUG: Broken bool supports in pandas' quantile by NumPy's percentile behaviour change",
#   'user': {'login': 'HyukjinKwon',
#    'id': 6477701,
#    'node_id': 'MDQ6VXNlcjY0Nzc3MDE=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6477701?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/HyukjinKwon',
#    'html_url': 'https://github.com/HyukjinKwon',
#    'followers_url': 'https://api.github.com/users/HyukjinKwon/followers',
#    'following_url': 'https://api.github.com/users/HyukjinKwon/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/HyukjinKwon/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/HyukjinKwon/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/HyukjinKwon/subscriptions',
#    'organizations_url': 'https://api.github.com/users/HyukjinKwon/orgs',
#    'repos_url': 'https://api.github.com/users/HyukjinKwon/repos',
#    'events_url': 'https://api.github.com/users/HyukjinKwon/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/HyukjinKwon/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-06-03T00:36:07Z',
#   'updated_at': '2021-06-03T03:53:02Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '- [x] I have checked that this issue has not already been reported.\r\n\r\n- [x] I have confirmed this bug exists on the latest version of pandas.\r\n\r\n- [ ] (optional) I have confirmed this bug exists on the master branch of pandas.\r\n\r\n---\r\n\r\n**Note**: Please read [this guide](https://matthewrocklin.com/blog/work/2018/02/28/minimal-bug-reports) detailing how to provide the necessary information for us to reproduce your bug.\r\n\r\n#### Code Sample, a copy-pastable example\r\n\r\n```python\r\nimport pandas as pd\r\npd.DataFrame({"i": [0, 1, 2], "b": [False, False, True], "s": ["x", "y", "z"]}).quantile(q=0.5, numeric_only=True)\r\n```\r\n\r\n#### Problem description\r\n\r\nhttps://github.com/numpy/numpy/pull/16273#discussion_r641264085  broke the case of NumPy\'s `percentile` with bools which causes to break pandas pandas\' `quantile` too. If this is considered as not a bug, I would expect pandas to handle it with `numeric_only`. Cross filed issue in NumPy: https://github.com/numpy/numpy/issues/19154\r\n\r\nCurrently it throws an exception as below:\r\n\r\n```\r\nTraceback (most recent call last):\r\n  File "<stdin>", line 1, in <module>\r\n  File "/.../python3.8/site-packages/pandas/core/frame.py", line 9266, in quantile\r\n    result = data._mgr.quantile(\r\n  File "/.../python3.8/site-packages/pandas/core/internals/managers.py", line 491, in quantile\r\n    block = b.quantile(axis=axis, qs=qs, interpolation=interpolation)\r\n  File "/.../python3.8/site-packages/pandas/core/internals/blocks.py", line 1592, in quantile\r\n    result = nanpercentile(\r\n  File "/.../python3.8/site-packages/pandas/core/nanops.py", line 1675, in nanpercentile\r\n    return np.percentile(values, q, axis=axis, interpolation=interpolation)\r\n  File "<__array_function__ internals>", line 5, in percentile\r\n  File "/.../python3.8/site-packages/numpy/lib/function_base.py", line 3818, in percentile\r\n    return _quantile_unchecked(\r\n  File "/.../python3.8/site-packages/numpy/lib/function_base.py", line 3937, in _quantile_unchecked\r\n    r, k = _ureduce(a, func=_quantile_ureduce_func, q=q, axis=axis, out=out,\r\n  File "/.../python3.8/site-packages/numpy/lib/function_base.py", line 3515, in _ureduce\r\n    r = func(a, **kwargs)\r\n  File "/.../python3.8/site-packages/numpy/lib/function_base.py", line 4064, in _quantile_ureduce_func\r\n    r = _lerp(x_below, x_above, weights_above, out=out)\r\n  File "/.../python3.8/site-packages/numpy/lib/function_base.py", line 3961, in _lerp\r\n    diff_b_a = subtract(b, a)\r\nTypeError: numpy boolean subtract, the `-` operator, is not supported, use the bitwise_xor, the `^` operator, or the logical_xor function instead.\r\n```\r\n\r\n#### Expected Output\r\n\r\n```\r\ni    1.0\r\nb    0.0\r\nName: 0.5, dtype: float64\r\n```\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\n\r\n```\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 2cb96529396d93b46abab7bbc73a208e708c642e\r\npython           : 3.8.8.final.0\r\npython-bits      : 64\r\nOS               : Darwin\r\nOS-release       : 20.4.0\r\nVersion          : Darwin Kernel Version 20.4.0: Thu Apr 22 21:46:47 PDT 2021; root:xnu-7195.101.2~1/RELEASE_X86_64\r\nmachine          : x86_64\r\nprocessor        : i386\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 1.2.4\r\nnumpy            : 1.20.3\r\npytz             : 2021.1\r\ndateutil         : 2.8.1\r\npip              : 21.0.1\r\nsetuptools       : 52.0.0.post20210125\r\nCython           : None\r\npytest           : 6.2.4\r\nhypothesis       : None\r\nsphinx           : 3.0.4\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 2.11.3\r\nIPython          : 7.23.1\r\npandas_datareader: None\r\nbs4             ...
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41788',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41788/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41788/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41788/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/41788',
#   'id': 909859476,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NjYwMzcxMzcw',
#   'number': 41788,
#   'title': 'BLD: Adjust Numpy Minimum Versions for aarch64/arm64 compatibility',
#   'user': {'login': 'lithomas1',
#    'id': 47963215,
#    'node_id': 'MDQ6VXNlcjQ3OTYzMjE1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47963215?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lithomas1',
#    'html_url': 'https://github.com/lithomas1',
#    'followers_url': 'https://api.github.com/users/lithomas1/followers',
#    'following_url': 'https://api.github.com/users/lithomas1/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lithomas1/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lithomas1/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lithomas1/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lithomas1/orgs',
#    'repos_url': 'https://api.github.com/users/lithomas1/repos',
#    'events_url': 'https://api.github.com/users/lithomas1/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lithomas1/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 2628846204,
#     'node_id': 'MDU6TGFiZWwyNjI4ODQ2MjA0',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/ARM',
#     'name': 'ARM',
#     'color': 'c2e0c6',
#     'default': False,
#     'description': 'aarch64 architecture'},
#    {'id': 129350,
#     'node_id': 'MDU6TGFiZWwxMjkzNTA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Build',
#     'name': 'Build',
#     'color': '75507B',
#     'default': False,
#     'description': 'Library building on various platforms'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-06-02T20:29:46Z',
#   'updated_at': '2021-06-05T17:46:07Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/41788',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/41788',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/41788.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/41788.patch'},
#   'body': '- [ ] closes #xxxx\r\n- [ ] tests added / passed\r\n- [ ] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing.html#code-standards) for how to run them\r\n- [ ] whatsnew entry\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41787',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41787/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41787/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41787/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/41787',
#   'id': 909654771,
#   'node_id': 'MDU6SXNzdWU5MDk2NTQ3NzE=',
#   'number': 41787,
#   'title': 'QST: Apple M1, arm64',
#   'user': {'login': 'beaverden',
#    'id': 10908270,
#    'node_id': 'MDQ6VXNlcjEwOTA4Mjcw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10908270?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/beaverden',
#    'html_url': 'https://github.com/beaverden',
#    'followers_url': 'https://api.github.com/users/beaverden/followers',
#    'following_url': 'https://api.github.com/users/beaverden/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/beaverden/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/beaverden/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/beaverden/subscriptions',
#    'organizations_url': 'https://api.github.com/users/beaverden/orgs',
#    'repos_url': 'https://api.github.com/users/beaverden/repos',
#    'events_url': 'https://api.github.com/users/beaverden/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/beaverden/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 2628846204,
#     'node_id': 'MDU6TGFiZWwyNjI4ODQ2MjA0',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/ARM',
#     'name': 'ARM',
#     'color': 'c2e0c6',
#     'default': False,
#     'description': 'aarch64 architecture'},
#    {'id': 129350,
#     'node_id': 'MDU6TGFiZWwxMjkzNTA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Build',
#     'name': 'Build',
#     'color': '75507B',
#     'default': False,
#     'description': 'Library building on various platforms'},
#    {'id': 34444536,
#     'node_id': 'MDU6TGFiZWwzNDQ0NDUzNg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Usage%20Question',
#     'name': 'Usage Question',
#     'color': '0052cc',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2021-06-02T16:01:23Z',
#   'updated_at': '2021-06-02T19:47:32Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "- [X] I have searched the [[pandas] tag](https://stackoverflow.com/questions/tagged/pandas) on StackOverflow for similar questions.\r\n\r\n- [X] I have asked my usage related question on [StackOverflow](https://stackoverflow.com).\r\n\r\n---\r\n\r\nWhat is the current state of amd64 compilation? Docker pip installation takes ages and I'm having trouble installing it on my macos with apple m1 chip.\r\n\r\nIs there anything I can do to help provide precompiled binaries for release on this platform?\r\n",
#   'performed_via_github_app': None}]

# %%
df4 = pd.DataFrame(js)

# %%
df4.to_csv('json_dump.csv')

# %%
js[0]['user']
# Out:
# {'login': 'jbrockmendel',
#  'id': 8078968,
#  'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/jbrockmendel',
#  'html_url': 'https://github.com/jbrockmendel',
#  'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#  'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#  'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#  'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#  'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#  'type': 'User',
#  'site_admin': False}

# %% [markdown]
# ## Coverting json to tabular format

# %%
pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                          comments_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                            events_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                              html_url         id  \
# 0   https://github.com/pandas-dev/pandas/issues/41838  912722673
# 1   https://github.com/pandas-dev/pandas/issues/41837  912620024
# 2   https://github.com/pandas-dev/pandas/issues/41836  912602114
# 3   https://github.com/pandas-dev/pandas/issues/41834  912490754
# 4     https://github.com/pandas-dev/pandas/pull/41833  912417260
# 5     https://github.com/pandas-dev/pandas/pull/41832  912416299
# 6   https://github.com/pandas-dev/pandas/issues/41831  912406932
# 7     https://github.com/pandas-dev/pandas/pull/41830  912393075
# 8   https://github.com/pandas-dev/pandas/issues/41829  912363631
# 9   https://github.com/pandas-dev/pandas/issues/41828  912347856
# 10  https://github.com/pandas-dev/pandas/issues/41827  912342186
# 11  https://github.com/pandas-dev/pandas/issues/41826  912311880
# 12    https://github.com/pandas-dev/pandas/pull/41825  912116016
# 13    https://github.com/pandas-dev/pandas/pull/41824  912109064
# 14  https://github.com/pandas-dev/pandas/issues/41823  912106294
# 15    https://github.com/pandas-dev/pandas/pull/41822  912089647
# 16    https://github.com/pandas-dev/pandas/pull/41821  912041109
# 17  https://github.com/pandas-dev/pandas/issues/41819  911904991
# 18    https://github.com/pandas-dev/pandas/pull/41818  911870973
# 19  https://github.com/pandas-dev/pandas/issues/41817  911787600
# 20  https://github.com/pandas-dev/pandas/issues/41815  911678275
# 21  https://github.com/pandas-dev/pandas/issues/41813  911358485
# 22  https://github.com/pandas-dev/pandas/issues/41807  910890401
# 23  https://github.com/pandas-dev/pandas/issues/41805  910796251
# 24  https://github.com/pandas-dev/pandas/issues/41800  910605255
# 25  https://github.com/pandas-dev/pandas/issues/41797  910406075
# 26  https://github.com/pandas-dev/pandas/issues/41796  910203189
# 27  https://github.com/pandas-dev/pandas/issues/41792  909986934
# 28    https://github.com/pandas-dev/pandas/pull/41788  909859476
# 29  https://github.com/pandas-dev/pandas/issues/41787  909654771
#
#                              node_id  number  \
# 0           MDU6SXNzdWU5MTI3MjI2NzM=   41838
# 1           MDU6SXNzdWU5MTI2MjAwMjQ=   41837
# 2           MDU6SXNzdWU5MTI2MDIxMTQ=   41836
# 3           MDU6SXNzdWU5MTI0OTA3NTQ=   41834
# 4   MDExOlB1bGxSZXF1ZXN0NjYyNTc3ODA5   41833
# 5   MDExOlB1bGxSZXF1ZXN0NjYyNTc2OTYy   41832
# 6           MDU6SXNzdWU5MTI0MDY5MzI=   41831
# 7   MDExOlB1bGxSZXF1ZXN0NjYyNTU1OTMy   41830
# 8           MDU6SXNzdWU5MTIzNjM2MzE=   41829
# 9           MDU6SXNzdWU5MTIzNDc4NTY=   41828
# 10          MDU6SXNzdWU5MTIzNDIxODY=   41827
# 11          MDU6SXNzdWU5MTIzMTE4ODA=   41826
# 12  MDExOlB1bGxSZXF1ZXN0NjYyMzEwNDI2   41825
# 13  MDExOlB1bGxSZXF1ZXN0NjYyMzA0NjY4   41824
# 14          MDU6SXNzdWU5MTIxMDYyOTQ=   41823
# 15  MDExOlB1bGxSZXF1ZXN0NjYyMjg4MzM4   41822
# 16  MDExOlB1bGxSZXF1ZXN0NjYyMjQ1OTI2   41821
# 17          MDU6SXNzdWU5MTE5MDQ5OTE=   41819
# 18  MDExOlB1bGxSZXF1ZXN0NjYyMDgzMjg1   41818
# 19          MDU6SXNzdWU5MTE3ODc2MDA=   41817
# 20          MDU6SXNzdWU5MTE2NzgyNzU=   41815
# 21          MDU6SXNzdWU5MTEzNTg0ODU=   41813
# 22          MDU6SXNzdWU5MTA4OTA0MDE=   41807
# 23          MDU6SXNzdWU5MTA3OTYyNTE=   41805
# 24          MDU6SXNzdWU5MTA2MDUyNTU=   41800
# 25          MDU6SXNzdWU5MTA0MDYwNzU=   41797
# 26          MDU6SXNzdWU5MTAyMDMxODk=   41796
# 27          MDU6SXNzdWU5MDk5ODY5MzQ=   41792
# 28  MDExOlB1bGxSZXF1ZXN0NjYwMzcxMzcw   41788
# 29          MDU6SXNzdWU5MDk2NTQ3NzE=   41787
#
#                                                 title  ...  \
# 0              ENH: Using transparentpath in read_csv  ...
# 1                     ENH: DataFrame.to_expr() method  ...
# 2   _libs.hashtable.ismember incorrect with tuples...  ...
# 3   BUG: Odd timezone offset change with old datet...  ...
# 4      REF: de-duplicate symmetric_difference, _union  ...
# 5              REF: de-duplicate IntervalIndex setops  ...
# 6   BUG: IntervalIndex([np.nan, np.nan]).is_monoto...  ...
# 7                                   TYP: datetimelike  ...
# 8                             CI: Re-enable Circle CI  ...
# 9            ENH: retain attrs when concat dataframes  ...
# 10  BUG: DataFrame `isin` function randomly select...  ...
# 11  ENH: Allow different senses of "distance" for ...  ...
# 12           REF: share wrapping in MultiIndex setops  ...
# 13  REF: de-duplicate Index._intersection + MultiI...  ...
# 14  BUG: MultiIndex.unique incorrect when NA value...  ...
# 15                           DOC: Whatsnew1.3 grammar  ...
# 16  BUG: wrong exception when slicing on Timedelta...  ...
# 17  BUG: read_csv does not read double double quot...  ...
# 18  DOC/BLD: update README.md, list setuptools as ...  ...
# 19  BUG: pd.util.hash_array fails on DatetimeIndex...  ...
# 20  DEPS: clarifying setuptools's status as a depe...  ...
# 21  Axis behaviour not consistent for df.interpola...  ...
# 22  TYP: Numpy compatibility of definition of "arr...  ...
# 23                                               BUG:  ...
# 24  BUG: combine_first fails when one series is ti...  ...
# 25  BUG: undocumented astype("category").astype(st...  ...
# 26       BUG: `round()` for 5e5 ms should be `ceil()`  ...
# 27  BUG: Broken bool supports in pandas' quantile ...  ...
# 28  BLD: Adjust Numpy Minimum Versions for aarch64...  ...
# 29                               QST: Apple M1, arm64  ...
#
#                                             milestone comments  \
# 0                                                None        1
# 1                                                None        0
# 2                                                None        0
# 3                                                None        0
# 4                                                None        0
# 5                                                None        0
# 6                                                None        0
# 7                                                None        0
# 8                                                None        0
# 9   {'url': 'https://api.github.com/repos/pandas-d...        3
# 10                                               None        0
# 11                                               None        2
# 12                                               None        3
# 13                                               None        0
# 14                                               None        0
# 15  {'url': 'https://api.github.com/repos/pandas-d...        0
# 16                                               None        0
# 17                                               None        5
# 18  {'url': 'https://api.github.com/repos/pandas-d...        1
# 19                                               None        0
# 20  {'url': 'https://api.github.com/repos/pandas-d...        1
# 21                                               None        0
# 22                                               None        6
# 23                                               None        0
# 24                                               None        0
# 25  {'url': 'https://api.github.com/repos/pandas-d...        1
# 26                                               None        1
# 27                                               None        0
# 28                                               None        0
# 29                                               None        3
#
#                   created_at                updated_at  closed_at  \
# 0  2021-06-06 08:41:07+00:00 2021-06-06 11:29:45+00:00        NaT
# 1  2021-06-06 04:48:43+00:00 2021-06-06 04:48:43+00:00        NaT
# 2  2021-06-06 04:02:39+00:00 2021-06-06 04:02:39+00:00        NaT
# 3  2021-06-05 23:02:57+00:00 2021-06-05 23:02:57+00:00        NaT
# 4  2021-06-05 19:53:54+00:00 2021-06-05 19:53:54+00:00        NaT
# 5  2021-06-05 19:51:30+00:00 2021-06-05 19:51:30+00:00        NaT
# 6  2021-06-05 19:24:41+00:00 2021-06-05 19:24:41+00:00        NaT
# 7  2021-06-05 18:50:56+00:00 2021-06-05 19:31:48+00:00        NaT
# 8  2021-06-05 17:38:50+00:00 2021-06-05 17:41:45+00:00        NaT
# 9  2021-06-05 16:59:07+00:00 2021-06-06 11:28:24+00:00        NaT
# 10 2021-06-05 16:44:35+00:00 2021-06-05 16:44:35+00:00        NaT
# 11 2021-06-05 15:26:36+00:00 2021-06-05 17:37:57+00:00        NaT
# 12 2021-06-05 06:12:50+00:00 2021-06-05 18:31:11+00:00        NaT
# 13 2021-06-05 05:31:30+00:00 2021-06-05 05:31:30+00:00        NaT
# 14 2021-06-05 05:13:47+00:00 2021-06-05 05:13:47+00:00        NaT
# 15 2021-06-05 03:50:57+00:00 2021-06-05 20:56:42+00:00        NaT
# 16 2021-06-05 00:45:07+00:00 2021-06-05 00:45:07+00:00        NaT
# 17 2021-06-04 22:23:28+00:00 2021-06-05 23:35:45+00:00        NaT
# 18 2021-06-04 21:54:02+00:00 2021-06-05 01:27:25+00:00        NaT
# 19 2021-06-04 19:42:27+00:00 2021-06-04 19:43:05+00:00        NaT
# 20 2021-06-04 16:41:48+00:00 2021-06-05 02:48:24+00:00        NaT
# 21 2021-06-04 10:19:09+00:00 2021-06-04 10:19:09+00:00        NaT
# 22 2021-06-03 21:52:58+00:00 2021-06-04 18:41:05+00:00        NaT
# 23 2021-06-03 19:37:07+00:00 2021-06-03 19:37:07+00:00        NaT
# 24 2021-06-03 15:27:56+00:00 2021-06-03 15:27:56+00:00        NaT
# 25 2021-06-03 11:36:44+00:00 2021-06-03 13:41:39+00:00        NaT
# 26 2021-06-03 07:33:43+00:00 2021-06-03 12:44:44+00:00        NaT
# 27 2021-06-03 00:36:07+00:00 2021-06-03 03:53:02+00:00        NaT
# 28 2021-06-02 20:29:46+00:00 2021-06-05 17:46:07+00:00        NaT
# 29 2021-06-02 16:01:23+00:00 2021-06-02 19:47:32+00:00        NaT
#
#    author_association active_lock_reason  \
# 0                NONE                NaN
# 1                NONE                NaN
# 2              MEMBER                NaN
# 3         CONTRIBUTOR                NaN
# 4              MEMBER                NaN
# 5              MEMBER                NaN
# 6              MEMBER                NaN
# 7              MEMBER                NaN
# 8              MEMBER                NaN
# 9                NONE                NaN
# 10               NONE                NaN
# 11               NONE                NaN
# 12             MEMBER                NaN
# 13             MEMBER                NaN
# 14             MEMBER                NaN
# 15             MEMBER                NaN
# 16             MEMBER                NaN
# 17               NONE                NaN
# 18             MEMBER                NaN
# 19        CONTRIBUTOR                NaN
# 20             MEMBER                NaN
# 21               NONE                NaN
# 22        CONTRIBUTOR                NaN
# 23        CONTRIBUTOR                NaN
# 24               NONE                NaN
# 25               NONE                NaN
# 26               NONE                NaN
# 27        CONTRIBUTOR                NaN
# 28             MEMBER                NaN
# 29               NONE                NaN
#
#                                                  body  \
# 0   Hi Guys,\r\n\r\nFirst of all, Thanks for your ...
# 1   #### Is your feature request related to a prob...
# 2   It looks like the equality check being done on...
# 3   - [x] I have checked that this issue has not a...
# 4   Also fixes buglet in CategoricalIndex.equals(M...
# 5   I expect we'll be able to get rid of the last ...
# 6   I'm pretty sure this is related to other quest...
# 7   - [ ] closes #xxxx\r\n- [ ] tests added / pass...
# 8   I contacted CircleCI to check if they could be...
# 9   #### Is your feature request related to a prob...
# 10  - [x ] I have checked that this issue has not ...
# 11  #### Is your feature request related to a prob...
# 12  If we can push _wrap_mi_setop_result further d...
# 13  With a bit more work I think we can further de...
# 14  drop_duplicates looks right, while unique (and...
# 15  - [x] Ensure all linting tests pass, see [here...
# 16  - [ ] closes #xxxx\r\n- [ ] tests added / pass...
# 17  - [x] I have checked that this issue has not a...
# 18                                   xref #41815 \r\n
# 19  - [X] I have checked that this issue has not a...
# 20  In `install.rst`, we list `setuptools` as a ru...
# 21  The axis along which interpolation is performe...
# 22  In `pandas/_typing.py`, we define `ArrayLike` ...
# 23  - [X] I have checked that this issue has not a...
# 24  - [x] I have checked that this issue has not a...
# 25  - [x] I have checked that this issue has not a...
# 26  - [x] I have checked that this issue has not a...
# 27  - [x] I have checked that this issue has not a...
# 28  - [ ] closes #xxxx\r\n- [ ] tests added / pass...
# 29  - [X] I have searched the [[pandas] tag](https...
#
#    performed_via_github_app                                       pull_request
# 0                       NaN                                                NaN
# 1                       NaN                                                NaN
# 2                       NaN                                                NaN
# 3                       NaN                                                NaN
# 4                       NaN  {'url': 'https://api.github.com/repos/pandas-d...
# 5                       NaN  {'url': 'https://api.github.com/repos/pandas-d...
# 6                       NaN                                                NaN
# 7                       NaN  {'url': 'https://api.github.com/repos/pandas-d...
# 8                       NaN                                                NaN
# 9                       NaN                                                NaN
# 10                      NaN                                                NaN
# 11                      NaN                                                NaN
# 12                      NaN  {'url': 'https://api.github.com/repos/pandas-d...
# 13                      NaN  {'url': 'https://api.github.com/repos/pandas-d...
# 14                      NaN                                                NaN
# 15                      NaN  {'url': 'https://api.github.com/repos/pandas-d...
# 16                      NaN  {'url': 'https://api.github.com/repos/pandas-d...
# 17                      NaN                                                NaN
# 18                      NaN  {'url': 'https://api.github.com/repos/pandas-d...
# 19                      NaN                                                NaN
# 20                      NaN                                                NaN
# 21                      NaN                                                NaN
# 22                      NaN                                                NaN
# 23                      NaN                                                NaN
# 24                      NaN                                                NaN
# 25                      NaN                                                NaN
# 26                      NaN                                                NaN
# 27                      NaN                                                NaN
# 28                      NaN  {'url': 'https://api.github.com/repos/pandas-d...
# 29                      NaN                                                NaN
#
# [30 rows x 26 columns]

# %% [markdown]
# ## From the dataset extract the user key and convert into tabular format

# %%
lis=[]
for i in range(len(js)):
    lis.append(js[i]['user'])
pd.DataFrame(lis)
# Out:
#                login        id               node_id  \
# 0       jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 1       jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 2       jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 3         rhshadrach  45562402  MDQ6VXNlcjQ1NTYyNDAy
# 4       jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 5      architsingh15  15556124  MDQ6VXNlcjE1NTU2MTI0
# 6         fangchenli   7614606  MDQ6VXNlcjc2MTQ2MDY=
# 7       TheNeuralBit    675055  MDQ6VXNlcjY3NTA1NQ==
# 8         fangchenli   7614606  MDQ6VXNlcjc2MTQ2MDY=
# 9          mwaddoups  11441393  MDQ6VXNlcjExNDQxMzkz
# 10            Dr-Irv  15113894  MDQ6VXNlcjE1MTEzODk0
# 11     tlaytongoogle  11558041  MDQ6VXNlcjExNTU4MDQx
# 12          johnands   5294322  MDQ6VXNlcjUyOTQzMjI=
# 13            timlod   7346303  MDQ6VXNlcjczNDYzMDM=
# 14            zxdawn  30388627  MDQ6VXNlcjMwMzg4NjI3
# 15       HyukjinKwon   6477701  MDQ6VXNlcjY0Nzc3MDE=
# 16         lithomas1  47963215  MDQ6VXNlcjQ3OTYzMjE1
# 17         beaverden  10908270  MDQ6VXNlcjEwOTA4Mjcw
# 19        https://api.github.com/users/benchittle
# 20  https://api.github.com/users/JoakimZachrisson
# 21    https://api.github.com/users/jordanrmerrick
# 22             https://api.github.com/users/aj125
# 23           https://api.github.com/users/ezerkar
# 24           https://api.github.com/users/adhadse
# 25            https://api.github.com/users/janosh
# 26      https://api.github.com/users/leonoverweel
# 27      https://api.github.com/users/MarcoGorelli
# 28      https://api.github.com/users/jbrockmendel
# 29        https://api.github.com/users/rhshadrach
#
#                                html_url  \
# 0       https://github.com/jbrockmendel
# 1       https://github.com/jbrockmendel
# 2       https://github.com/jbrockmendel
# 3         https://github.com/rhshadrach
# 4       https://github.com/jbrockmendel
# 5      https://github.com/architsingh15
# 6         https://github.com/fangchenli
# 7       https://github.com/TheNeuralBit
# 8         https://github.com/fangchenli
# 9          https://github.com/mwaddoups
# 10            https://github.com/Dr-Irv
# 11     https://github.com/tlaytongoogle
# 12          https://github.com/johnands
# 13            https://github.com/timlod
# 14            https://github.com/zxdawn
# 15       https://github.com/HyukjinKwon
# 16         https://github.com/lithomas1
# 17         https://github.com/beaverden
# 18         https://github.com/irshad-io
# 19        https://github.com/benchittle
# 20  https://github.com/JoakimZachrisson
# 21    https://github.com/jordanrmerrick
# 22             https://github.com/aj125
# 23           https://github.com/ezerkar
# 24           https://github.com/adhadse
# 25            https://github.com/janosh
# 26      https://github.com/leonoverweel
# 27      https://github.com/MarcoGorelli
# 28      https://github.com/jbrockmendel
# 29        https://github.com/rhshadrach
#
#                                         followers_url  \
# 0   https://api.github.com/users/jbrockmendel/foll...
# 1   https://api.github.com/users/jbrockmendel/foll...
# 2   https://api.github.com/users/jbrockmendel/foll...
# 3   https://api.github.com/users/rhshadrach/followers
# 4   https://api.github.com/users/jbrockmendel/foll...
# 5   https://api.github.com/users/architsingh15/fol...
# 6   https://api.github.com/users/fangchenli/followers
# 7   https://api.github.com/users/TheNeuralBit/foll...
# 8   https://api.github.com/users/fangchenli/followers
# 9    https://api.github.com/users/mwaddoups/followers
# 10      https://api.github.com/users/Dr-Irv/followers
# 11  https://api.github.com/users/tlaytongoogle/fol...
# 12    https://api.github.com/users/johnands/followers
# 13      https://api.github.com/users/timlod/followers
# 14      https://api.github.com/users/zxdawn/followers
# 15  https://api.github.com/users/HyukjinKwon/follo...
# 16   https://api.github.com/users/lithomas1/followers
# 17   https://api.github.com/users/beaverden/followers
# 18   https://api.github.com/users/irshad-io/followers
# 19  https://api.github.com/users/benchittle/followers
# 20  https://api.github.com/users/JoakimZachrisson/...
# 21  https://api.github.com/users/jordanrmerrick/fo...
# 22       https://api.github.com/users/aj125/followers
# 23     https://api.github.com/users/ezerkar/followers
# 24     https://api.github.com/users/adhadse/followers
# 25      https://api.github.com/users/janosh/followers
# 26  https://api.github.com/users/leonoverweel/foll...
# 27  https://api.github.com/users/MarcoGorelli/foll...
# 28  https://api.github.com/users/jbrockmendel/foll...
# 29  https://api.github.com/users/rhshadrach/followers
#
#                                         following_url  \
# 0   https://api.github.com/users/jbrockmendel/foll...
# 1   https://api.github.com/users/jbrockmendel/foll...
# 2   https://api.github.com/users/jbrockmendel/foll...
# 

# 20  https://api.github.com/users/JoakimZachrisson/...
# 21  https://api.github.com/users/jordanrmerrick/st...
# 22  https://api.github.com/users/aj125/starred{/ow...
# 23  https://api.github.com/users/ezerkar/starred{/...
# 24  https://api.github.com/users/adhadse/starred{/...
# 25  https://api.github.com/users/janosh/starred{/o...
# 26  https://api.github.com/users/leonoverweel/star...
# 27  https://api.github.com/users/MarcoGorelli/star...
# 28  https://api.github.com/users/jbrockmendel/star...
# 29  https://api.github.com/users/rhshadrach/starre...
#
#                                     subscriptions_url  \
# 0   https://api.github.com/users/jbrockmendel/subs...
# 1   https://api.github.com/users/jbrockmendel/subs...
# 2   https://api.github.com/users/jbrockmendel/subs...
# 3   https://api.github.com/users/rhshadrach/subscr...
# 4   https://api.github.com/users/jbrockmendel/subs...
# 5   https://api.github.com/users/architsingh15/sub...
# 6   https://api.github.com/users/fangchenli/subscr...
# 7   https://api.github.com/users/TheNeuralBit/subs...
# 8   https://api.github.com/users/fangchenli/subscr...
# 9   https://api.github.com/users/mwaddoups/subscri...
# 10  https://api.github.com/users/Dr-Irv/subscriptions
# 11  https://api.github.com/users/tlaytongoogle/sub...
# 12  https://api.github.com/users/johnands/subscrip...
# 13  https://api.github.com/users/timlod/subscriptions
# 14  https://api.github.com/users/zxdawn/subscriptions
# 15  https://api.github.com/users/HyukjinKwon/subsc...
# 16  https://api.github.com/users/lithomas1/subscri...
# 17  https://api.github.com/users/beaverden/subscri...
# 18  https://api.github.com/users/irshad-io/subscri...
# 19  https://api.github.com/users/benchittle/subscr...
# 20  https://api.github.com/users/JoakimZachrisson/...
# 21  https://api.github.com/users/jordanrmerrick/su...
# 22   https://api.github.com/users/aj125/subscriptions
# 23  https://api.github.com/users/ezerkar/subscript...
# 24  https://api.github.com/users/adhadse/subscript...
# 25  https://api.github.com/users/janosh/subscriptions
# 26  https://api.github.com/users/leonoverweel/subs...
# 27  https://api.github.com/users/MarcoGorelli/subs...
# 28  https://api.github.com/users/jbrockmendel/subs...
# 29  https://api.github.com/users/rhshadrach/subscr...
#
#                                     organizations_url  \
# 0      https://api.github.com/users/jbrockmendel/orgs
# 1      https://api.github.com/users/jbrockmendel/orgs
# 2      https://api.github.com/users/jbrockmendel/orgs
# 3        https://api.github.com/users/rhshadrach/orgs
# 4      https://api.github.com/users/jbrockmendel/orgs
# 5     https://api.github.com/users/architsingh15/orgs
# 6        https://api.github.com/users/fangchenli/orgs
# 7      https://api.github.com/users/TheNeuralBit/orgs
# 8        https://api.github.com/users/fangchenli/orgs
# 9         https://api.github.com/users/mwaddoups/orgs
# 10           https://api.github.com/users/Dr-Irv/orgs
# 11    https://api.github.com/users/tlaytongoogle/orgs
# 12         https://api.github.com/users/johnands/orgs
# 13           https://api.github.com/users/timlod/orgs
# 14           https://api.github.com/users/zxdawn/orgs
# 15      https://api.github.com/users/HyukjinKwon/orgs
# 16        https://api.github.com/users/lithomas1/orgs
# 17        https://api.github.com/users/beaverden/orgs
# 18        https://api.github.com/users/irshad-io/orgs
# 19       https://api.github.com/users/benchittle/orgs
# 20  https://api.github.com/users/JoakimZachrisson/...
# 21   https://api.github.com/users/jordanrmerrick/orgs
# 22            https://api.github.com/users/aj125/orgs
# 23          https://api.github.com/users/ezerkar/orgs
# 24          https://api.github.com/users/adhadse/orgs
# 25           https://api.github.com/users/janosh/orgs
# 26     https://api.github.com/users/leonoverweel/orgs
# 27     https://api.github.com/users/MarcoGorelli/orgs
# 28     https://api.github.com/users/jbrockmendel/orgs
# 29       https://api.github.com/users/rhshadrach/orgs
#
#                                             repos_url  \
# 0     https://api.github.com/users/jbrockmendel/repos
# 1     https://api.github.com/users/jbrockmendel/repos
# 2     https://api.github.com/users/jbrockmendel/repos
# 3       https://api.github.com/users/rhshadrach/repos
# 4     https://api.github.com/users/jbrockmendel/repos
# 5    https://api.github.com/users/architsingh15/repos
# 6       https://api.github.com/users/fangchenli/repos
# 7     https://api.github.com/users/TheNeuralBit/repos
# 8       https://api.github.com/users/fangchenli/repos
# 9        https://api.github.com/users/mwaddoups/repos
# 10          https://api.github.com/users/Dr-Irv/repos
# 11   https://api.github.com/users/tlaytongoogle/repos
# 12        https://api.github.com/users/johnands/repos
# 13          https://api.github.com/users/timlod/repos
# 14          https://api.github.com/users/zxdawn/repos
# 15     https://api.github.com/users/HyukjinKwon/repos
# 16       https://api.github.com/users/lithomas1/repos
# 17       https://api.github.com/users/beaverden/repos
# 18       https://api.github.com/users/irshad-io/repos
# 19      https://api.github.com/users/benchittle/repos
# 20  https://api.github.com/users/JoakimZachrisson/...
# 21  https://api.github.com/users/jordanrmerrick/repos
# 22           https://api.github.com/users/aj125/repos
# 23         https://api.github.com/users/ezerkar/repos
# 24         https://api.github.com/users/adhadse/repos
# 25          https://api.github.com/users/janosh/repos
# 26    https://api.github.com/users/leonoverweel/repos
# 27    https://api.github.com/users/MarcoGorelli/repos
# 28    https://api.github.com/users/jbrockmendel/repos
# 29      https://api.github.com/users/rhshadrach/repos
#
#                                            events_url  \
# 0   https://api.github.com/users/jbrockmendel/even...
# 1   https://api.github.com/users/jbrockmendel/even...
# 2   https://api.github.com/users/jbrockmendel/even...
# 3   https://api.github.com/users/rhshadrach/events...
# 4   https://api.github.com/users/jbrockmendel/even...
# 5   https://api.github.com/users/architsingh15/eve...
# 6   https://api.github.com/users/fangchenli/events...
# 7   https://api.github.com/users/TheNeuralBit/even...
# 8   https://api.github.com/users/fangchenli/events...
# 9   https://api.github.com/users/mwaddoups/events{...
# 10  https://api.github.com/users/Dr-Irv/events{/pr...
# 11  https://api.github.com/users/tlaytongoogle/eve...
# 12  https://api.github.com/users/johnands/events{/...
# 13  https://api.github.com/users/timlod/events{/pr...
# 14  https://api.github.com/users/zxdawn/events{/pr...
# 15  https://api.github.com/users/HyukjinKwon/event...
# 16  https://api.github.com/users/lithomas1/events{...
# 17  https://api.github.com/users/beaverden/events{...
# 18  https://api.github.com/users/irshad-io/events{...
# 19  https://api.github.com/users/benchittle/events...
# 20  https://api.github.com/users/JoakimZachrisson/...
# 21  https://api.github.com/users/jordanrmerrick/ev...
# 22  https://api.github.com/users/aj125/events{/pri...
# 23  https://api.github.com/users/ezerkar/events{/p...
# 24  https://api.github.com/users/adhadse/events{/p...
# 25  https://api.github.com/users/janosh/events{/pr...
# 26  https://api.github.com/users/leonoverweel/even...
# 27  https://api.github.com/users/MarcoGorelli/even...
# 28  https://api.github.com/users/jbrockmendel/even...
# 29  https://api.github.com/users/rhshadrach/events...
#
#                                   received_events_url  type  site_admin
# 0   https://api.github.com/users/jbrockmendel/rece...  User       False
# 1   https://api.github.com/users/jbrockmendel/rece...  User       False
# 2   https://api.github.com/users/jbrockmendel/rece...  User       False
# 3   https://api.github.com/users/rhshadrach/receiv...  User       False
# 4   https://api.github.com/users/jbrockmendel/rece...  User       False
# 5   https://api.github.com/users/architsingh15/rec...  User       False
# 6   https://api.github.com/users/fangchenli/receiv...  User       False
# 7   https://api.github.com/users/TheNeuralBit/rece...  User       False
# 8   https://api.github.com/users/fangchenli/receiv...  User       False
# 9   https://api.github.com/users/mwaddoups/receive...  User       False
# 10  https://api.github.com/users/Dr-Irv/received_e...  User       False
# 11  https://api.github.com/users/tlaytongoogle/rec...  User       False
# 12  https://api.github.com/users/johnands/received...  User       False
# 13  https://api.github.com/users/timlod/received_e...  User       False
# 14  https://api.github.com/users/zxdawn/received_e...  User       False
# 15  https://api.github.com/users/HyukjinKwon/recei...  User       False
# 16  https://api.github.com/users/lithomas1/receive...  User       False
# 17  https://api.github.com/users/beaverden/receive...  User       False
# 18  https://api.github.com/users/irshad-io/receive...  User       False
# 19  https://api.github.com/users/benchittle/receiv...  User       False
# 20  https://api.github.com/users/JoakimZachrisson/...  User       False
# 21  https://api.github.com/users/jordanrmerrick/re...  User       False
# 22  https://api.github.com/users/aj125/received_ev...  User       False
# 23  https://api.github.com/users/ezerkar/received_...  User       False
# 24  https://api.github.com/users/adhadse/received_...  User       False
# 25  https://api.github.com/users/janosh/received_e...  User       False
# 26  https://api.github.com/users/leonoverweel/rece...  User       False
# 27  https://api.github.com/users/MarcoGorelli/rece...  User       False
# 28  https://api.github.com/users/jbrockmendel/rece...  User       False
# 29  https://api.github.com/users/rhshadrach/receiv...  User       False

# %%
user = []
res=requests.get('https://api.github.com/repos/pandas-dev/pandas/issues')
js=res.json()
for i in range(len(js)):
    user.append(js[i]['user'])

pd.DataFrame(user)
# Out:
#                login        id               node_id  \
# 0       jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 1       jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 2       jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 3         rhshadrach  45562402  MDQ6VXNlcjQ1NTYyNDAy
# 4       jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 5      architsingh15  15556124  MDQ6VXNlcjE1NTU2MTI0
# 6         fangchenli   7614606  MDQ6VXNlcjc2MTQ2MDY=
# 7       TheNeuralBit    675055  MDQ6VXNlcjY3NTA1NQ==
# 8         fangchenli   7614606  MDQ6VXNlcjc2MTQ2MDY=
# 9          mwaddoups  11441393  MDQ6VXNlcjExNDQxMzkz
# 10            Dr-Irv  15113894  MDQ6VXNlcjE1MTEzODk0
# 11     tlaytongoogle  11558041  MDQ6VXNlcjExNTU4MDQx
# 12          johnands   5294322  MDQ6VXNlcjUyOTQzMjI=
# 13            timlod   7346303  MDQ6VXNlcjczNDYzMDM=
# 14            zxdawn  30388627  MDQ6VXNlcjMwMzg4NjI3
# 15       HyukjinKwon   6477701  MDQ6VXNlcjY0Nzc3MDE=
# 14            https://api.github.com/users/zxdawn
# 15       https://api.github.com/users/HyukjinKwon
# 16         https://api.github.com/users/lithomas1
# 17         https://api.github.com/users/beaverden
# 18         https://api.github.com/users/irshad-io
# 19        https://api.github.com/users/benchittle
# 20  https://api.github.com/users/JoakimZachrisson
# 21    https://api.github.com/users/jordanrmerrick
# 22             https://api.github.com/users/aj125
# 23           https://api.github.com/users/ezerkar
# 24           https://api.github.com/users/adhadse
# 25            https://api.github.com/users/janosh
# 26      https://api.github.com/users/leonoverweel
# 27      https://api.github.com/users/MarcoGorelli
# 28      https://api.github.com/users/jbrockmendel
# 29        https://api.github.com/users/rhshadrach
#
#                                html_url  \
# 0       https://github.com/jbrockmendel
# 1       https://github.com/jbrockmendel
# 2       https://github.com/jbrockmendel
# 3         https://github.com/rhshadrach
# 4       https://github.com/jbrockmendel
# 5      https://github.com/architsingh15
# 6         https://github.com/fangchenli
# 7       https://github.com/TheNeuralBit
# 8         https://github.com/fangchenli
# 9          https://github.com/mwaddoups
# 10            https://github.com/Dr-Irv
# 11     https://github.com/tlaytongoogle
# 12          https://github.com/johnands
# 13            https://github.com/timlod
# 14            https://github.com/zxdawn
# 15       https://github.com/HyukjinKwon
# 16         https://github.com/lithomas1
# 17         https://github.com/beaverden
# 18         https://github.com/irshad-io
# 19        https://github.com/benchittle
# 20  https://github.com/JoakimZachrisson
# 21    https://github.com/jordanrmerrick
# 22             https://github.com/aj125
# 23           https://github.com/ezerkar
# 24           https://github.com/adhadse
# 25            https://github.com/janosh
# 26      https://github.com/leonoverweel
# 27      https://github.com/MarcoGorelli
# 28      https://github.com/jbrockmendel
# 29        https://github.com/rhshadrach
#
#                                         followers_url  \
# 0   https://api.github.com/users/jbrockmendel/foll...
# 1   https://api.github.com/users/jbrockmendel/foll...
# 2   https://api.github.com/users/jbrockmendel/foll...
# 3   https://api.github.com/users/rhshadrach/followers
# 4   https://api.github.com/users/jbrockmendel/foll...
# 5   https://api.github.com/users/architsingh15/fol...
# 6   https://api.github.com/users/fangchenli/followers
# 7   https://api.github.com/users/TheNeuralBit/foll...
# 8   https://api.github.com/users/fangchenli/followers
# 9    https://api.github.com/users/mwaddoups/followers
# 10      https://api.github.com/users/Dr-Irv/followers
# 11  https://api.github.com/users/tlaytongoogle/fol...
# 12    https://api.github.com/users/johnands/followers
# 13      https://api.github.com/users/timlod/followers
# 14      https://api.github.com/users/zxdawn/followers
# 15  https://api.github.com/users/HyukjinKwon/follo...
# 16   https://api.github.com/users/lithomas1/followers
# 17   https://api.github.com/users/beaverden/followers
# 18   https://api.github.com/users/irshad-io/followers
# 19  https://api.github.com/users/benchittle/followers
# 20  https://api.github.com/users/JoakimZachrisson/...
# 21  https://api.github.com/users/jordanrmerrick/fo...
# 22       https://api.github.com/users/aj125/followers
# 23     https://api.github.com/users/ezerkar/followers
# 24     https://api.github.com/users/adhadse/followers
# 25      https://api.github.com/users/janosh/followers
# 26  https://api.github.com/users/leonoverweel/foll...
# 27  https://api.github.com/users/MarcoGorelli/foll...
# 28  https://api.github.com/users/jbrockmendel/foll...
# 29  https://api.github.com/users/rhshadrach/followers
#
#                                         following_url  \
# 0   https://api.github.com/users/jbrockmendel/foll...
# 1   https://api.github.com/users/jbrockmendel/foll...
# 2   https://api.github.com/users/jbrockmendel/foll...
# 
# 20  https://api.github.com/users/JoakimZachrisson/...
# 21   https://api.github.com/users/jordanrmerrick/orgs
# 22            https://api.github.com/users/aj125/orgs
# 23          https://api.github.com/users/ezerkar/orgs
# 24          https://api.github.com/users/adhadse/orgs
# 25           https://api.github.com/users/janosh/orgs
# 26     https://api.github.com/users/leonoverweel/orgs
# 27     https://api.github.com/users/MarcoGorelli/orgs
# 28     https://api.github.com/users/jbrockmendel/orgs
# 29       https://api.github.com/users/rhshadrach/orgs
#
#                                             repos_url  \
# 0     https://api.github.com/users/jbrockmendel/repos
# 1     https://api.github.com/users/jbrockmendel/repos
# 2     https://api.github.com/users/jbrockmendel/repos
# 3       https://api.github.com/users/rhshadrach/repos
# 4     https://api.github.com/users/jbrockmendel/repos
# 5    https://api.github.com/users/architsingh15/repos
# 6       https://api.github.com/users/fangchenli/repos
# 7     https://api.github.com/users/TheNeuralBit/repos
# 8       https://api.github.com/users/fangchenli/repos
# 9        https://api.github.com/users/mwaddoups/repos
# 10          https://api.github.com/users/Dr-Irv/repos
# 11   https://api.github.com/users/tlaytongoogle/repos
# 12        https://api.github.com/users/johnands/repos
# 13          https://api.github.com/users/timlod/repos
# 14          https://api.github.com/users/zxdawn/repos
# 15     https://api.github.com/users/HyukjinKwon/repos
# 16       https://api.github.com/users/lithomas1/repos
# 17       https://api.github.com/users/beaverden/repos
# 18       https://api.github.com/users/irshad-io/repos
# 19      https://api.github.com/users/benchittle/repos
# 20  https://api.github.com/users/JoakimZachrisson/...
# 21  https://api.github.com/users/jordanrmerrick/repos
# 22           https://api.github.com/users/aj125/repos
# 23         https://api.github.com/users/ezerkar/repos
# 24         https://api.github.com/users/adhadse/repos
# 25          https://api.github.com/users/janosh/repos
# 26    https://api.github.com/users/leonoverweel/repos
# 27    https://api.github.com/users/MarcoGorelli/repos
# 28    https://api.github.com/users/jbrockmendel/repos
# 29      https://api.github.com/users/rhshadrach/repos
#
#                                            events_url  \
# 0   https://api.github.com/users/jbrockmendel/even...
# 1   https://api.github.com/users/jbrockmendel/even...
# 2   https://api.github.com/users/jbrockmendel/even...
# 3   https://api.github.com/users/rhshadrach/events...
# 4   https://api.github.com/users/jbrockmendel/even...
# 5   https://api.github.com/users/architsingh15/eve...
# 6   https://api.github.com/users/fangchenli/events...
# 7   https://api.github.com/users/TheNeuralBit/even...
# 8   https://api.github.com/users/fangchenli/events...
# 9   https://api.github.com/users/mwaddoups/events{...
# 10  https://api.github.com/users/Dr-Irv/events{/pr...
# 11  https://api.github.com/users/tlaytongoogle/eve...
# 12  https://api.github.com/users/johnands/events{/...
# 13  https://api.github.com/users/timlod/events{/pr...
# 14  https://api.github.com/users/zxdawn/events{/pr...
# 15  https://api.github.com/users/HyukjinKwon/event...
# 16  https://api.github.com/users/lithomas1/events{...
# 17  https://api.github.com/users/beaverden/events{...
# 18  https://api.github.com/users/irshad-io/events{...
# 19  https://api.github.com/users/benchittle/events...
# 20  https://api.github.com/users/JoakimZachrisson/...
# 21  https://api.github.com/users/jordanrmerrick/ev...
# 22  https://api.github.com/users/aj125/events{/pri...
# 23  https://api.github.com/users/ezerkar/events{/p...
# 24  https://api.github.com/users/adhadse/events{/p...
# 25  https://api.github.com/users/janosh/events{/pr...
# 26  https://api.github.com/users/leonoverweel/even...
# 27  https://api.github.com/users/MarcoGorelli/even...
# 28  https://api.github.com/users/jbrockmendel/even...
# 29  https://api.github.com/users/rhshadrach/events...
#
#                                   received_events_url  type  site_admin
# 0   https://api.github.com/users/jbrockmendel/rece...  User       False
# 1   https://api.github.com/users/jbrockmendel/rece...  User       False
# 2   https://api.github.com/users/jbrockmendel/rece...  User       False
# 3   https://api.github.com/users/rhshadrach/receiv...  User       False
# 4   https://api.github.com/users/jbrockmendel/rece...  User       False
# 5   https://api.github.com/users/architsingh15/rec...  User       False
# 6   https://api.github.com/users/fangchenli/receiv...  User       False
# 7   https://api.github.com/users/TheNeuralBit/rece...  User       False
# 8   https://api.github.com/users/fangchenli/receiv...  User       False
# 9   https://api.github.com/users/mwaddoups/receive...  User       False
# 10  https://api.github.com/users/Dr-Irv/received_e...  User       False
# 11  https://api.github.com/users/tlaytongoogle/rec...  User       False
# 12  https://api.github.com/users/johnands/received...  User       False
# 13  https://api.github.com/users/timlod/received_e...  User       False
# 14  https://api.github.com/users/zxdawn/received_e...  User       False
# 15  https://api.github.com/users/HyukjinKwon/recei...  User       False
# 16  https://api.github.com/users/lithomas1/receive...  User       False
# 17  https://api.github.com/users/beaverden/receive...  User       False
# 18  https://api.github.com/users/irshad-io/receive...  User       False
# 19  https://api.github.com/users/benchittle/receiv...  User       False
# 20  https://api.github.com/users/JoakimZachrisson/...  User       False
# 21  https://api.github.com/users/jordanrmerrick/re...  User       False
# 22  https://api.github.com/users/aj125/received_ev...  User       False
# 23  https://api.github.com/users/ezerkar/received_...  User       False
# 24  https://api.github.com/users/adhadse/received_...  User       False
# 25  https://api.github.com/users/janosh/received_e...  User       False
# 26  https://api.github.com/users/leonoverweel/rece...  User       False
# 27  https://api.github.com/users/MarcoGorelli/rece...  User       False
# 28  https://api.github.com/users/jbrockmendel/rece...  User       False
# 29  https://api.github.com/users/rhshadrach/receiv...  User       False

# %%
pd.DataFrame([js[i]["user"] for i in range(len(js))])
# Out:
#                login        id               node_id  \
# 0       jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 1       jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 2       jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 3         rhshadrach  45562402  MDQ6VXNlcjQ1NTYyNDAy
# 4       jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 5      architsingh15  15556124  MDQ6VXNlcjE1NTU2MTI0
# 6         fangchenli   7614606  MDQ6VXNlcjc2MTQ2MDY=
# 7       TheNeuralBit    675055  MDQ6VXNlcjY3NTA1NQ==
# 8         fangchenli   7614606  MDQ6VXNlcjc2MTQ2MDY=
# 9          mwaddoups  11441393  MDQ6VXNlcjExNDQxMzkz
# 10            Dr-Irv  15113894  MDQ6VXNlcjE1MTEzODk0
# 11     tlaytongoogle  11558041  MDQ6VXNlcjExNTU4MDQx
# 12          johnands   5294322  MDQ6VXNlcjUyOTQzMjI=
# 13            timlod   7346303  MDQ6VXNlcjczNDYzMDM=
# 11     https://api.github.com/users/tlaytongoogle
# 12          https://api.github.com/users/johnands
# 13            https://api.github.com/users/timlod
# 14            https://api.github.com/users/zxdawn
# 15       https://api.github.com/users/HyukjinKwon
# 16         https://api.github.com/users/lithomas1
# 17         https://api.github.com/users/beaverden
# 18         https://api.github.com/users/irshad-io
# 19        https://api.github.com/users/benchittle
# 20  https://api.github.com/users/JoakimZachrisson
# 21    https://api.github.com/users/jordanrmerrick
# 22             https://api.github.com/users/aj125
# 23           https://api.github.com/users/ezerkar
# 24           https://api.github.com/users/adhadse
# 25            https://api.github.com/users/janosh
# 26      https://api.github.com/users/leonoverweel
# 27      https://api.github.com/users/MarcoGorelli
# 28      https://api.github.com/users/jbrockmendel
# 29        https://api.github.com/users/rhshadrach
#
#                                html_url  \
# 0       https://github.com/jbrockmendel
# 1       https://github.com/jbrockmendel
# 2       https://github.com/jbrockmendel
# 3         https://github.com/rhshadrach
# 4       https://github.com/jbrockmendel
# 5      https://github.com/architsingh15
# 6         https://github.com/fangchenli
# 7       https://github.com/TheNeuralBit
# 8         https://github.com/fangchenli
# 9          https://github.com/mwaddoups
# 10            https://github.com/Dr-Irv
# 11     https://github.com/tlaytongoogle
# 12          https://github.com/johnands
# 13            https://github.com/timlod
# 14            https://github.com/zxdawn
# 15       https://github.com/HyukjinKwon
# 16         https://github.com/lithomas1
# 17         https://github.com/beaverden
# 18         https://github.com/irshad-io
# 19        https://github.com/benchittle
# 20  https://github.com/JoakimZachrisson
# 21    https://github.com/jordanrmerrick
# 22             https://github.com/aj125
# 23           https://github.com/ezerkar
# 24           https://github.com/adhadse
# 25            https://github.com/janosh
# 26      https://github.com/leonoverweel
# 27      https://github.com/MarcoGorelli
# 28      https://github.com/jbrockmendel
# 29        https://github.com/rhshadrach
#
#                                         followers_url  \
# 0   https://api.github.com/users/jbrockmendel/foll...
# 1   https://api.github.com/users/jbrockmendel/foll...
# 2   https://api.github.com/users/jbrockmendel/foll...
# 3   https://api.github.com/users/rhshadrach/followers
# 4   https://api.github.com/users/jbrockmendel/foll...
# 5   https://api.github.com/users/architsingh15/fol...
# 6   https://api.github.com/users/fangchenli/followers
# 7   https://api.github.com/users/TheNeuralBit/foll...
# 8   https://api.github.com/users/fangchenli/followers
# 9    https://api.github.com/users/mwaddoups/followers
# 10      https://api.github.com/users/Dr-Irv/followers
# 11  https://api.github.com/users/tlaytongoogle/fol...
# 12    https://api.github.com/users/johnands/followers
# 13      https://api.github.com/users/timlod/followers
# 14      https://api.github.com/users/zxdawn/followers
# 15  https://api.github.com/users/HyukjinKwon/follo...
# 16   https://api.github.com/users/lithomas1/followers
# 17   https://api.github.com/users/beaverden/followers
# 18   https://api.github.com/users/irshad-io/followers
# 19  https://api.github.com/users/benchittle/followers
# 20  https://api.github.com/users/JoakimZachrisson/...
# 21  https://api.github.com/users/jordanrmerrick/fo...
# 22       https://api.github.com/users/aj125/followers
# 23     https://api.github.com/users/ezerkar/followers
# 24     https://api.github.com/users/adhadse/followers
# 25      https://api.github.com/users/janosh/followers
# 26  https://api.github.com/users/leonoverweel/foll...
# 27  https://api.github.com/users/MarcoGorelli/foll...
# 28  https://api.github.com/users/jbrockmendel/foll...
# 29  https://api.github.com/users/rhshadrach/followers
#
#                                         following_url  \
# 0   https://api.github.com/users/jbrockmendel/foll...
# 1   https://api.github.com/users/jbrockmendel/foll...
# 2   https://api.github.com/users/jbrockmendel/foll...
# 
# 11    https://api.github.com/users/tlaytongoogle/orgs
# 12         https://api.github.com/users/johnands/orgs
# 13           https://api.github.com/users/timlod/orgs
# 14           https://api.github.com/users/zxdawn/orgs
# 15      https://api.github.com/users/HyukjinKwon/orgs
# 16        https://api.github.com/users/lithomas1/orgs
# 17        https://api.github.com/users/beaverden/orgs
# 18        https://api.github.com/users/irshad-io/orgs
# 19       https://api.github.com/users/benchittle/orgs
# 20  https://api.github.com/users/JoakimZachrisson/...
# 21   https://api.github.com/users/jordanrmerrick/orgs
# 22            https://api.github.com/users/aj125/orgs
# 23          https://api.github.com/users/ezerkar/orgs
# 24          https://api.github.com/users/adhadse/orgs
# 25           https://api.github.com/users/janosh/orgs
# 26     https://api.github.com/users/leonoverweel/orgs
# 27     https://api.github.com/users/MarcoGorelli/orgs
# 28     https://api.github.com/users/jbrockmendel/orgs
# 29       https://api.github.com/users/rhshadrach/orgs
#
#                                             repos_url  \
# 0     https://api.github.com/users/jbrockmendel/repos
# 1     https://api.github.com/users/jbrockmendel/repos
# 2     https://api.github.com/users/jbrockmendel/repos
# 3       https://api.github.com/users/rhshadrach/repos
# 4     https://api.github.com/users/jbrockmendel/repos
# 5    https://api.github.com/users/architsingh15/repos
# 6       https://api.github.com/users/fangchenli/repos
# 7     https://api.github.com/users/TheNeuralBit/repos
# 8       https://api.github.com/users/fangchenli/repos
# 9        https://api.github.com/users/mwaddoups/repos
# 10          https://api.github.com/users/Dr-Irv/repos
# 11   https://api.github.com/users/tlaytongoogle/repos
# 12        https://api.github.com/users/johnands/repos
# 13          https://api.github.com/users/timlod/repos
# 14          https://api.github.com/users/zxdawn/repos
# 15     https://api.github.com/users/HyukjinKwon/repos
# 16       https://api.github.com/users/lithomas1/repos
# 17       https://api.github.com/users/beaverden/repos
# 18       https://api.github.com/users/irshad-io/repos
# 19      https://api.github.com/users/benchittle/repos
# 20  https://api.github.com/users/JoakimZachrisson/...
# 21  https://api.github.com/users/jordanrmerrick/repos
# 22           https://api.github.com/users/aj125/repos
# 23         https://api.github.com/users/ezerkar/repos
# 24         https://api.github.com/users/adhadse/repos
# 25          https://api.github.com/users/janosh/repos
# 26    https://api.github.com/users/leonoverweel/repos
# 27    https://api.github.com/users/MarcoGorelli/repos
# 28    https://api.github.com/users/jbrockmendel/repos
# 29      https://api.github.com/users/rhshadrach/repos
#
#                                            events_url  \
# 0   https://api.github.com/users/jbrockmendel/even...
# 1   https://api.github.com/users/jbrockmendel/even...
# 2   https://api.github.com/users/jbrockmendel/even...
# 3   https://api.github.com/users/rhshadrach/events...
# 4   https://api.github.com/users/jbrockmendel/even...
# 5   https://api.github.com/users/architsingh15/eve...
# 6   https://api.github.com/users/fangchenli/events...
# 7   https://api.github.com/users/TheNeuralBit/even...
# 8   https://api.github.com/users/fangchenli/events...
# 9   https://api.github.com/users/mwaddoups/events{...
# 10  https://api.github.com/users/Dr-Irv/events{/pr...
# 11  https://api.github.com/users/tlaytongoogle/eve...
# 12  https://api.github.com/users/johnands/events{/...
# 13  https://api.github.com/users/timlod/events{/pr...
# 14  https://api.github.com/users/zxdawn/events{/pr...
# 15  https://api.github.com/users/HyukjinKwon/event...
# 16  https://api.github.com/users/lithomas1/events{...
# 17  https://api.github.com/users/beaverden/events{...
# 18  https://api.github.com/users/irshad-io/events{...
# 19  https://api.github.com/users/benchittle/events...
# 20  https://api.github.com/users/JoakimZachrisson/...
# 21  https://api.github.com/users/jordanrmerrick/ev...
# 22  https://api.github.com/users/aj125/events{/pri...
# 23  https://api.github.com/users/ezerkar/events{/p...
# 24  https://api.github.com/users/adhadse/events{/p...
# 25  https://api.github.com/users/janosh/events{/pr...
# 26  https://api.github.com/users/leonoverweel/even...
# 27  https://api.github.com/users/MarcoGorelli/even...
# 28  https://api.github.com/users/jbrockmendel/even...
# 29  https://api.github.com/users/rhshadrach/events...
#
#                                   received_events_url  type  site_admin
# 0   https://api.github.com/users/jbrockmendel/rece...  User       False
# 1   https://api.github.com/users/jbrockmendel/rece...  User       False
# 2   https://api.github.com/users/jbrockmendel/rece...  User       False
# 3   https://api.github.com/users/rhshadrach/receiv...  User       False
# 4   https://api.github.com/users/jbrockmendel/rece...  User       False
# 5   https://api.github.com/users/architsingh15/rec...  User       False
# 6   https://api.github.com/users/fangchenli/receiv...  User       False
# 7   https://api.github.com/users/TheNeuralBit/rece...  User       False
# 8   https://api.github.com/users/fangchenli/receiv...  User       False
# 9   https://api.github.com/users/mwaddoups/receive...  User       False
# 10  https://api.github.com/users/Dr-Irv/received_e...  User       False
# 11  https://api.github.com/users/tlaytongoogle/rec...  User       False
# 12  https://api.github.com/users/johnands/received...  User       False
# 13  https://api.github.com/users/timlod/received_e...  User       False
# 14  https://api.github.com/users/zxdawn/received_e...  User       False
# 15  https://api.github.com/users/HyukjinKwon/recei...  User       False
# 16  https://api.github.com/users/lithomas1/receive...  User       False
# 17  https://api.github.com/users/beaverden/receive...  User       False
# 18  https://api.github.com/users/irshad-io/receive...  User       False
# 19  https://api.github.com/users/benchittle/receiv...  User       False
# 20  https://api.github.com/users/JoakimZachrisson/...  User       False
# 21  https://api.github.com/users/jordanrmerrick/re...  User       False
# 22  https://api.github.com/users/aj125/received_ev...  User       False
# 23  https://api.github.com/users/ezerkar/received_...  User       False
# 24  https://api.github.com/users/adhadse/received_...  User       False
# 25  https://api.github.com/users/janosh/received_e...  User       False
# 26  https://api.github.com/users/leonoverweel/rece...  User       False
# 27  https://api.github.com/users/MarcoGorelli/rece...  User       False
# 28  https://api.github.com/users/jbrockmendel/rece...  User       False
# 29  https://api.github.com/users/rhshadrach/receiv...  User       False

# %%
l = []
for i in range(len(js)):
    l.append(js[i]['user'])
    
pd.DataFrame(l)
# Out:
#                login        id               node_id  \
# 0       jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 1       jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 2       jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 3         rhshadrach  45562402  MDQ6VXNlcjQ1NTYyNDAy
# 4       jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 5      architsingh15  15556124  MDQ6VXNlcjE1NTU2MTI0
# 6         fangchenli   7614606  MDQ6VXNlcjc2MTQ2MDY=
# 7       TheNeuralBit    675055  MDQ6VXNlcjY3NTA1NQ==
# 8         fangchenli   7614606  MDQ6VXNlcjc2MTQ2MDY=
# 9          mwaddoups  11441393  MDQ6VXNlcjExNDQxMzkz
# 10            Dr-Irv  15113894  MDQ6VXNlcjE1MTEzODk0
# 11     tlaytongoogle  11558041  MDQ6VXNlcjExNTU4MDQx
# 8         https://api.github.com/users/fangchenli
# 9          https://api.github.com/users/mwaddoups
# 10            https://api.github.com/users/Dr-Irv
# 11     https://api.github.com/users/tlaytongoogle
# 12          https://api.github.com/users/johnands
# 13            https://api.github.com/users/timlod
# 14            https://api.github.com/users/zxdawn
# 15       https://api.github.com/users/HyukjinKwon
# 16         https://api.github.com/users/lithomas1
# 17         https://api.github.com/users/beaverden
# 18         https://api.github.com/users/irshad-io
# 19        https://api.github.com/users/benchittle
# 20  https://api.github.com/users/JoakimZachrisson
# 21    https://api.github.com/users/jordanrmerrick
# 22             https://api.github.com/users/aj125
# 23           https://api.github.com/users/ezerkar
# 24           https://api.github.com/users/adhadse
# 25            https://api.github.com/users/janosh
# 26      https://api.github.com/users/leonoverweel
# 27      https://api.github.com/users/MarcoGorelli
# 28      https://api.github.com/users/jbrockmendel
# 29        https://api.github.com/users/rhshadrach
#
#                                html_url  \
# 0       https://github.com/jbrockmendel
# 1       https://github.com/jbrockmendel
# 2       https://github.com/jbrockmendel
# 3         https://github.com/rhshadrach
# 4       https://github.com/jbrockmendel
# 5      https://github.com/architsingh15
# 6         https://github.com/fangchenli
# 7       https://github.com/TheNeuralBit
# 8         https://github.com/fangchenli
# 9          https://github.com/mwaddoups
# 10            https://github.com/Dr-Irv
# 11     https://github.com/tlaytongoogle
# 12          https://github.com/johnands
# 13            https://github.com/timlod
# 14            https://github.com/zxdawn
# 15       https://github.com/HyukjinKwon
# 16         https://github.com/lithomas1
# 17         https://github.com/beaverden
# 18         https://github.com/irshad-io
# 19        https://github.com/benchittle
# 20  https://github.com/JoakimZachrisson
# 21    https://github.com/jordanrmerrick
# 22             https://github.com/aj125
# 23           https://github.com/ezerkar
# 24           https://github.com/adhadse
# 25            https://github.com/janosh
# 26      https://github.com/leonoverweel
# 27      https://github.com/MarcoGorelli
# 28      https://github.com/jbrockmendel
# 29        https://github.com/rhshadrach
#
#                                         followers_url  \
# 0   https://api.github.com/users/jbrockmendel/foll...
# 1   https://api.github.com/users/jbrockmendel/foll...
# 2   https://api.github.com/users/jbrockmendel/foll...
# 3   https://api.github.com/users/rhshadrach/followers
# 4   https://api.github.com/users/jbrockmendel/foll...
# 5   https://api.github.com/users/architsingh15/fol...
# 6   https://api.github.com/users/fangchenli/followers
# 7   https://api.github.com/users/TheNeuralBit/foll...
# 8   https://api.github.com/users/fangchenli/followers
# 9    https://api.github.com/users/mwaddoups/followers
# 10      https://api.github.com/users/Dr-Irv/followers
# 11  https://api.github.com/users/tlaytongoogle/fol...
# 12    https://api.github.com/users/johnands/followers
# 13      https://api.github.com/users/timlod/followers
# 14      https://api.github.com/users/zxdawn/followers
# 15  https://api.github.com/users/HyukjinKwon/follo...
# 16   https://api.github.com/users/lithomas1/followers
# 17   https://api.github.com/users/beaverden/followers
# 18   https://api.github.com/users/irshad-io/followers
# 19  https://api.github.com/users/benchittle/followers
# 20  https://api.github.com/users/JoakimZachrisson/...
# 21  https://api.github.com/users/jordanrmerrick/fo...
# 22       https://api.github.com/users/aj125/followers
# 23     https://api.github.com/users/ezerkar/followers
# 24     https://api.github.com/users/adhadse/followers
# 25      https://api.github.com/users/janosh/followers
# 26  https://api.github.com/users/leonoverweel/foll...
# 27  https://api.github.com/users/MarcoGorelli/foll...
# 28  https://api.github.com/users/jbrockmendel/foll...
# 29  https://api.github.com/users/rhshadrach/followers
#
#                                         following_url  \
# 0   https://api.github.com/users/jbrockmendel/foll...
# 1   https://api.github.com/users/jbrockmendel/foll...
# 2   https://api.github.com/users/jbrockmendel/foll...
# 
# 8        https://api.github.com/users/fangchenli/orgs
# 9         https://api.github.com/users/mwaddoups/orgs
# 10           https://api.github.com/users/Dr-Irv/orgs
# 11    https://api.github.com/users/tlaytongoogle/orgs
# 12         https://api.github.com/users/johnands/orgs
# 13           https://api.github.com/users/timlod/orgs
# 14           https://api.github.com/users/zxdawn/orgs
# 15      https://api.github.com/users/HyukjinKwon/orgs
# 16        https://api.github.com/users/lithomas1/orgs
# 17        https://api.github.com/users/beaverden/orgs
# 18        https://api.github.com/users/irshad-io/orgs
# 19       https://api.github.com/users/benchittle/orgs
# 20  https://api.github.com/users/JoakimZachrisson/...
# 21   https://api.github.com/users/jordanrmerrick/orgs
# 22            https://api.github.com/users/aj125/orgs
# 23          https://api.github.com/users/ezerkar/orgs
# 24          https://api.github.com/users/adhadse/orgs
# 25           https://api.github.com/users/janosh/orgs
# 26     https://api.github.com/users/leonoverweel/orgs
# 27     https://api.github.com/users/MarcoGorelli/orgs
# 28     https://api.github.com/users/jbrockmendel/orgs
# 29       https://api.github.com/users/rhshadrach/orgs
#
#                                             repos_url  \
# 0     https://api.github.com/users/jbrockmendel/repos
# 1     https://api.github.com/users/jbrockmendel/repos
# 2     https://api.github.com/users/jbrockmendel/repos
# 3       https://api.github.com/users/rhshadrach/repos
# 4     https://api.github.com/users/jbrockmendel/repos
# 5    https://api.github.com/users/architsingh15/repos
# 6       https://api.github.com/users/fangchenli/repos
# 7     https://api.github.com/users/TheNeuralBit/repos
# 8       https://api.github.com/users/fangchenli/repos
# 9        https://api.github.com/users/mwaddoups/repos
# 10          https://api.github.com/users/Dr-Irv/repos
# 11   https://api.github.com/users/tlaytongoogle/repos
# 12        https://api.github.com/users/johnands/repos
# 13          https://api.github.com/users/timlod/repos
# 14          https://api.github.com/users/zxdawn/repos
# 15     https://api.github.com/users/HyukjinKwon/repos
# 16       https://api.github.com/users/lithomas1/repos
# 17       https://api.github.com/users/beaverden/repos
# 18       https://api.github.com/users/irshad-io/repos
# 19      https://api.github.com/users/benchittle/repos
# 20  https://api.github.com/users/JoakimZachrisson/...
# 21  https://api.github.com/users/jordanrmerrick/repos
# 22           https://api.github.com/users/aj125/repos
# 23         https://api.github.com/users/ezerkar/repos
# 24         https://api.github.com/users/adhadse/repos
# 25          https://api.github.com/users/janosh/repos
# 26    https://api.github.com/users/leonoverweel/repos
# 27    https://api.github.com/users/MarcoGorelli/repos
# 28    https://api.github.com/users/jbrockmendel/repos
# 29      https://api.github.com/users/rhshadrach/repos
#
#                                            events_url  \
# 0   https://api.github.com/users/jbrockmendel/even...
# 1   https://api.github.com/users/jbrockmendel/even...
# 2   https://api.github.com/users/jbrockmendel/even...
# 3   https://api.github.com/users/rhshadrach/events...
# 4   https://api.github.com/users/jbrockmendel/even...
# 5   https://api.github.com/users/architsingh15/eve...
# 6   https://api.github.com/users/fangchenli/events...
# 7   https://api.github.com/users/TheNeuralBit/even...
# 8   https://api.github.com/users/fangchenli/events...
# 9   https://api.github.com/users/mwaddoups/events{...
# 10  https://api.github.com/users/Dr-Irv/events{/pr...
# 11  https://api.github.com/users/tlaytongoogle/eve...
# 12  https://api.github.com/users/johnands/events{/...
# 13  https://api.github.com/users/timlod/events{/pr...
# 14  https://api.github.com/users/zxdawn/events{/pr...
# 15  https://api.github.com/users/HyukjinKwon/event...
# 16  https://api.github.com/users/lithomas1/events{...
# 17  https://api.github.com/users/beaverden/events{...
# 18  https://api.github.com/users/irshad-io/events{...
# 19  https://api.github.com/users/benchittle/events...
# 20  https://api.github.com/users/JoakimZachrisson/...
# 21  https://api.github.com/users/jordanrmerrick/ev...
# 22  https://api.github.com/users/aj125/events{/pri...
# 23  https://api.github.com/users/ezerkar/events{/p...
# 24  https://api.github.com/users/adhadse/events{/p...
# 25  https://api.github.com/users/janosh/events{/pr...
# 26  https://api.github.com/users/leonoverweel/even...
# 27  https://api.github.com/users/MarcoGorelli/even...
# 28  https://api.github.com/users/jbrockmendel/even...
# 29  https://api.github.com/users/rhshadrach/events...
#
#                                   received_events_url  type  site_admin
# 0   https://api.github.com/users/jbrockmendel/rece...  User       False
# 1   https://api.github.com/users/jbrockmendel/rece...  User       False
# 2   https://api.github.com/users/jbrockmendel/rece...  User       False
# 3   https://api.github.com/users/rhshadrach/receiv...  User       False
# 4   https://api.github.com/users/jbrockmendel/rece...  User       False
# 5   https://api.github.com/users/architsingh15/rec...  User       False
# 6   https://api.github.com/users/fangchenli/receiv...  User       False
# 7   https://api.github.com/users/TheNeuralBit/rece...  User       False
# 8   https://api.github.com/users/fangchenli/receiv...  User       False
# 9   https://api.github.com/users/mwaddoups/receive...  User       False
# 10  https://api.github.com/users/Dr-Irv/received_e...  User       False
# 11  https://api.github.com/users/tlaytongoogle/rec...  User       False
# 12  https://api.github.com/users/johnands/received...  User       False
# 13  https://api.github.com/users/timlod/received_e...  User       False
# 14  https://api.github.com/users/zxdawn/received_e...  User       False
# 15  https://api.github.com/users/HyukjinKwon/recei...  User       False
# 16  https://api.github.com/users/lithomas1/receive...  User       False
# 17  https://api.github.com/users/beaverden/receive...  User       False
# 18  https://api.github.com/users/irshad-io/receive...  User       False
# 19  https://api.github.com/users/benchittle/receiv...  User       False
# 20  https://api.github.com/users/JoakimZachrisson/...  User       False
# 21  https://api.github.com/users/jordanrmerrick/re...  User       False
# 22  https://api.github.com/users/aj125/received_ev...  User       False
# 23  https://api.github.com/users/ezerkar/received_...  User       False
# 24  https://api.github.com/users/adhadse/received_...  User       False
# 25  https://api.github.com/users/janosh/received_e...  User       False
# 26  https://api.github.com/users/leonoverweel/rece...  User       False
# 27  https://api.github.com/users/MarcoGorelli/rece...  User       False
# 28  https://api.github.com/users/jbrockmendel/rece...  User       False
# 29  https://api.github.com/users/rhshadrach/receiv...  User       False

# %%
json_data = pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")
data = pd.DataFrame.from_records(json_data['user'])
data.head()
# Out:
#              login        id               node_id  \
# 0  michaelshekasta  41590425  MDQ6VXNlcjQxNTkwNDI1
# 1    kerrickstaley    184773  MDQ6VXNlcjE4NDc3Mw==
# 2     jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 3              rok     54589      MDQ6VXNlcjU0NTg5
# 4     jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
#
#                                           avatar_url gravatar_id  \
# 0  https://avatars.githubusercontent.com/u/415904...
# 1  https://avatars.githubusercontent.com/u/184773...
# 2  https://avatars.githubusercontent.com/u/807896...
# 3  https://avatars.githubusercontent.com/u/54589?v=4
# 4  https://avatars.githubusercontent.com/u/807896...
#
#                                             url  \
# 0  https://api.github.com/users/michaelshekasta
# 1    https://api.github.com/users/kerrickstaley
# 2     https://api.github.com/users/jbrockmendel
# 3              https://api.github.com/users/rok
# 4     https://api.github.com/users/jbrockmendel
#
#                              html_url  \
# 0  https://github.com/michaelshekasta
# 1    https://github.com/kerrickstaley
# 2     https://github.com/jbrockmendel
# 3              https://github.com/rok
# 4     https://github.com/jbrockmendel
#
#                                        followers_url  \
# 0  https://api.github.com/users/michaelshekasta/f...
# 1  https://api.github.com/users/kerrickstaley/fol...
# 2  https://api.github.com/users/jbrockmendel/foll...
# 3         https://api.github.com/users/rok/followers
# 4  https://api.github.com/users/jbrockmendel/foll...
#
#                                        following_url  \
# 0  https://api.github.com/users/michaelshekasta/f...
# 1  https://api.github.com/users/kerrickstaley/fol...
# 2  https://api.github.com/users/jbrockmendel/foll...
# 3  https://api.github.com/users/rok/following{/ot...
# 4  https://api.github.com/users/jbrockmendel/foll...
#
#                                            gists_url  \
# 0  https://api.github.com/users/michaelshekasta/g...
# 1  https://api.github.com/users/kerrickstaley/gis...
# 2  https://api.github.com/users/jbrockmendel/gist...
# 3   https://api.github.com/users/rok/gists{/gist_id}
# 4  https://api.github.com/users/jbrockmendel/gist...
#
#                                          starred_url  \
# 0  https://api.github.com/users/michaelshekasta/s...
# 1  https://api.github.com/users/kerrickstaley/sta...
# 2  https://api.github.com/users/jbrockmendel/star...
# 3  https://api.github.com/users/rok/starred{/owne...
# 4  https://api.github.com/users/jbrockmendel/star...
#
#                                    subscriptions_url  \
# 0  https://api.github.com/users/michaelshekasta/s...
# 1  https://api.github.com/users/kerrickstaley/sub...
# 2  https://api.github.com/users/jbrockmendel/subs...
# 3     https://api.github.com/users/rok/subscriptions
# 4  https://api.github.com/users/jbrockmendel/subs...
#
#                                    organizations_url  \
# 0  https://api.github.com/users/michaelshekasta/orgs
# 1    https://api.github.com/users/kerrickstaley/orgs
# 2     https://api.github.com/users/jbrockmendel/orgs
# 3              https://api.github.com/users/rok/orgs
# 4     https://api.github.com/users/jbrockmendel/orgs
#
#                                            repos_url  \
# 0  https://api.github.com/users/michaelshekasta/r...
# 1   https://api.github.com/users/kerrickstaley/repos
# 2    https://api.github.com/users/jbrockmendel/repos
# 3             https://api.github.com/users/rok/repos
# 4    https://api.github.com/users/jbrockmendel/repos
#
#                                           events_url  \
# 0  https://api.github.com/users/michaelshekasta/e...
# 1  https://api.github.com/users/kerrickstaley/eve...
# 2  https://api.github.com/users/jbrockmendel/even...
# 3  https://api.github.com/users/rok/events{/privacy}
# 4  https://api.github.com/users/jbrockmendel/even...
#
#                                  received_events_url  type  site_admin
# 0  https://api.github.com/users/michaelshekasta/r...  User       False
# 1  https://api.github.com/users/kerrickstaley/rec...  User       False
# 2  https://api.github.com/users/jbrockmendel/rece...  User       False
# 3   https://api.github.com/users/rok/received_events  User       False
# 4  https://api.github.com/users/jbrockmendel/rece...  User       False
