# %% [markdown]
# ### Python OOP Concepts

# %% [markdown]
# OOP stands for Object Oriented Programming

# %% [markdown]
# An object-oriented paradigm is to design the program using classes and objects. The object is related to real-word entities such as book, house, pencil, etc. The oops concept focuses on writing the reusable code. It is a widespread technique to solve the problem by creating objects.

# %% [markdown]
# Major principles of object-oriented programming system are:
#
# -> Class
#
# -> Object
#
# -> Method
#
# -> Inheritance
#
# -> Polymorphism
#
# -> Data Abstraction
#
# -> Encapsulation

# %% [markdown]
# ### Class

# %% [markdown]
# class is a high level classification of real world entity

# %% [markdown]
# The class can be defined as a collection of objects. It is a logical entity that has some specific attributes and methods

# %% [raw]
# Syntax:
#
# class ClassName:
#     < statement-1 >
#     .
#     .
#     < statement-N >

# %% [markdown]
# #### Creating a class

# %%
class person:
    pass        # The pass keyword is used as a placeholder for future code. When the pass statement is executed, nothing happens, but you avoid getting an error when empty code is not allowed.

# %% [markdown]
# ### Object

# %% [markdown]
# The object is an entity that has state & behavior. It may be any real-world object like mouse, keyboard, chair, table, pen, etc.

# %% [markdown]
# An Object is an instance of a Class. A class is like a blueprint while an instance is a copy of the class with actual values.

# %% [markdown]
# When we define a class, it needs to create an object to allocate the memory.

# %% [markdown]
# #### Creating an object/instance

# %%
p=person()

# %%
print(p)
# Out:
# <class '__main__.person'>

# %%
p.name="Bhagyasree"
p.surname="Garatala"
p.yob=1996

# %%
p.name
# Out:
# 'Bhagyasree'

# %%
p.yob
# Out:
# 1996

# %%
 type(p.name)
# Out:
# str

# %% [markdown]
# ### Method

# %% [markdown]
# The method is a function that is associated with an object. In Python, a method is not unique to class instances. Any object type can have methods.

# %% [markdown]
# #### General Method Syntax

# %% [raw]
# class ClassName:
#    def method_name():
#       …………..
#       # Method_body
#       ………………

# %% [markdown]
# #### Creating method

# %%
class person:
    def __init__(self,name,surname,yob):  # creating method inside a class
        self.name=name
        self.surname=surname
        self.yob=yob

# %% [markdown]
# The __init__ method is similar to constructors in C++ and Java. Constructors are used to initialize the object’s state. The task of constructors is to initialize(assign values) to the data members of the class when an object of class is created

# %% [markdown]
# The self parameter is a reference to the current instance of the class, and is used to access variables that belongs to the class.
# It does not have to be named self , you can call it whatever you like, but it has to be the first parameter of any function in the class:

# %%
p=person("bhagyasree","garatala",7863)
print(p)

# %%
s=person("abc","xyz",3744)

# %%
s.name
# Out:
# 'abc'

# %%
p.name
# Out:
# 'bhagyasree'

# %%
class person:
    def __init__(self,name,surname,yob): 
        self.name=name
        self.surname=surname
        self.yob=yob
    def test(self,n,m):
        return n+m+self.yob

# %%
p=person("bhagya","sree",2342)

# %%
p.name
# Out:
# 'bhagya'

# %%
p.test(34,23)
# Out:
# 2399

# %%
 class person:
    def __init__(self,name,surname,yob): 
        self.name=name
        self.surname=surname
        self.yob=yob
    def __str__(self):
        return "%s is the name and its surname is %s and year of birth is %d" %(self.name, self.surname, self.yob)

# %%
p=person("bhagyasree","garatala",7837)

# %%
print(p)
# Out:
# bhagyasree is the name and its surname is garatala and year of birth is 7837

# %%
class test():
    pass

# %%
p=test()
p.name="ahkdf"
p.surname="lkajs"
p.yob=3643

# %%
p.surname
# Out:
# 'lkajs'

# %%
s = test()
s.name="lauYS"

# %%
s.name
# Out:
# 'lauYS'

# %%
class person:
    def pass_name(self,name):
        self.name=name
    def pass_surname(self,surname):
        self.surname=surname
    def pass_yob(self,yob):
        self.yob=yob

# %%
p=person()

# %%
p.pass_name("bhagyasree")
p.pass_surname("jhfdjk")
p.pass_yob(8246)

# %%
p.name
# Out:
# 'bhagyasree'

# %%
p.surname
# Out:
# 'jhfdjk'

# %% [markdown]
# ### Inheritance

# %% [markdown]
# Inheritance is the capability of one class to derive or inherit the properties from another class.
#
# Parent class is the class being inherited from, also called base class.
#
# Child class is the class that inherits from another class, also called derived class.

# %% [markdown]
# #### Benefits of inheritance:

# %% [markdown]
# -> It provides reusability of a code. We don’t have to write the same code again and again.
#
# -> It allows us to add more features to a class without modifying it.
#
# -> It is transitive in nature, which means that if class B inherits from another class A, then all the subclasses of B would automatically inherit from class A.

# %% [markdown]
# ### Types of Inheritance
# ![Inheritences.jpg](attachment:Inheritences.jpg)

# %% [markdown]
# #### 1. Single inheritance:
# ![single%20inheri.png](attachment:single%20inheri.png)

# %% [markdown]
# When a child class inherits from only one parent class, it is called single inheritance.

# %% [markdown]
# #### Syntax:

# %% [raw]
# class derived-class(base class):
#     <class-suite>

# %% [markdown]
# #### Example:

# %%
class Animal:  
    def speak(self):  
        print("Animal Speaking")  
#child class Dog inherits the base class Animal  
class Dog(Animal):  
    def bark(self):  
        print("dog barking")  
d = Dog()  
d.bark()  
d.speak()
# Out:
# dog barking
# Animal Speaking

# %% [markdown]
# #### 2. Multi-Level inheritance
# ![Multilevel-inheritance1.png](attachment:Multilevel-inheritance1.png)

# %% [markdown]
# When we have a child and grandchild relationship.Multi-level inheritance is archived when a derived class inherits another derived class. There is no limit on the number of levels up to which, the multi-level inheritance is archived in python.

# %% [markdown]
# #### Syntax:

# %% [raw]
# class class1:
#     <class-suite>
# class class2(class1):
#     <class suite>
# class class3(class2):
#     <class suite>
# .
# .

# %% [markdown]
# #### Example:

# %%
class Animal:  
    def speak(self):  
        print("Animal Speaking")  
#The child class Dog inherits the base class Animal  
class Dog(Animal):  
    def bark(self):  
        print("dog barking")  
#The child class Dogchild inherits another child class Dog  
class DogChild(Dog):  
    def eat(self):  
        print("Eating bread...")  
d = DogChild()  
d.bark()  
d.speak()  
d.eat()
# Out:
# dog barking
# Animal Speaking
# Eating bread...

# %% [markdown]
# #### 3. Multiple inheritance
# ![multiple-inheritance1.png](attachment:multiple-inheritance1.png)

# %% [markdown]
# When a child class inherits from multiple parent classes, it is called multiple inheritance.

# %% [markdown]
# #### Syntax:

# %% [raw]
# class Base1:
#     <class-suite>
#
# class Base2:
#     <class-suite>
# .
# .
# .
# class BaseN:
#     <class-suite>
#
# class Derived(Base1, Base2, ...... BaseN):
#     <class-suite>

# %% [markdown]
# #### Example:

# %%
class Calculation1:  
    def Summation(self,a,b):  
        return a+b;  
class Calculation2:  
    def Multiplication(self,a,b):  
        return a*b;  
class Derived(Calculation1,Calculation2):  
    def Divide(self,a,b):  
        return a/b;  
d = Derived()  
print(d.Summation(10,20))  
print(d.Multiplication(10,20))  
print(d.Divide(10,20))
# Out:
# 30
# 200
# 0.5

# %% [markdown]
# #### 4. Hierarchical Inheritance:
# ![Hierarchical-inheritance1.png](attachment:Hierarchical-inheritance1.png)

# %% [markdown]
# When more than one derived classes are created from a single base this type of inheritance is called hierarchical inheritance.

# %% [markdown]
# #### Example:

# %%
# Base class
class Parent:
      def func1(self):
            print("This function is in parent class.")

# Derived class1
class Child1(Parent):
      def func2(self):
            print("This function is in child 1.")

# Derivied class2
class Child2(Parent):
      def func3(self):
            print("This function is in child 2.")

object1 = Child1()
object2 = Child2()
object1.func1()
object1.func2()
object2.func1()
object2.func3()
# Out:
# This function is in parent class.
# This function is in child 1.
# This function is in parent class.
# This function is in child 2.

# %% [markdown]
# #### 5. Hybrid Inheritance:
# ![Hybrid%20inheri.png](attachment:Hybrid%20inheri.png)

# %% [markdown]
#  Inheritance consisting of multiple types of inheritance is called hybrid inheritance.

# %% [markdown]
# #### Example:

# %%
class School:
     def func1(self):
            print("This function is in school.")

class Student1(School):
     def func2(self):
            print("This function is in student 1. ")

class Student2(School):
     def func3(self):
            print("This function is in student 2.")

class Student3(Student1, School):
     def func4(self):
            print("This function is in student 3.")

object = Student3()
object.func1()
object.func2()
# Out:
# This function is in school.
# This function is in student 1.

# %% [markdown]
# #### Create a Parent Class using init method

# %%
class Person:
    def __init__(self, fname, lname):
        self.firstname = fname
        self.lastname = lname

    def printname(self):
        print(self.firstname, self.lastname)

#Use the Person class to create an object, and then execute the printname method:

x = Person("Bhagya", "sree")
x.printname()
# Out:
# Bhagya sree

# %% [markdown]
# #### Create a Child Class

# %%
class Student(Person):
    pass

# %% [markdown]
# Now the Student class has the same properties and methods as the Person class.

# %%
x = Student("Bhagya", "sree")
x.printname()
# Out:
# Bhagya sree

# %% [markdown]
# #### Adding the \_\_init\_\_() Function to child class

# %% [markdown]
# When you add the \_\_init\_\_() function, the child class will no longer inherit the parent's __init__() function.

# %%
class Person:
    def __init__(self, fname, lname):
        self.firstname = fname
        self.lastname = lname

    def printname(self):
        print(self.firstname, self.lastname)

class Student(Person):
    def __init__(self, fname, lname):
#To keep the inheritance of the parent's __init__() function, add a call to the parent's __init__() function:
        Person.__init__(self, fname, lname)

x = Student("Bhagya", "sree")
x.printname()
# Out:
# Bhagya sree

# %% [markdown]
# #### Use the super() Function

# %%
class Person:
    def __init__(self, fname, lname):
        self.firstname = fname
        self.lastname = lname

    def printname(self):
        print(self.firstname, self.lastname)
        
class Student(Person):
    def __init__(self, fname, lname):
        super().__init__(fname, lname)
        
x = Student("Bhagya", "sree")
x.printname()

# By using the super() function, you do not have to use the name of the parent element, it will automatically inherit the methods and properties from its parent.
# Out:
# Bhagya sree

# %% [markdown]
# ###  Polymorphism

# %% [markdown]
# Polymorphism is taken from the Greek words Poly (many) and morphism (forms). It means that the same function name can be used for different types.

# %% [markdown]
# A child class inherits all the methods from the parent class. However, in some situations, the method inherited from the parent class doesn’t quite fit into the child class. In such cases, you will have to re-implement method in the child class which is called as method overloading.

# %% [markdown]
# #### Polymorphism with Function and Objects

# %% [markdown]
# We can create a function that can take any object, allowing for polymorphism.

# %%
class Tomato(): 
    def type(self): 
        print("Vegetable") 
    def color(self):
        print("Red") 
class Apple(): 
    def type(self): 
        print("Fruit") 
    def color(self): 
        print("Red") 

def func(obj): 
    obj.type() 
    obj.color()
        
obj_tomato = Tomato() 
obj_apple = Apple() 
func(obj_tomato) 
func(obj_apple)
# Out:
# Vegetable
# Red
# Fruit
# Red

# %% [markdown]
# #### Polymorphism with Class Methods

# %%
class India():
     def capital(self):
        print("New Delhi")
 
     def language(self):
        print("Hindi and English")

class USA():
     def capital(self):
        print("Washington, D.C.")
 
     def language(self):
        print("English")

obj_ind = India()
obj_usa = USA()
for country in (obj_ind, obj_usa):
    country.capital()
    country.language()
# Out:
# New Delhi
# Hindi and English
# Washington, D.C.
# English

# %% [markdown]
# #### Polymorphism with Inheritance

# %%
class Bird:
     def intro(self):
        print("There are different types of birds")
 
     def flight(self):
        print("Most of the birds can fly but some cannot")

class parrot(Bird):
     def flight(self):
        print("Parrots can fly")

class penguin(Bird):
     def flight(self):
        print("Penguins do not fly")

obj_bird = Bird()
obj_parr = parrot()
obj_peng = penguin()
 
obj_bird.intro()
obj_bird.flight()
 
obj_parr.intro()
obj_parr.flight()
 
obj_peng.intro()
obj_peng.flight()
# Out:
# There are different types of birds
# Most of the birds can fly but some cannot
# There are different types of birds
# Parrots can fly
# There are different types of birds
# Penguins do not fly

# %% [markdown]
# ### Abstraction

# %% [markdown]
# Abstraction is used to hide the internal functionality of the function from the users. The users only interact with the basic implementation of the function, but inner working is hidden. User is familiar with that "what function does" but they don't know "how it does."

# %% [markdown]
# ### Why Abstraction is Important?

# %% [markdown]
# In Python, an abstraction is used to hide the irrelevant data/class in order to reduce the complexity. It also enhances the application efficiency.

# %% [markdown]
# Abstraction in Python is achieved by using abstract classes and interfaces.

# %% [markdown]
# #### Abstract class

# %% [markdown]
# The partially implemented classes are called an abstract class.
# An abstract class can be considered as a blueprint for other classes.
# A class which contains one or more abstract methods is called an abstract class.

# %% [markdown]
# For declaring an Abstract class you need to import the abc module. Every abstract class in python should be a child of ABC(Abstract Base classes) class, which is present in the abc module.

# %% [markdown]
# #### Abstract method

# %% [markdown]
# An abstract method is a method that has a declaration but does not have an implementation.

# %% [markdown]
# In Python, we can declare an abstract method by using @abstractmethod decorator.

# %% [markdown]
# #### Interface

# %% [markdown]
# An interface provides just the method signatures without method bodies. Sub-classes should provide implementation for all the methods defined in an interface. Python doesn’t support creation of interface through any separate keyword, we have to define an interface using abstract class itself. If we create an abstract class which contains only abstract methods that acts as an interface in Python.

# %% [markdown]
# #### Abstraction in Python using abstract class

# %%
from abc import ABC, abstractmethod

class User(ABC):         # abstarct class
    def __init__(self, name, num_of_months):
        self.name = name
        self.num_of_months = num_of_months

    # concrete method
    def display_user(self):
        print('User %s subscribed for %d months' % (self.name, self.num_of_months))

    # abstract method
    @abstractmethod
    def process_fee(self):
        pass

# %% [markdown]
# Creating child classes that are responsible for providing implementation to parent abstract class. These classes are called concrete classes.The concrete class provides an implementation of abstract methods

# %% [markdown]
# We cannot create an object to the abstract class, but we can create an object to the child's class.

# %% [markdown]
# In this example, there are two sub classes inheriting from User and implementing the abstract method process_fee().

# %%
class PlatinumUser(User):      ##implementing parent abstract class by using child class
    PLATINUM_PACKAGE = 2200

    def process_fee(self):       # overriding abstract method
        return self.num_of_months * PlatinumUser.PLATINUM_PACKAGE


class GoldUser(User):          ##implementing parent abstract class by using child class
    Gold_PACKAGE = 1500

    def process_fee(self):       # overriding abstract method    
        return self.num_of_months * GoldUser.Gold_PACKAGE

# %% [markdown]
# As a user we just know that we have to call process_fee() method, we are abstracted from the actual implementation of the method which differs for different child classes of User.

# %%
obj = PlatinumUser('Bharadwaj', 18)
obj.display_user()
fee = obj.process_fee()
print('Fee is', fee)

obj = GoldUser('Yashwanth', 10)
obj.display_user()
fee = obj.process_fee()
print('Fee is', fee)

obj = PlatinumUser('Bhagya', 8)
obj.display_user()
fee = obj.process_fee()
print('Fee is', fee)
# Out:
# User Bharadwaj subscribed for 18 months
# Fee is 39600
# User Yashwanth subscribed for 10 months
# Fee is 15000
# User Bhagya subscribed for 8 months
# Fee is 17600

# %% [markdown]
# ### Encapsulation

# %% [markdown]
# Encapsulation is the process of providing security to the most important component of an object by preventing direct access. However encapsulation is not preventing access, it is providing controlled access.

# %% [markdown]
# This puts restrictions on accessing variables and methods directly and can prevent the accidental modification of data. To prevent accidental change, an object’s variable can only be changed by an object’s method. Those types of variables are known as private variable.

# %% [markdown]
# #### Protected members

# %% [markdown]
# Protected members are those members of the class that cannot be accessed outside the class but can be accessed from within the class and its subclasses. To accomplish this in Python, we have to follow the convention by prefixing the name of the member by a single underscore “_”.

# %%
# Creating a base class
class Base:
    def __init__(self): 
        # Protected member
        self._a = 2

# Creating a derived class   
class Derived(Base):
    def __init__(self):
        # Calling constructor of Base class
        Base.__init__(self)
        print("Calling protected member of base class: ")
        print(self._a)

obj1 = Derived()         
obj2 = Base()
# Out:
# Calling protected member of base class:
# 2

# %%
# Calling protected member Outside class will  result in AttributeError
print(obj2.a)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-157-645ec825ead5> in <module>
#       1 # Calling protected member Outside class will  result in AttributeError
# ----> 2 print(obj2.a)
#
# AttributeError: 'Base' object has no attribute 'a'

# %% [markdown]
# #### Private members

# %% [markdown]
# Private members are similar to protected members, the difference is that the class members declared private should neither be accessed outside the class nor by any base class. In Python, there is no existence of Private instance variables that cannot be accessed except inside a class. However, to define a private member prefix the member name with double underscore “__”.

# %%
# Creating a Base class
class Base:
    def __init__(self):
        self.a = "Encapsulation"
        self.__c = "shfgoadfa"

# Creating a derived class
class Derived(Base):
    def __init__(self):
        
        # Calling constructor of
        # Base class
        Base.__init__(self)
        print("Calling private member of base class: ")
        print(self.__c)
# Driver code
obj1 = Base()
#obj2 = Derived()
print(obj1.a)
# Out:
# Encapsulation

# %%
obj2 = Derived()
# Out:
# Calling private member of base class:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-166-a92fa519d552> in <module>
# ----> 1 obj2 = Derived()
#
# <ipython-input-165-7e36dd3b9520> in __init__(self)
#      13         Base.__init__(self)
#      14         print("Calling private member of base class: ")
# ---> 15         print(self.__c)
#      16 # Driver code
#      17 obj1 = Base()
#
# AttributeError: 'Derived' object has no attribute '_Derived__c'

# %%
print(obj1.c)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-164-b1276be81fff> in <module>
# ----> 1 print(obj1.c)
#
# AttributeError: 'Base' object has no attribute 'c'
