# %% [markdown]
# ### Pycharm Download and Install
# https://www.jetbrains.com/pycharm/download/#section=windows
#
# ![2.PNG](attachment:2.PNG)

# %% [markdown]
# ### Postman Download and Install
# https://www.postman.com/downloads/
# ![3.PNG](attachment:3.PNG)

# %% [markdown]
# ### What is an API? (Application Programming Interface)
# >API is the acronym for Application Programming Interface, which is a software intermediary that allows two applications to talk to each other. Each time you use an app like Facebook, send an instant message, or check the weather on your phone, you’re using an API.
#
# ### Watch the Video in the below link
# https://www.mulesoft.com/resources/api/what-is-an-api#:~:text=API%20is%20the%20acronym%20for,you%27re%20using%20an%20API.

# %% [markdown]
# ![4.gif](attachment:4.gif)

# %% [markdown]
# ### Frameworks in Python to Create API's
# ![5.jpg](attachment:5.jpg)

# %% [markdown]
# ### Protocol Layering
# ### SOAP : Simple Object Access Protocol
# ### REST : Representational State Transfer
# ![5.png](attachment:5.png)

# %% [markdown]
# ### Flask is a Micro Web Developement Frame work
# ![6.png](attachment:6.png)

# %% [markdown]
# ### Flask  uses WSGI
# ### WSGI : Web Server Gateway Interface
# ![7.jpg](attachment:7.jpg)

# %% [markdown]
# ### GET and POST : Both are used to Send Data
# ### Example:
# ### GET : Google query : query is attaced to URL and send Data
# ### POST : gmail Login : query is NOT attached to URL and send Data .Query is attached to Body
# ![9.jpg](attachment:9.jpg)

# %% [markdown]
# ![8.jpg](attachment:8.jpg)

# %% [markdown]
# ### Open the New project in the Pycharm
# ### Copy the link of the folder where Faskdemo exists
# ### Open app.py file
# ### How to setup ?
# ![10.PNG](attachment:10.PNG)

# %% [markdown]
# ![11.PNG](attachment:11.PNG)

# %% [markdown]
# ![12.PNG](attachment:12.PNG)

# %% [markdown]
# ![13.PNG](attachment:13.PNG)

# %% [markdown]
# ### Install flask
# ### pip install flask --user

# %% [markdown]
# ### Interacting Between Python Code and Postman

# %% [markdown]
# ![14.PNG](attachment:14.PNG)

# %% [markdown]
# ![16.PNG](attachment:16.PNG)

# %% [markdown]
# ![15.PNG](attachment:15.PNG)

# %% [markdown]
# ### Example
# ![18.PNG](attachment:18.PNG)

# %% [markdown]
# ![17.PNG](attachment:17.PNG)

# %% [markdown]
# # Example :
# # Python Program (acts as Server)
# ![22.PNG](attachment:22.PNG)

# %%
from flask import Flask, render_template, request, jsonify

app = Flask(__name__)

@app.route('/bharadwaja1', methods=['POST']) # for calling the API from Postman/SOAPUI
def math_operation_via_postman():
    if (request.method=='POST'):
        email=request.json['email']
        name=request.json['name']
        phno = request.json['phno']
        result = " Name : " + str(name) + " Phno : " + str(phno) + " email : " + str(email)
        return jsonify(result)


if __name__ == '__main__':
    app.run()

# %% [markdown]
# ### Open the Above Code in Pycharm and Let the Program be Running . Because Program acts as a Server
# ### Warning : Don't Stop Running Program
# ![24.PNG](attachment:24.PNG)

# %% [markdown]
# # Output in Postman (acts as Client)
# ![20.PNG](attachment:20.PNG)

# %% [markdown]
# ### Interacting Between Python Code and Webpage

# %% [markdown]
# ### Example :

# %%
from flask import Flask, render_template, request, jsonify

app = Flask(__name__)


@app.route('/web_function')
def url_test1():

    test1 = request.args.get('val1')
    test2 = request.args.get('val2')
    test3 = int(test1) + int(test2)

    return '''<h1>my result is : {}</h1>'''.format(test3)


if __name__ == '__main__':
    app.run()

# %% [markdown]
# ### append the route name and url in the browser

# %% [markdown]
# ![web.PNG](attachment:web.PNG)

# %% [markdown]
# ### As we did not pass any input in the url it will throw the below error

# %% [markdown]
# ![error.PNG](attachment:error.PNG)

# %% [markdown]
# ### After passing input values we will get the result as follows

# %% [markdown]
# ![output.PNG](attachment:output.PNG)

# %% [markdown]
# ### Example 2:

# %% [markdown]
# ### Hirerachy of Folder in a HTML and Python interaction Project
# ![26.PNG](attachment:26.PNG)

# %% [markdown]
# ### Hirerachy of Folder in a HTML and Python interaction Project
# ![25.png](attachment:25.png)

# %%
from flask import Flask, render_template, request, jsonify

app = Flask(__name__)


@app.route('/', methods=['GET', 'POST']) # To render Homepage
def home_page():
    return render_template('index.html')

@app.route('/math', methods=['POST'])  # This will be called from UI
def math_operation():
    if (request.method=='POST'):
        operation=request.form['operation']
        num1=int(request.form['num1'])
        num2 = int(request.form['num2'])
        if(operation=='add'):
            r=num1+num2
            result= 'the sum of '+str(num1)+' and '+str(num2) +' is '+str(r)
        if (operation == 'subtract'):
            r = num1 - num2
            result = 'the difference of ' + str(num1) + ' and ' + str(num2) + ' is ' + str(r)
        if (operation == 'multiply'):
            r = num1 * num2
            result = 'the product of ' + str(num1) + ' and ' + str(num2) + ' is ' + str(r)
        if (operation == 'divide'):
            r = num1 / num2
            result = 'the quotient when ' + str(num1) + ' is divided by ' + str(num2) + ' is ' + str(r)
        return render_template('results.html',result=result)


if __name__ == '__main__':
    app.run()

# %% [markdown]
# ### Run the query and hit below url which will be in the console

# %% [markdown]
# ![url.PNG](attachment:url.PNG)

# %% [markdown]
# ### Output

# %% [markdown]
# ![calc.PNG](attachment:calc.PNG)

# %% [markdown]
# ![out.PNG](attachment:out.PNG)

# %% [markdown]
# ### Debugging

# %% [markdown]
# #### If we want to check the internal code at particular step then we need to select the check points and click on debug button. Code will stop running at the first check point

# %% [markdown]
# ![debug.PNG](attachment:debug.PNG)

# %% [markdown]
# #### After hitting the url which is in the console,give the input values

# %% [markdown]
# ![c.PNG](attachment:c.PNG)

# %% [markdown]
# ### Then we can see the internal code at that particular check point as shown below.

# %% [markdown]
# ![internal.PNG](attachment:internal.PNG)

# %% [markdown]
# ### click on the below shown button to move to the next line of code

# %% [markdown]
# ![nextline.PNG](attachment:nextline.PNG)

# %% [markdown]
# ### we can check the code by changing the input values at run time also

# %% [markdown]
# ![runtime.PNG](attachment:runtime.PNG)

# %% [markdown]
# ### After changing the values, click on enter and then click on next line button then the changed values will be reflected

# %% [markdown]
# ![changed.PNG](attachment:changed.PNG)

# %% [markdown]
# ### We can change the operation as well

# %% [markdown]
# ![Capture.PNG](attachment:Capture.PNG)

# %% [markdown]
# ![mul.PNG](attachment:mul.PNG)

# %% [markdown]
# ## Task:

# %% [markdown]
# ### Through API's Perform the below operations on mongo DB, MySQL, Cassandra databases
#
# >#### 1. Creation of table
#
# >#### 2. One row insertion into table
#
# >#### 3. Update into table
#
# >#### 4. Bulk inserstion into table(like csv,json etc.,)
#
# >#### 5. Delete from table
#
# >#### 6. Download data
