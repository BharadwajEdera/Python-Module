# %% [markdown]
# ## what is Data Visualization?
# * ### It is used for Data Analysis
# * Data Visualization is the process of presenting information, in a form that we can see, with the purpose of furthering our understanding of that information. It can be as simple as a 2-dimensional graph, or as complex as a 3-dimensional topology representation of your country. If you think about it, we see examples every day; the share price graph for our favorite stock in the local newspaper, the leader board on the Golf Channel, and the digital eye candy in our favorite Sci-Fi movie. The fact is that Data Visualization is an important part of our lives.
#
# ## What is a Dashboard?
# * ### It is used to create summary of End product
# * In contrast, a Dashboard is a snapshot of a large set of information. Think of it as a summary. It only displays a small portion of the information, but that portion is representative of the information set as a whole. A prime example is the daily weather report on your local TV station. The screen contains current weather conditions, and the short-term forecast, which is a small portion of the meteorological information collected. Its purpose is to give you an overall impression of the current conditions, without boring you with the minute by minute details.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
np.random.seed(20)
df = pd.DataFrame(np.random.randn(1000,1) , index = pd.date_range('2021-07-18',periods=1000),columns=['data'])
df.head()
# Out:
#                 data
# 2021-07-18  0.883893
# 2021-07-19  0.195865
# 2021-07-20  0.357537
# 2021-07-21 -2.343262
# 2021-07-22 -1.084833

# %% [markdown]
# # df.plot()

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.data.cumsum()
# Out:
# 2021-07-18    0.883893
# 2021-07-19    1.079758
# 2021-07-20    1.437295
# 2021-07-21   -0.905967
# 2021-07-22   -1.990800
#                 ...
# 2024-04-08   -2.379919
# 2024-04-09   -3.218376
# 2024-04-10   -3.232502
# 2024-04-11   -1.155149
# 2024-04-12   -0.698515
# Freq: D, Name: data, Length: 1000, dtype: float64

# %% [markdown]
# ## df.column.cumsum.plot()

# %%
df.data.cumsum().plot()
# Out:
# <AxesSubplot:>

# %%
df["data1"] = df.data.cumsum()
df["data2"] = df.data.apply(lambda x : np.log(x))
df
# Out:
#                 data     data1     data2
# 2021-07-18  0.883893  0.883893 -0.123419
# 2021-07-19  0.195865  1.079758 -1.630330
# 2021-07-20  0.357537  1.437295 -1.028518
# 2021-07-21 -2.343262 -0.905967       NaN
# 2021-07-22 -1.084833 -1.990800       NaN
# ...              ...       ...       ...
# 2024-04-08 -0.771658 -2.379919       NaN
# 2024-04-09 -0.838457 -3.218376       NaN
# 2024-04-10 -0.014126 -3.232502       NaN
# 2024-04-11  2.077352 -1.155149  0.731094
# 2024-04-12  0.456634 -0.698515 -0.783872
#
# [1000 rows x 3 columns]

# %% [markdown]
# ## figsize

# %%
df.plot(figsize= (5,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## loading dataset from sns
# ## sns.load_dataset(DatasetName)

# %%
df1 = sns.load_dataset('iris')
df1.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## Title , X_label , Y_label

# %%
gf = df1.plot(figsize= (5,5) , title="iris Data")
gf.set_xlabel("This is X_axis")
gf.set_ylabel("This is Y_axis")
# Out:
# Text(0, 0.5, 'This is Y_axis')

# %%
df1.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ## kind = 'bar'

# %%
df1.iloc[0][0:4]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: object

# %%
df1.iloc[0][0:4].plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
df2 = sns.load_dataset('titanic')
df2.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df2["pclass"].plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
np.random.seed(20)
df3 = pd.DataFrame(np.random.rand(10,4) ,columns=['a','b','c','d'])
df3.head()
# Out:
#           a         b         c         d
# 0  0.588131  0.897714  0.891531  0.815837
# 1  0.035890  0.691758  0.378681  0.518511
# 2  0.657951  0.193850  0.272316  0.718606
# 3  0.783004  0.850328  0.775245  0.036664
# 4  0.116694  0.751281  0.239218  0.254806

# %% [markdown]
# ## Vertical bar plot

# %%
df3.plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Horizontal bar plot

# %%
df3.plot.barh()
# Out:
# <AxesSubplot:>

# %%
df1.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## Histogram
# * ## x_axis : bins or Range
# * ## y_axis : frequency

# %%
df1.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df1["sepal_length"].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ## Vertical Histogram

# %%
df1.plot(kind = 'hist' , stacked = True , bins = 100 , figsize = (5,5) , title = "Histogrm")
# Out:
# <AxesSubplot:title={'center':'Histogrm'}, ylabel='Frequency'>

# %% [markdown]
# ## Horizontal Histogram
# * ### orientation = 'horizontal'

# %%
df1.plot(kind = 'hist' , stacked = True , bins = 100 , figsize = (5,5) , title = "Histogrm" , orientation = 'horizontal' )
# Out:
# <AxesSubplot:title={'center':'Histogrm'}, xlabel='Frequency'>

# %% [markdown]
# ## Seperate Hsitogram for each column

# %%
df1.hist(figsize = (10,10) , color = 'r')
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
df1.hist(figsize = (10,10) , color = '#00FFFF' )
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %% [markdown]
# ## alpha

# %%
df1.hist(figsize = (10,10) , color = '#00FFFF' , alpha= 0.2)
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %% [markdown]
# ## Relationshipbetween attributes

# %%
df1.plot.scatter(x = "sepal_width" , y = "petal_width")
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>

# %%
df1.plot.scatter(x = "sepal_length" , y = "petal_width")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>

# %% [markdown]
# ## Color Scale or Color Dependency
# ## Effect of two columns on third column
# * # c = Third_Column_Name

# %%
df1.plot.scatter(x = "sepal_length" , y = "petal_width" , c = "petal_length")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>

# %%
df1.plot.scatter(x = "sepal_length" , y = "sepal_width" , label = "XYZ" , s=200 , c= "petal_length")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# ## df.plot.hexbin()

# %%
df1.plot.hexbin(x = "sepal_length" , y = "sepal_width" , label = "XYZ" , gridsize = 10)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# ## Pie chart

# %%
k = df1.iloc[2 , :4]
k
# Out:
# sepal_length    4.7
# sepal_width     3.2
# petal_length    1.3
# petal_width     0.2
# Name: 2, dtype: object

# %%
k.plot.pie(figsize=(5,5))
# Out:
# <AxesSubplot:ylabel='2'>

# %% [markdown]
# ## Multiple pie plots
# * ## autopct :: To get decimal float values

# %%
x = df1.head(3).T
x
# Out:
#                    0       1       2
# sepal_length     5.1     4.9     4.7
# sepal_width      3.5       3     3.2
# petal_length     1.4     1.4     1.3
# petal_width      0.2     0.2     0.2
# species       setosa  setosa  setosa

# %%
x.iloc[:4].plot.pie(subplots = True , figsize = (20,20) , fontsize = 30 , autopct = "%.2f")
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %% [markdown]
# # scatter_matrix()
# # pd.plotting.scatter_matrix(DataFrame_Name)

# %%
pd.plotting.scatter_matrix(df1 , figsize = (10,10))
# Out:
# array([[<AxesSubplot:xlabel='sepal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_width'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='petal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>,
# ...

# %% [markdown]
# # kde : Kernel Density Estimation
# ## scatter_matrix with kde plot at diagonal

# %%
pd.plotting.scatter_matrix(df1 , figsize = (10,10) , diagonal = "kde")
# Out:
# array([[<AxesSubplot:xlabel='sepal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_width'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='petal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>,
# ...

# %%
df['data'].plot(style ="r--" , legend = True , label = "XYZ")
# Out:
# <AxesSubplot:>
