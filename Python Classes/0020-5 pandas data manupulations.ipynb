# %%
import pandas as pd  
titanic_train = pd.read_csv("https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv",
                           sep='\t')   
titanic_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
type(titanic_train)
# Out:
# pandas.core.frame.DataFrame

# %%
titanic_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
type(titanic_train.dtypes)
# Out:
# pandas.core.series.Series

# %%
dy = titanic_train.dtypes

# %%
dy['Pclass']
# Out:
# dtype('int64')

# %%
dy
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
l = [0,1,2,3,4,5,"XYZ" , "PQRS" ,"ABC"]

# %%
l[6]
# Out:
# 'XYZ'

# %%
dy[0:100:2]
# Out:
# PassengerId     int64
# Pclass          int64
# Sex            object
# SibSp           int64
# Ticket         object
# Cabin          object
# dtype: object

# %%
titanic_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_train['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 151    22.0
# 152    55.5
# 153    40.5
# 154     NaN
# 155    51.0
# Name: Age, Length: 156, dtype: float64

# %%
type(titanic_train['Age'])
# Out:
# pandas.core.series.Series

# %%
titanic_train['Age'][10:100]
# Out:
# 10     4.0
# 11    58.0
# 12    20.0
# 13    39.0
# 14    14.0
#       ...
# 95     NaN
# 96    71.0
# 97    23.0
# 98    34.0
# 99    34.0
# Name: Age, Length: 90, dtype: float64

# %%
list(titanic_train['Age'][::10])
# Out:
# [22.0,
#  4.0,
#  35.0,
#  40.0,
#  40.0,
#  7.0,
#  22.0,
#  32.0,
#  22.0,
#  29.0,
#  28.0,
#  47.0,
#  21.0,
#  33.0,
#  nan,
#  51.0]

# %%
titanic_train['Age'][::-1]
# Out:
# 155    51.0
# 154     NaN
# 153    40.5
# 152    55.5
# 151    22.0
#        ...
# 4      35.0
# 3      35.0
# 2      26.0
# 1      38.0
# 0      22.0
# Name: Age, Length: 156, dtype: float64

# %% [markdown]
# ### Negative indexes are not possible in Series

# %%
titanic_train['Age'][-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\.conda\envs\gputest\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     354                 try:
# --> 355                     return self._range.index(new_key)
#     356                 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-aeedf62ded2b> in <module>
# ----> 1 titanic_train['Age'][-1]
#
# ~\.conda\envs\gputest\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     880
#     881         elif key_is_scalar:
# --> 882             return self._get_value(key)
#     883
#     884         if is_hashable(key):
#
# ...

# %%
titanic_train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   156.000000  156.000000  156.000000  126.000000  156.000000
# mean     78.500000    0.346154    2.423077   28.141508    0.615385
# std      45.177428    0.477275    0.795459   14.613880    1.056235
# min       1.000000    0.000000    1.000000    0.830000    0.000000
# 25%      39.750000    0.000000    2.000000   19.000000    0.000000
# 50%      78.500000    0.000000    3.000000   26.000000    0.000000
# 75%     117.250000    1.000000    3.000000   35.000000    1.000000
# max     156.000000    1.000000    3.000000   71.000000    5.000000
#
#             Parch        Fare
# count  156.000000  156.000000
# mean     0.397436   28.109587
# std      0.870146   39.401047
# min      0.000000    6.750000
# 25%      0.000000    8.003150
# 50%      0.000000   14.454200
# 75%      0.000000   30.371850
# max      5.000000  263.000000

# %% [markdown]
# ## How to Filter-out the Categorical data from Dataframe ?

# %%
titanic_train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic_train.dtypes == 'object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
type(titanic_train.dtypes[titanic_train.dtypes == 'object'])
# Out:
# pandas.core.series.Series

# %%
titanic_train.dtypes[titanic_train.dtypes == 'object']
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
titanic_train.dtypes[titanic_train.dtypes == 'object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
titanic_train_categorical = titanic_train[titanic_train.dtypes[titanic_train.dtypes == 'object'].index]

# %%
titanic_train_categorical.describe()
# Out:
#                       Name   Sex  Ticket Cabin Embarked
# count                  156   156     156    31      155
# unique                 156     2     145    28        3
# top     Richard, Mr. Emile  male  237736  C123        S
# freq                     1   100       2     2      110

# %% [markdown]
# ## How to Filter-out Columns ?

# %%
titanic_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
type(titanic_train[['Name' ,'Fare' ]])
# Out:
# pandas.core.frame.DataFrame

# %%
titanic_train[['Name']]
# Out:
#                                                   Name
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# ..                                                 ...
# 151                  Pears, Mrs. Thomas (Edith Wearne)
# 152                                   Meo, Mr. Alfonzo
# 153                    van Billiard, Mr. Austin Blyler
# 154                              Olsen, Mr. Ole Martin
# 155                        Williams, Mr. Charles Duane
#
# [156 rows x 1 columns]

# %% [markdown]
# ## How to Filter-out isnull() ?

# %%
import numpy as np

# %%
titanic_train['Age'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 151    False
# 152    False
# 153    False
# 154     True
# 155    False
# Name: Age, Length: 156, dtype: bool

# %%
titanic_train['Age'].isnull() == True
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 151    False
# 152    False
# 153    False
# 154     True
# 155    False
# Name: Age, Length: 156, dtype: bool

# %%
np.where(titanic_train['Age'].isnull() == True)
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154], dtype=int64),)

# %%
titanic_train_age_null = np.where(titanic_train['Age'].isnull() == True)

# %%
titanic_train[titanic_train['Age'].isnull() == True].head()
# Out:
#     PassengerId  Survived  Pclass                           Name     Sex  Age  \
# 5             6         0       3               Moran, Mr. James    male  NaN
# 17           18         1       2   Williams, Mr. Charles Eugene    male  NaN
# 19           20         1       3        Masselmani, Mrs. Fatima  female  NaN
# 26           27         0       3        Emir, Mr. Farred Chehab    male  NaN
# 28           29         1       3  O'Dwyer, Miss. Ellen "Nellie"  female  NaN
#
#     SibSp  Parch  Ticket     Fare Cabin Embarked
# 5       0      0  330877   8.4583   NaN        Q
# 17      0      0  244373  13.0000   NaN        S
# 19      0      0    2649   7.2250   NaN        C
# 26      0      0    2631   7.2250   NaN        C
# 28      0      0  330959   7.8792   NaN        Q

# %%
titanic_train_age_null
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154], dtype=int64),)

# %%
titanic_train[['Name' , 'Pclass']]
# Out:
#                                                   Name  Pclass
# 0                              Braund, Mr. Owen Harris       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2                               Heikkinen, Miss. Laina       3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4                             Allen, Mr. William Henry       3
# ..                                                 ...     ...
# 151                  Pears, Mrs. Thomas (Edith Wearne)       1
# 152                                   Meo, Mr. Alfonzo       3
# 153                    van Billiard, Mr. Austin Blyler       3
# 154                              Olsen, Mr. Ole Martin       3
# 155                        Williams, Mr. Charles Duane       1
#
# [156 rows x 2 columns]

# %% [markdown]
# ## How to filter-out Rows ??
# > ## iloc : Integer Location

# %%
titanic_train.iloc[titanic_train_age_null].head()
# Out:
#     PassengerId  Survived  Pclass                           Name     Sex  Age  \
# 5             6         0       3               Moran, Mr. James    male  NaN
# 17           18         1       2   Williams, Mr. Charles Eugene    male  NaN
# 19           20         1       3        Masselmani, Mrs. Fatima  female  NaN
# 26           27         0       3        Emir, Mr. Farred Chehab    male  NaN
# 28           29         1       3  O'Dwyer, Miss. Ellen "Nellie"  female  NaN
#
#     SibSp  Parch  Ticket     Fare Cabin Embarked
# 5       0      0  330877   8.4583   NaN        Q
# 17      0      0  244373  13.0000   NaN        S
# 19      0      0    2649   7.2250   NaN        C
# 26      0      0    2631   7.2250   NaN        C
# 28      0      0  330959   7.8792   NaN        Q

# %%
type(titanic_train.iloc[5])
# Out:
# pandas.core.series.Series

# %%
titanic_train.iloc[5]
# Out:
# PassengerId                   6
# Survived                      0
# Pclass                        3
# Name           Moran, Mr. James
# Sex                        male
# Age                         NaN
# SibSp                         0
# Parch                         0
# Ticket                   330877
# Fare                     8.4583
# Cabin                       NaN
# Embarked                      Q
# Name: 5, dtype: object

# %%
titanic_train.iloc[[1,2,3,6,7]]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 6            7         0       1
# 7            8         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S

# %% [markdown]
# ## Name of a Person Who has paid highest fair ?
# > ## np.where() : To get index when condition is true

# %%
titanic_train['Fare']
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 151    66.6000
# 152     8.0500
# 153    14.5000
# 154     7.3125
# 155    61.3792
# Name: Fare, Length: 156, dtype: float64

# %%
max(titanic_train['Fare'])
# Out:
# 263.0

# %%
titanic_train['Fare'] == max(titanic_train['Fare'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 151    False
# 152    False
# 153    False
# 154    False
# 155    False
# Name: Fare, Length: 156, dtype: bool

# %%
np.where(titanic_train['Fare'] == max(titanic_train['Fare']))
# Out:
# (array([27, 88], dtype=int64),)

# %%
titanic_train.iloc[np.where(titanic_train['Fare'] == max(titanic_train['Fare']))]
# Out:
#     PassengerId  Survived  Pclass                            Name     Sex  \
# 27           28         0       1  Fortune, Mr. Charles Alexander    male
# 88           89         1       1      Fortune, Miss. Mabel Helen  female
#
#      Age  SibSp  Parch Ticket   Fare        Cabin Embarked
# 27  19.0      3      2  19950  263.0  C23 C25 C27        S
# 88  23.0      3      2  19950  263.0  C23 C25 C27        S

# %%
titanic_train.iloc[np.where(titanic_train['Fare'] == max(titanic_train['Fare']))]['Name']
# Out:
# 27    Fortune, Mr. Charles Alexander
# 88        Fortune, Miss. Mabel Helen
# Name: Name, dtype: object

# %%
titanic_train[titanic_train['Fare']==titanic_train['Fare'].max()]['Name']
# Out:
# 27    Fortune, Mr. Charles Alexander
# 88        Fortune, Miss. Mabel Helen
# Name: Name, dtype: object

# %% [markdown]
# ## Name of a Person Whose age is 24 ?

# %%
titanic_train[titanic_train['Age']==24.0]['Name']
# Out:
# 89                                Celotti, Mr. Francesco
# 118                             Baxter, Mr. Quigg Edmond
# 127                            Madsen, Mr. Fridtjof Arne
# 139                                   Giglio, Mr. Victor
# 142    Hakkarainen, Mrs. Pekka Pietari (Elin Matilda ...
# Name: Name, dtype: object

# %% [markdown]
# ## Name of a Person Whose age is minimum ?

# %%
titanic_train[titanic_train['Age'] == titanic_train['Age'].min()]['Name']
# Out:
# 78    Caldwell, Master. Alden Gates
# Name: Name, dtype: object

# %% [markdown]
# ## Name of a Person Whose Cabin is 'Nan' ?

# %%
titanic_train['Age'][titanic_train['Cabin'].isnull()]
# Out:
# 0      22.0
# 2      26.0
# 4      35.0
# 5       NaN
# 7       2.0
#        ...
# 150    51.0
# 152    55.5
# 153    40.5
# 154     NaN
# 155    51.0
# Name: Age, Length: 125, dtype: float64

# %%
titanic_train[['Age','Cabin']][titanic_train.Cabin.isnull()==True]
# Out:
#       Age Cabin
# 0    22.0   NaN
# 2    26.0   NaN
# 4    35.0   NaN
# 5     NaN   NaN
# 7     2.0   NaN
# ..    ...   ...
# 150  51.0   NaN
# 152  55.5   NaN
# 153  40.5   NaN
# 154   NaN   NaN
# 155  51.0   NaN
#
# [125 rows x 2 columns]

# %%
titanic_train[titanic_train['Cabin']  == 'Nan']
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
titanic_train[titanic_train['Cabin'] == 'NaN']['Age']
# Out:
# Series([], Name: Age, dtype: float64)

# %%
titanic_train[titanic_train["Cabin"].isnull()]["Age"]
# Out:
# 0      22.0
# 2      26.0
# 4      35.0
# 5       NaN
# 7       2.0
#        ...
# 150    51.0
# 152    55.5
# 153    40.5
# 154     NaN
# 155    51.0
# Name: Age, Length: 125, dtype: float64

# %%
titanic_train['Cabin'] == 'NaN'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 151    False
# 152    False
# 153    False
# 154    False
# 155    False
# Name: Cabin, Length: 156, dtype: bool

# %%
titanic_train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic_train.iloc[np.where(titanic_train['Cabin'].isnull() == True)][['Age','Cabin']]
# Out:
#       Age Cabin
# 0    22.0   NaN
# 2    26.0   NaN
# 4    35.0   NaN
# 5     NaN   NaN
# 7     2.0   NaN
# ..    ...   ...
# 150  51.0   NaN
# 152  55.5   NaN
# 153  40.5   NaN
# 154   NaN   NaN
# 155  51.0   NaN
#
# [125 rows x 2 columns]

# %%
titanic_train.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## How many male passengers who have survived ?

# %%
titanic_train[(titanic_train.Survived == 1) & (titanic_train.Sex == "male")]["Name"]
# Out:
# 17                     Williams, Mr. Charles Eugene
# 21                            Beesley, Mr. Lawrence
# 23                     Sloper, Mr. William Thompson
# 36                                 Mamee, Mr. Hanna
# 55                                Woolner, Mr. Hugh
# 65                         Moubarek, Master. Gerios
# 74                                    Bing, Mr. Lee
# 78                    Caldwell, Master. Alden Gates
# 81                      Sheerlinck, Mr. Jan Baptist
# 97                  Greenfield, Mr. William Bertram
# 107                          Moss, Mr. Albert Johan
# 125                    Nicola-Yarred, Master. Elias
# 127                       Madsen, Mr. Fridtjof Arne
# 146    Andersson, Mr. August Edvard ("Wennerstrom")
# Name: Name, dtype: object

# %%
titanic_train.Name[(titanic_train.Survived == 1) & (titanic_train.Sex == "male")]
# Out:
# 17                     Williams, Mr. Charles Eugene
# 21                            Beesley, Mr. Lawrence
# 23                     Sloper, Mr. William Thompson
# 36                                 Mamee, Mr. Hanna
# 55                                Woolner, Mr. Hugh
# 65                         Moubarek, Master. Gerios
# 74                                    Bing, Mr. Lee
# 78                    Caldwell, Master. Alden Gates
# 81                      Sheerlinck, Mr. Jan Baptist
# 97                  Greenfield, Mr. William Bertram
# 107                          Moss, Mr. Albert Johan
# 125                    Nicola-Yarred, Master. Elias
# 127                       Madsen, Mr. Fridtjof Arne
# 146    Andersson, Mr. August Edvard ("Wennerstrom")
# Name: Name, dtype: object

# %%
titanic_train.Name[(titanic_train.Survived == 0) & (titanic_train.Sex == "male")]
# Out:
# 0              Braund, Mr. Owen Harris
# 4             Allen, Mr. William Henry
# 5                     Moran, Mr. James
# 6              McCarthy, Mr. Timothy J
# 7       Palsson, Master. Gosta Leonard
#                     ...
# 150         Bateman, Rev. Robert James
# 152                   Meo, Mr. Alfonzo
# 153    van Billiard, Mr. Austin Blyler
# 154              Olsen, Mr. Ole Martin
# 155        Williams, Mr. Charles Duane
# Name: Name, Length: 86, dtype: object

# %%
titanic_train['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 151                    Pears, Mrs. Thomas (Edith Wearne)
# 152                                     Meo, Mr. Alfonzo
# 153                      van Billiard, Mr. Austin Blyler
# 154                                Olsen, Mr. Ole Martin
# 155                          Williams, Mr. Charles Duane
# Name: Name, Length: 156, dtype: object

# %%
titanic_train.Name
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 151                    Pears, Mrs. Thomas (Edith Wearne)
# 152                                     Meo, Mr. Alfonzo
# 153                      van Billiard, Mr. Austin Blyler
# 154                                Olsen, Mr. Ole Martin
# 155                          Williams, Mr. Charles Duane
# Name: Name, Length: 156, dtype: object

# %%
titanic_train[(titanic_train['Sex']== 'male') & (titanic_train['Survived']== 1)]['Name']
# Out:
# 17                     Williams, Mr. Charles Eugene
# 21                            Beesley, Mr. Lawrence
# 23                     Sloper, Mr. William Thompson
# 36                                 Mamee, Mr. Hanna
# 55                                Woolner, Mr. Hugh
# 65                         Moubarek, Master. Gerios
# 74                                    Bing, Mr. Lee
# 78                    Caldwell, Master. Alden Gates
# 81                      Sheerlinck, Mr. Jan Baptist
# 97                  Greenfield, Mr. William Bertram
# 107                          Moss, Mr. Albert Johan
# 125                    Nicola-Yarred, Master. Elias
# 127                       Madsen, Mr. Fridtjof Arne
# 146    Andersson, Mr. August Edvard ("Wennerstrom")
# Name: Name, dtype: object

# %% [markdown]
# ## Adding a New Column

# %%
titanic_train['new_col'] = "XYZ"

# %%
titanic_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked new_col
# 0      0         A/5 21171   7.2500   NaN        S     XYZ
# 1      0          PC 17599  71.2833   C85        C     XYZ
# 2      0  STON/O2. 3101282   7.9250   NaN        S     XYZ
# 3      0            113803  53.1000  C123        S     XYZ
# ...

# %% [markdown]
# ## Convert List into Series ?

# %%
l = [1,2,3,4,5]

# %%
pd.Series(l)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %% [markdown]
# ## COnvert Dictionary into Dataframe ?

# %%
d = {'key' : "sudh" , "title" :"kumar" , "mail_id" : "sudha@gmail.com"}

# %% [markdown]
# > ## Without index converting a dictionary into dataframe will give an error

# %%
pd.DataFrame(d)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-3449b472dc69> in <module>
# ----> 1 pd.DataFrame(d)
#
# ~\.conda\envs\gputest\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     466
#     467         elif isinstance(data, dict):
# --> 468             mgr = init_dict(data, index, columns, dtype=dtype)
#     469         elif isinstance(data, ma.MaskedArray):
#     470             import numpy.ma.mrecords as mrecords
#
# ~\.conda\envs\gputest\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     281             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     282         ]
# --> 283     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     284
#     285
#
# ...

# %%
pd.DataFrame(d,index=[0,1,2])
# Out:
#     key  title          mail_id
# 0  sudh  kumar  sudha@gmail.com
# 1  sudh  kumar  sudha@gmail.com
# 2  sudh  kumar  sudha@gmail.com

# %% [markdown]
# ## COnvert Dictionary into Series ?

# %%
d = {'key' : "sudh" , "title" :"kumar" , "mail_id" : "sudha@gmail.com"}

# %%
pd.Series(d)
# Out:
# key                   sudh
# title                kumar
# mail_id    sudha@gmail.com
# dtype: object

# %% [markdown]
# ## COnvert Numpy into DataFrame ?

# %%
arr  = np.random.randn(3,4)

# %%
pd.DataFrame(arr)
# Out:
#           0         1         2         3
# 0  0.249873 -0.894455 -1.157412 -1.166982
# 1 -0.803732  2.011122 -0.396354 -0.999178
# 2 -0.763614 -1.364206  0.064865 -0.326826

# %% [markdown]
# > ## Can't convert 2d array into Series
#
# > ## To covert into series array should be 1d array

# %%
pd.Series(arr)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-123-409226d0ba63> in <module>
# ----> 1 pd.Series(arr)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     325                     data = data.copy()
#     326             else:
# --> 327                 data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#     328
#     329                 data = SingleBlockManager.from_array(data, index)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     494     elif subarr.ndim > 1:
#     495         if isinstance(data, np.ndarray):
# --> 496             raise Exception("Data must be 1-dimensional")
#     497         else:
# ...

# %%
pd.Series(np.array([4,5,6,7,8]))
# Out:
# 0    4
# 1    5
# 2    6
# 3    7
# 4    8
# dtype: int32

# %%
ser = pd.Series(np.array([4,5,6,7,8]),index=['a','b','XYZ',"ABC",'c'])

# %%
ser
# Out:
# a      4
# b      5
# XYZ    6
# ABC    7
# c      8
# dtype: int32

# %%
ser['XYZ']
# Out:
# 6

# %%
ser.iloc[0]
# Out:
# 4

# %% [markdown]
# > ## If we try to index iloc with Non-Integer then it will give an error
#
# > ## loc :: In Non-Integer Index or Named Index, we can use loc

# %%
ser.iloc['XYZ']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-7b12e3e3651e> in <module>
# ----> 1 ser.iloc['XYZ']
#
# ~\.conda\envs\gputest\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# ~\.conda\envs\gputest\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1491             key = item_from_zerodim(key)
#    1492             if not is_integer(key):
# -> 1493                 raise TypeError("Cannot index by location index with a non-integer key")
#    1494
#    1495             # validate the location
#
# TypeError: Cannot index by location index with a non-integer key

# %%
ser.loc['XYZ']
# Out:
# 6

# %%
ser['XYZ']
# Out:
# 6

# %%
ser1 = pd.Series(np.array([4,5,6,7,8]),index=[45,51,62,"ABC",83])

# %%
ser1
# Out:
# 45     4
# 51     5
# 62     6
# ABC    7
# 83     8
# dtype: int32

# %% [markdown]
# * ## 51 is integer and iloc takes integer index , Then still Why it is giving an Error ??
#
# * # iloc takes default Indexes
#
# # loc ::
# * ## To access data using Custom indexes use loc
# * ## To access data using Named indexes use loc
#
# # iloc ::
# * ## To access data using Default indexes use loc

# %%
ser1.iloc[51]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-82-280a5a11aba7> in <module>
# ----> 1 ser1.iloc[51]
#
# ~\.conda\envs\gputest\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# ~\.conda\envs\gputest\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1494
#    1495             # validate the location
# -> 1496             self._validate_integer(key, axis)
#    1497
#    1498             return self.obj._ixs(key, axis=axis)
#
# ~\.conda\envs\gputest\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
#    1435         len_axis = len(self.obj._get_axis(axis))
# ...

# %%
ser1.loc[51]
# Out:
# 5

# %% [markdown]
# ## COnvert Numpy array to Dataframe
# ## Give Custom Row and Column Names
# ## Access Particular Rows and Columns using loc

# %%
df = pd.DataFrame(np.random.randint(3,6,(4,5)),index=['a','b','c','d'],columns=['x','y','z','u','v'])

# %%
df
# Out:
#    x  y  z  u  v
# a  4  4  5  5  4
# b  4  4  5  3  5
# c  3  4  3  3  3
# d  3  5  5  3  4

# %% [markdown]
# ## Using loc fetcing Data
# > ## Custom Indexes

# %%
df.loc[['c','d'],['z','u']]
# Out:
#    z  u
# c  3  3
# d  5  3

# %% [markdown]
# ## Using iloc fetcing Data
# > ## Default Indexes

# %%
df.iloc[[2,3],[2,3]]
# Out:
#    z  u
# c  5  5
# d  4  4

# %%
df.iloc[2:,2:4]
# Out:
#    z  u
# c  5  5
# d  4  4

# %%
df
# Out:
#    x  y  z  u  v
# a  4  5  5  3  3
# b  4  4  3  4  4
# c  4  5  5  5  3
# d  3  3  4  4  5

# %% [markdown]
# ## Create a New Column and The Colum Values are the sum of x and y Column values

# %%
df['new'] = df['x'] + df.y

# %%
df
# Out:
#    x  y  z  u  v  new
# a  4  4  5  5  4    8
# b  4  4  5  3  5    8
# c  3  4  3  3  3    7
# d  3  5  5  3  4    8

# %% [markdown]
# ## Drop a Column (axis = 1) or Drop a Row (axis = 0)
# * ## inplace = True : Replace changes in the same DataFrame
#
# * ## axis = 0 :: Row
# * ## axis = 1 :: Column

# %%
df.drop('x',axis=1)
df
# Out:
#    x  y  z  u  v  new
# a  4  4  5  5  4    8
# b  4  4  5  3  5    8
# c  3  4  3  3  3    7
# d  3  5  5  3  4    8

# %%
df.drop('x',axis=1,inplace=True)
df
# Out:
#    y  z  u  v  new
# a  4  5  5  4    8
# b  4  5  3  5    8
# c  4  3  3  3    7
# d  5  5  3  4    8

# %%
df = df.drop('a')

# %%
df
# Out:
#    y  z  u  v  new
# b  4  3  4  4    8
# d  3  4  4  5    6

# %% [markdown]
# ## Create a Dataframe with Values follows Gaussian Distribution
# ## Extract Negative values
# ## Extract Column and Row names where values are negative

# %%
np.random.seed(23)
df = pd.DataFrame(np.random.randn(4,5),index=['a','b','c','d'],columns=['x','y','z','u','v'])

# %%
df
# Out:
#           x         y         z         u         v
# a  0.666988  0.025813 -0.777619  0.948634  0.701672
# b -1.051082 -0.367548 -1.137460 -1.322148  1.772258
# c -0.347459  0.670140  0.322272  0.060343 -1.043450
# d -1.009942  0.441736  1.128877 -1.838068 -0.938769

# %% [markdown]
# ## Extract Negative values

# %%
df<0
# Out:
#        y      z      u      v    new
# a  False  False  False  False  False
# b  False  False  False  False  False
# c  False  False  False  False  False
# d  False  False  False  False  False

# %%
df[df<0]
# Out:
#           x         y         z         u         v
# a       NaN       NaN -0.777619       NaN       NaN
# b -1.051082 -0.367548 -1.137460 -1.322148       NaN
# c -0.347459       NaN       NaN       NaN -1.043450
# d -1.009942       NaN       NaN -1.838068 -0.938769

# %%
df.values[df.values<0]
# Out:
# array([-0.77761941, -1.05108156, -0.36754812, -1.13745969, -1.32214752,
#        -0.34745899, -1.04345   , -1.00994188, -1.83806777, -0.93876863])

# %% [markdown]
# ## Extract Column and Row names where values are negative

# %%
c = df.values[df.values<0]
for i in df.columns:
    for j in df.index:
        if df.loc[j,i] in c:
            print(i,j)
# Out:
# x b
# x c
# x d
# y b
# z a
# z b
# u b
# u d
# v c
# v d

# %%
l = df.values[df<0]
for c in df.columns:
    for v in df.index:
        if df[c][v] in l:
            print(c,v,df[c][v])
# Out:
# x b -1.0510815639071178
# x c -0.34745899102186334
# x d -1.0099418765878465
# y b -0.3675481161171661
# z a -0.7776194131918178
# z b -1.1374596907250272
# u b -1.3221475225908594
# u d -1.8380677677579502
# v c -1.0434500017467254
# v d -0.9387686311201282

# %%
for i in df.columns:
    for j in df.index:
        if df.loc[j,i]<0:
            print(i,j,df.loc[j,i])
# Out:
# x b -1.0510815639071178
# x c -0.34745899102186334
# x d -1.0099418765878465
# y b -0.3675481161171661
# z a -0.7776194131918178
# z b -1.1374596907250272
# u b -1.3221475225908594
# u d -1.8380677677579502
# v c -1.0434500017467254
# v d -0.9387686311201282

# %%
k=df<0
for i in k.columns:
    for j in k.index:
        if k[i][j]==True:
            print(i,j)

# %% [markdown]
# * ## Create Dictionary along with np.nan
# * ## Convert Dictionary to DataFrame
# * ## Drop nan values (axis = 1) and (axis = 0)
# * ## Threshold : Requires That many non Nan Values , Then It wont drop. If that many Non Nan values are Not vailable then drop it
# * ## Fill Nan Values with random value or with mean

# %%
d = {'key1':[1,2,3,4,np.nan],"key2":["XYZ" ,"PQRS" , np.nan,5,6] ,'key3' :[np.nan,np.nan,np.nan,3,8]}
df = pd.DataFrame(d)

# %%
df
# Out:
#    key1  key2  key3
# 0   1.0   XYZ   NaN
# 1   2.0  PQRS   NaN
# 2   3.0   NaN   NaN
# 3   4.0     5   3.0
# 4   NaN     6   8.0

# %%
df.dropna()
# Out:
#    key1 key2  key3
# 3   4.0    5   3.0

# %%
df.dropna(axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
df
# Out:
#    key1   key2  key3
# 0   1.0   sudh   NaN
# 1   2.0  kumar   NaN
# 2   3.0    NaN   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna(thresh=0)
# Out:
#    key1   key2  key3
# 0   1.0   sudh   NaN
# 1   2.0  kumar   NaN
# 2   3.0    NaN   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna(thresh=1)
# Out:
#    key1   key2  key3
# 0   1.0   sudh   NaN
# 1   2.0  kumar   NaN
# 2   3.0    NaN   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna(thresh=2)
# Out:
#    key1   key2  key3
# 0   1.0   sudh   NaN
# 1   2.0  kumar   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna(thresh=3)
# Out:
#    key1 key2  key3
# 3   4.0    5   3.0

# %%
df
# Out:
#    key1  key2  key3
# 0   1.0   XYZ   NaN
# 1   2.0  PQRS   NaN
# 2   3.0   NaN   NaN
# 3   4.0     5   3.0
# 4   NaN     6   8.0

# %%
df.dropna(thresh=4)
# Out:
# Empty DataFrame
# Columns: [key1, key2, key3]
# Index: []

# %%
df.dropna(axis=1 , thresh=3)
# Out:
#    key1  key2
# 0   1.0   XYZ
# 1   2.0  PQRS
# 2   3.0   NaN
# 3   4.0     5
# 4   NaN     6

# %%
df
# Out:
#    key1  key2  key3
# 0   1.0   XYZ   NaN
# 1   2.0  PQRS   NaN
# 2   3.0   NaN   NaN
# 3   4.0     5   3.0
# 4   NaN     6   8.0

# %%
df.fillna(567)
# Out:
#     key1  key2   key3
# 0    1.0   XYZ  567.0
# 1    2.0  PQRS  567.0
# 2    3.0   567  567.0
# 3    4.0     5    3.0
# 4  567.0     6    8.0

# %%
df.fillna(value=df['key1'].mean())
# Out:
#    key1  key2  key3
# 0   1.0   XYZ   2.5
# 1   2.0  PQRS   2.5
# 2   3.0   2.5   2.5
# 3   4.0     5   3.0
# 4   2.5     6   8.0

# %%
df
# Out:
#    key1  key2  key3
# 0   1.0   XYZ   NaN
# 1   2.0  PQRS   NaN
# 2   3.0   NaN   NaN
# 3   4.0     5   3.0
# 4   NaN     6   8.0

# %% [markdown]
# * # Groupby
# * ## mean()
# * ## sum()
# * ## describe()
# * ## Extract Data from describe()
# * ## Describe Transpose

# %%
d1 = {'name' :['ABC' , 'DEF' , 'GHI', 'JKL' ,'MNO'],"mail_id" :["ABC@gmail.com", "DEF@gmail.com","ABC@gmail.com",'JKL@gmail.com',"DEF@gmail.com"],
     'salary' :[100,200,500,200,500]}

# %%
df = pd.DataFrame(d1)

# %%
df
# Out:
#   name        mail_id  salary
# 0  ABC  ABC@gmail.com     100
# 1  DEF  DEF@gmail.com     200
# 2  GHI  ABC@gmail.com     500
# 3  JKL  JKL@gmail.com     200
# 4  MNO  DEF@gmail.com     500

# %%
df.groupby('mail_id').mean()
# Out:
#                salary
# mail_id
# ABC@gmail.com     300
# DEF@gmail.com     350
# JKL@gmail.com     200

# %%
df.groupby('mail_id').sum()
# Out:
#                salary
# mail_id
# ABC@gmail.com     600
# DEF@gmail.com     700
# JKL@gmail.com     200

# %%
type(df.groupby('mail_id').describe())
# Out:
# pandas.core.frame.DataFrame

# %%
df.groupby('mail_id').describe()
# Out:
#               salary
#                count   mean         std    min    25%    50%    75%    max
# mail_id
# ABC@gmail.com    2.0  300.0  282.842712  100.0  200.0  300.0  400.0  500.0
# DEF@gmail.com    2.0  350.0  212.132034  200.0  275.0  350.0  425.0  500.0
# JKL@gmail.com    1.0  200.0         NaN  200.0  200.0  200.0  200.0  200.0

# %%
df.groupby('mail_id').describe().loc['ABC@gmail.com']
# Out:
# salary  count      2.000000
#         mean     300.000000
#         std      282.842712
#         min      100.000000
#         25%      200.000000
#         50%      300.000000
#         75%      400.000000
#         max      500.000000
# Name: ABC@gmail.com, dtype: float64

# %%
df.groupby('mail_id').describe().loc['ABC@gmail.com']['salary']['mean']
# Out:
# 300.0

# %%
df.groupby('mail_id').describe().T
# Out:
# mail_id       ABC@gmail.com  DEF@gmail.com  JKL@gmail.com
# salary count       2.000000       2.000000            1.0
#        mean      300.000000     350.000000          200.0
#        std       282.842712     212.132034            NaN
#        min       100.000000     200.000000          200.0
#        25%       200.000000     275.000000          200.0
#        50%       300.000000     350.000000          200.0
#        75%       400.000000     425.000000          200.0
#        max       500.000000     500.000000          200.0

# %%
df.groupby('mail_id').describe()
# Out:
#               salary
#                count   mean         std    min    25%    50%    75%    max
# mail_id
# ABC@gmail.com    2.0  300.0  282.842712  100.0  200.0  300.0  400.0  500.0
# DEF@gmail.com    2.0  350.0  212.132034  200.0  275.0  350.0  425.0  500.0
# JKL@gmail.com    1.0  200.0         NaN  200.0  200.0  200.0  200.0  200.0

# %% [markdown]
# # Concatenate
# * ## Create Three different Dataframes from numpy arrays seperately
# * ## COncatenate three to form a single DataFrame with (axis = 1) and (axis = 0)

# %%
arr1 = np.random.randn(3,4)

# %%
arr2 = np.random.randn(3,4)

# %%
arr3 = np.random.randn(3,4)

# %%
df1 = pd.DataFrame(arr1,columns=["A","B","C","D"],index = [0,1,2])

# %%
df2 = pd.DataFrame(arr2,columns=["A","B","C","D"],index = [0,1,2])

# %%
df2
# Out:
#           A         B         C         D
# 0 -0.168698 -0.225506 -1.320261 -0.882418
# 1  0.243104 -1.405327 -0.215816 -0.649603
# 2 -1.678331  1.055575 -0.002299  1.823348

# %%
df3 = pd.DataFrame(arr3,columns=["A","B","C","D"],index = [0,1,2])

# %%
df1
# Out:
#           A         B         C         D
# 0 -2.514562 -1.279378  1.178987  0.656248
# 1 -0.407654  0.935506  0.446102  1.273216
# 2 -0.216739  0.800256 -1.059594 -0.637772

# %%
df2
# Out:
#           A         B         C         D
# 0 -0.168698 -0.225506 -1.320261 -0.882418
# 1  0.243104 -1.405327 -0.215816 -0.649603
# 2 -1.678331  1.055575 -0.002299  1.823348

# %%
df3
# Out:
#           A         B         C         D
# 0 -0.601989  1.517713 -1.962739  0.185090
# 1  0.914915  0.504552  0.388933  1.199763
# 2  0.139732 -0.021725  0.894451 -0.356252

# %%
df4 = pd.concat([df1,df2,df3])

# %%
df4
# Out:
#           A         B         C         D
# 0 -2.514562 -1.279378  1.178987  0.656248
# 1 -0.407654  0.935506  0.446102  1.273216
# 2 -0.216739  0.800256 -1.059594 -0.637772
# 0 -0.168698 -0.225506 -1.320261 -0.882418
# 1  0.243104 -1.405327 -0.215816 -0.649603
# 2 -1.678331  1.055575 -0.002299  1.823348
# 0 -0.601989  1.517713 -1.962739  0.185090
# 1  0.914915  0.504552  0.388933  1.199763
# 2  0.139732 -0.021725  0.894451 -0.356252

# %% [markdown]
# # Reset Index

# %%
df1.reset_index(drop=True, inplace=True)
df2.reset_index(drop=True, inplace=True)
df3.reset_index(drop=True, inplace=True)

# %%
df5 = pd.concat([df1,df2,df3],axis=1)
df5
# Out:
#           A         B         C         D         A         B         C  \
# 0 -2.514562 -1.279378  1.178987  0.656248 -0.168698 -0.225506 -1.320261
# 1 -0.407654  0.935506  0.446102  1.273216  0.243104 -1.405327 -0.215816
# 2 -0.216739  0.800256 -1.059594 -0.637772 -1.678331  1.055575 -0.002299
#
#           D         A         B         C         D
# 0 -0.882418 -0.601989  1.517713 -1.962739  0.185090
# 1 -0.649603  0.914915  0.504552  0.388933  1.199763
# 2  1.823348  0.139732 -0.021725  0.894451 -0.356252

# %%
df4.iloc[0]
# Out:
# A   -2.514562
# B   -1.279378
# C    1.178987
# D    0.656248
# Name: 0, dtype: float64

# %%
df4.loc[0]
# Out:
#           A         B         C         D
# 0 -2.514562 -1.279378  1.178987  0.656248
# 0 -0.168698 -0.225506 -1.320261 -0.882418
# 0 -0.601989  1.517713 -1.962739  0.185090

# %%
df5
# Out:
#           A         B         C         D         A         B         C  \
# 0  0.728876  1.968435 -0.547788 -0.679418 -0.071324 -0.045438  1.040886
# 1 -2.506230  0.146960  0.606195 -0.022539 -0.420844 -0.551989 -0.121098
# 2  0.013422  0.935945  0.420623  0.411620  0.512137  0.131538 -0.331617
#
#           D         A         B         C         D
# 0 -0.094035  0.619114 -0.992574 -0.161346  1.192404
# 1  0.190141  0.250737 -0.813616  0.703624 -0.268142
# 2 -1.632386 -0.482559  1.244610  0.676860  3.187503

# %%
df5['A']
# Out:
#           A         A         A
# 0 -2.514562 -0.168698 -0.601989
# 1 -0.407654  0.243104  0.914915
# 2 -0.216739 -1.678331  0.139732

# %%
df5.iloc[:,4]
# Out:
# 0   -0.168698
# 1    0.243104
# 2   -1.678331
# Name: A, dtype: float64

# %%
df1 = pd.DataFrame(arr1,columns=["A","B","C","D"],index = [0,1,2])
df2 = pd.DataFrame(arr2,columns=["A","B","C","D"],index = [3,4,5])
df3 = pd.DataFrame(arr3,columns=["A","B","C","D"],index = [6,7,8])

# %%
pd.concat([df1,df2,df3],axis=1)
# Out:
#           A         B         C         D         A         B         C  \
# 0 -2.514562 -1.279378  1.178987  0.656248       NaN       NaN       NaN
# 1 -0.407654  0.935506  0.446102  1.273216       NaN       NaN       NaN
# 2 -0.216739  0.800256 -1.059594 -0.637772       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN -0.168698 -0.225506 -1.320261
# 4       NaN       NaN       NaN       NaN  0.243104 -1.405327 -0.215816
# 5       NaN       NaN       NaN       NaN -1.678331  1.055575 -0.002299
# 6       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 7       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 8       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#           D         A         B         C         D
# 0       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN
# ...

# %%
pd.concat([df1,df2,df3],axis=1).fillna(0)
# Out:
#           A         B         C         D         A         B         C  \
# 0 -2.514562 -1.279378  1.178987  0.656248  0.000000  0.000000  0.000000
# 1 -0.407654  0.935506  0.446102  1.273216  0.000000  0.000000  0.000000
# 2 -0.216739  0.800256 -1.059594 -0.637772  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.000000  0.000000 -0.168698 -0.225506 -1.320261
# 4  0.000000  0.000000  0.000000  0.000000  0.243104 -1.405327 -0.215816
# 5  0.000000  0.000000  0.000000  0.000000 -1.678331  1.055575 -0.002299
# 6  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 7  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 8  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#           D         A         B         C         D
# 0  0.000000  0.000000  0.000000  0.000000  0.000000
# 1  0.000000  0.000000  0.000000  0.000000  0.000000
# 2  0.000000  0.000000  0.000000  0.000000  0.000000
# ...

# %% [markdown]
# # Reset Index

# %%
df1.reset_index(drop=True, inplace=True)
df2.reset_index(drop=True, inplace=True)
df3.reset_index(drop=True, inplace=True)

# %%
pd.concat([df1,df2,df3],axis=1).fillna(0)
# Out:
#           A         B         C         D         A         B         C  \
# 0 -2.514562 -1.279378  1.178987  0.656248 -0.168698 -0.225506 -1.320261
# 1 -0.407654  0.935506  0.446102  1.273216  0.243104 -1.405327 -0.215816
# 2 -0.216739  0.800256 -1.059594 -0.637772 -1.678331  1.055575 -0.002299
#
#           D         A         B         C         D
# 0 -0.882418 -0.601989  1.517713 -1.962739  0.185090
# 1 -0.649603  0.914915  0.504552  0.388933  1.199763
# 2  1.823348  0.139732 -0.021725  0.894451 -0.356252

# %%
df1
# Out:
#           A         B         C         D
# 0 -2.514562 -1.279378  1.178987  0.656248
# 1 -0.407654  0.935506  0.446102  1.273216
# 2 -0.216739  0.800256 -1.059594 -0.637772

# %%
df2
# Out:
#           A         B         C         D
# 0 -0.168698 -0.225506 -1.320261 -0.882418
# 1  0.243104 -1.405327 -0.215816 -0.649603
# 2 -1.678331  1.055575 -0.002299  1.823348

# %% [markdown]
# * # Merge

# %%
np.random.seed(23)
arr1 = np.random.randn(3,4)
np.random.seed(23)
arr2 = np.random.randn(3,4)
df11 = pd.DataFrame(arr1,columns=["A","B","C","D"],index = [0,1,2])
df22 = pd.DataFrame(arr2,columns=["A","B","C","D"],index = [3,4,5])

# %%
df11
# Out:
#           A         B         C         D
# 0  0.666988  0.025813 -0.777619  0.948634
# 1  0.701672 -1.051082 -0.367548 -1.137460
# 2 -1.322148  1.772258 -0.347459  0.670140

# %%
df22
# Out:
#           A         B         C         D
# 3  0.666988  0.025813 -0.777619  0.948634
# 4  0.701672 -1.051082 -0.367548 -1.137460
# 5 -1.322148  1.772258 -0.347459  0.670140

# %%
pd.merge(df11,df22,on= "A")
# Out:
#           A       B_x       C_x       D_x       B_y       C_y       D_y
# 0  0.666988  0.025813 -0.777619  0.948634  0.025813 -0.777619  0.948634
# 1  0.701672 -1.051082 -0.367548 -1.137460 -1.051082 -0.367548 -1.137460
# 2 -1.322148  1.772258 -0.347459  0.670140  1.772258 -0.347459  0.670140

# %%
df1 = pd.DataFrame({'key': ['K0', 'K8', 'K2', 'K3'],
                     'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3']})
   
df2 = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                          'C': ['C0', 'C1', 'C2', 'C3'],
                          'D': ['D0', 'D1', 'D2', 'D3']})

# %%
df1
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K8  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3

# %%
df2
# Out:
#   key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K3  C3  D3

# %% [markdown]
# # inner join :: Intersection

# %%
pd.merge(df1,df2,on= 'key')
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K2  A2  B2  C2  D2
# 2  K3  A3  B3  C3  D3

# %% [markdown]
# # Outer join :: Except Intersection

# %%
pd.merge(df1,df2,on= 'key',how = 'outer')
# Out:
#   key    A    B    C    D
# 0  K0   A0   B0   C0   D0
# 1  K8   A1   B1  NaN  NaN
# 2  K2   A2   B2   C2   D2
# 3  K3   A3   B3   C3   D3
# 4  K1  NaN  NaN   C1   D1

# %% [markdown]
# # Left join ::

# %%
pd.merge(df1,df2,on= 'key',how = 'left')
# Out:
#   key   A   B    C    D
# 0  K0  A0  B0   C0   D0
# 1  K8  A1  B1  NaN  NaN
# 2  K2  A2  B2   C2   D2
# 3  K3  A3  B3   C3   D3

# %% [markdown]
# # Right join ::

# %%
pd.merge(df1,df2,on= 'key',how = 'right')
# Out:
#   key    A    B   C   D
# 0  K0   A0   B0  C0  D0
# 1  K1  NaN  NaN  C1  D1
# 2  K2   A2   B2  C2  D2
# 3  K3   A3   B3  C3  D3

# %% [markdown]
# # Join ::

# %%
df1 = pd.DataFrame({'key1': ['K0', 'K0', 'K1', 'K2'],
                     'key2': ['K0', 'K1', 'K0', 'K1'],
                        'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3']})
    
df2 = pd.DataFrame({'key1': ['K0', 'K1', 'K1', 'K2'],
                               'key2': ['K0', 'K0', 'K0', 'K0'],
                                  'C': ['C0', 'C1', 'C2', 'C3'],
                                  'D': ['D0', 'D1', 'D2', 'D3']})

# %%
df1
# Out:
#   key1 key2   A   B
# 0   K0   K0  A0  B0
# 1   K0   K1  A1  B1
# 2   K1   K0  A2  B2
# 3   K2   K1  A3  B3

# %%
df2
# Out:
#   key1 key2   C   D
# 0   K0   K0  C0  D0
# 1   K1   K0  C1  D1
# 2   K1   K0  C2  D2
# 3   K2   K0  C3  D3

# %%
pd.merge(df1,df2,on = ['key1','key2'])
# Out:
#   key1 key2   A   B   C   D
# 0   K0   K0  A0  B0  C0  D0
# 1   K1   K0  A2  B2  C1  D1
# 2   K1   K0  A2  B2  C2  D2

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2'],
                     'B': ['B0', 'B1', 'B2']},
                      index=['K0', 'K1', 'K2']) 

df2 = pd.DataFrame({'C': ['C0', 'C2', 'C3'],
                    'D': ['D0', 'D2', 'D3']},
                      index=['K0', 'K2', 'K3'])

# %%
df1
# Out:
#      A   B
# K0  A0  B0
# K1  A1  B1
# K2  A2  B2

# %%
df2
# Out:
#      C   D
# K0  C0  D0
# K2  C2  D2
# K3  C3  D3

# %%
df1.join(df2)
# Out:
#      A   B    C    D
# K0  A0  B0   C0   D0
# K1  A1  B1  NaN  NaN
# K2  A2  B2   C2   D2

# %%
df1.join(df2,how = 'outer')
# Out:
#       A    B    C    D
# K0   A0   B0   C0   D0
# K1   A1   B1  NaN  NaN
# K2   A2   B2   C2   D2
# K3  NaN  NaN   C3   D3

# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(20)
df = pd.DataFrame(np.random.randn(10,4) , index = pd.date_range('2021-07-18',periods=10),columns=['a','b','c','d'])
df
# Out:
#                    a         b         c         d
# 2021-07-18  0.883893  0.195865  0.357537 -2.343262
# 2021-07-19 -1.084833  0.559696  0.939469 -0.978481
# 2021-07-20  0.503097  0.406414  0.323461 -0.493411
# 2021-07-21 -0.792017 -0.842368 -1.279503  0.245715
# 2021-07-22 -0.044195  1.567633  1.051109  0.406368
# 2021-07-23 -0.168646 -3.189703  1.120132  1.332778
# 2021-07-24 -0.243339 -0.130031 -0.109017  1.556186
# 2021-07-25  0.128778 -2.066949 -0.885493 -1.104579
# 2021-07-26  0.932866  2.059838 -0.934938 -1.612990
# 2021-07-27  0.527070 -1.551101  0.329613 -1.136527

# %%
df['new'] = df['c'] + df['d']
df
# Out:
#                    a         b         c         d       new
# 2021-07-18  0.883893  0.195865  0.357537 -2.343262 -1.985725
# 2021-07-19 -1.084833  0.559696  0.939469 -0.978481 -0.039012
# 2021-07-20  0.503097  0.406414  0.323461 -0.493411 -0.169950
# 2021-07-21 -0.792017 -0.842368 -1.279503  0.245715 -1.033787
# 2021-07-22 -0.044195  1.567633  1.051109  0.406368  1.457477
# 2021-07-23 -0.168646 -3.189703  1.120132  1.332778  2.452910
# 2021-07-24 -0.243339 -0.130031 -0.109017  1.556186  1.447169
# 2021-07-25  0.128778 -2.066949 -0.885493 -1.104579 -1.990073
# 2021-07-26  0.932866  2.059838 -0.934938 -1.612990 -2.547928
# 2021-07-27  0.527070 -1.551101  0.329613 -1.136527 -0.806913

# %% [markdown]
# # filter based Data Manipulations
# ## apply(lambda x : Condition)
# ## apply(function Call)

# %%
df["new_square_d"] = df["d"].apply(lambda x : x**2)
df
# Out:
#                    a         b         c         d       new  new_square_d
# 2021-07-18  0.883893  0.195865  0.357537 -2.343262 -1.985725      5.490876
# 2021-07-19 -1.084833  0.559696  0.939469 -0.978481 -0.039012      0.957425
# 2021-07-20  0.503097  0.406414  0.323461 -0.493411 -0.169950      0.243454
# 2021-07-21 -0.792017 -0.842368 -1.279503  0.245715 -1.033787      0.060376
# 2021-07-22 -0.044195  1.567633  1.051109  0.406368  1.457477      0.165135
# 2021-07-23 -0.168646 -3.189703  1.120132  1.332778  2.452910      1.776298
# 2021-07-24 -0.243339 -0.130031 -0.109017  1.556186  1.447169      2.421716
# 2021-07-25  0.128778 -2.066949 -0.885493 -1.104579 -1.990073      1.220096
# 2021-07-26  0.932866  2.059838 -0.934938 -1.612990 -2.547928      2.601737
# 2021-07-27  0.527070 -1.551101  0.329613 -1.136527 -0.806913      1.291693

# %%
df["new_square_d_log"] = df["d"].apply(lambda x : np.log(x))
df
# Out:
#                    a         b         c         d       new  new_square_d  \
# 2021-07-18  0.883893  0.195865  0.357537 -2.343262 -1.985725      5.490876
# 2021-07-19 -1.084833  0.559696  0.939469 -0.978481 -0.039012      0.957425
# 2021-07-20  0.503097  0.406414  0.323461 -0.493411 -0.169950      0.243454
# 2021-07-21 -0.792017 -0.842368 -1.279503  0.245715 -1.033787      0.060376
# 2021-07-22 -0.044195  1.567633  1.051109  0.406368  1.457477      0.165135
# 2021-07-23 -0.168646 -3.189703  1.120132  1.332778  2.452910      1.776298
# 2021-07-24 -0.243339 -0.130031 -0.109017  1.556186  1.447169      2.421716
# 2021-07-25  0.128778 -2.066949 -0.885493 -1.104579 -1.990073      1.220096
# 2021-07-26  0.932866  2.059838 -0.934938 -1.612990 -2.547928      2.601737
# 2021-07-27  0.527070 -1.551101  0.329613 -1.136527 -0.806913      1.291693
#
#             new_square_d_log
# 2021-07-18               NaN
# 2021-07-19               NaN
# 2021-07-20               NaN
# ...

# %%
def test(x):
    if x<0:
        return x
    else:
        return np.log(x)

# %%
df["new_square_d_log_+ve"] = df["d"].apply(test)
df
# Out:
#                    a         b         c         d       new  new_square_d  \
# 2021-07-18  0.883893  0.195865  0.357537 -2.343262 -1.985725      5.490876
# 2021-07-19 -1.084833  0.559696  0.939469 -0.978481 -0.039012      0.957425
# 2021-07-20  0.503097  0.406414  0.323461 -0.493411 -0.169950      0.243454
# 2021-07-21 -0.792017 -0.842368 -1.279503  0.245715 -1.033787      0.060376
# 2021-07-22 -0.044195  1.567633  1.051109  0.406368  1.457477      0.165135
# 2021-07-23 -0.168646 -3.189703  1.120132  1.332778  2.452910      1.776298
# 2021-07-24 -0.243339 -0.130031 -0.109017  1.556186  1.447169      2.421716
# 2021-07-25  0.128778 -2.066949 -0.885493 -1.104579 -1.990073      1.220096
# 2021-07-26  0.932866  2.059838 -0.934938 -1.612990 -2.547928      2.601737
# 2021-07-27  0.527070 -1.551101  0.329613 -1.136527 -0.806913      1.291693
#
#             new_square_d_log  new_square_d_log_+ve
# 2021-07-18               NaN             -2.343262
# ...

# %%
def test1(x):
    if x<0:
        return 1
    elif x>0:
        return 0
    else:
        0

# %%
df["new_a"] = df["a"].apply(test1)
df
# Out:
#                    a         b         c         d       new  new_square_d  \
# 2021-07-18  0.883893  0.195865  0.357537 -2.343262 -1.985725      5.490876
# 2021-07-19 -1.084833  0.559696  0.939469 -0.978481 -0.039012      0.957425
# 2021-07-20  0.503097  0.406414  0.323461 -0.493411 -0.169950      0.243454
# 2021-07-21 -0.792017 -0.842368 -1.279503  0.245715 -1.033787      0.060376
# 2021-07-22 -0.044195  1.567633  1.051109  0.406368  1.457477      0.165135
# 2021-07-23 -0.168646 -3.189703  1.120132  1.332778  2.452910      1.776298
# 2021-07-24 -0.243339 -0.130031 -0.109017  1.556186  1.447169      2.421716
# 2021-07-25  0.128778 -2.066949 -0.885493 -1.104579 -1.990073      1.220096
# 2021-07-26  0.932866  2.059838 -0.934938 -1.612990 -2.547928      2.601737
# 2021-07-27  0.527070 -1.551101  0.329613 -1.136527 -0.806913      1.291693
#
#             new_square_d_log  new_square_d_log_+ve  new_a
# 2021-07-18               NaN             -2.343262      0
# ...

# %% [markdown]
# # df.sort_values(by = column_name)

# %%
df.sort_values(by = 'b')
# Out:
#                    a         b         c         d       new  new_square_d  \
# 2021-07-23 -0.168646 -3.189703  1.120132  1.332778  2.452910      1.776298
# 2021-07-25  0.128778 -2.066949 -0.885493 -1.104579 -1.990073      1.220096
# 2021-07-27  0.527070 -1.551101  0.329613 -1.136527 -0.806913      1.291693
# 2021-07-21 -0.792017 -0.842368 -1.279503  0.245715 -1.033787      0.060376
# 2021-07-24 -0.243339 -0.130031 -0.109017  1.556186  1.447169      2.421716
# 2021-07-18  0.883893  0.195865  0.357537 -2.343262 -1.985725      5.490876
# 2021-07-20  0.503097  0.406414  0.323461 -0.493411 -0.169950      0.243454
# 2021-07-19 -1.084833  0.559696  0.939469 -0.978481 -0.039012      0.957425
# 2021-07-22 -0.044195  1.567633  1.051109  0.406368  1.457477      0.165135
# 2021-07-26  0.932866  2.059838 -0.934938 -1.612990 -2.547928      2.601737
#
#             new_square_d_log  new_square_d_log_+ve  new_a
# 2021-07-23          0.287266              0.287266      1
# ...

# %%
df.sort_values(by = 'b',ascending = True)
# Out:
#                    a         b         c         d       new  new_square_d  \
# 2021-07-23 -0.168646 -3.189703  1.120132  1.332778  2.452910      1.776298
# 2021-07-25  0.128778 -2.066949 -0.885493 -1.104579 -1.990073      1.220096
# 2021-07-27  0.527070 -1.551101  0.329613 -1.136527 -0.806913      1.291693
# 2021-07-21 -0.792017 -0.842368 -1.279503  0.245715 -1.033787      0.060376
# 2021-07-24 -0.243339 -0.130031 -0.109017  1.556186  1.447169      2.421716
# 2021-07-18  0.883893  0.195865  0.357537 -2.343262 -1.985725      5.490876
# 2021-07-20  0.503097  0.406414  0.323461 -0.493411 -0.169950      0.243454
# 2021-07-19 -1.084833  0.559696  0.939469 -0.978481 -0.039012      0.957425
# 2021-07-22 -0.044195  1.567633  1.051109  0.406368  1.457477      0.165135
# 2021-07-26  0.932866  2.059838 -0.934938 -1.612990 -2.547928      2.601737
#
#             new_square_d_log  new_square_d_log_+ve  new_a
# 2021-07-23          0.287266              0.287266      1
# ...

# %%
df.sort_values(by = 'b',ascending = False)
# Out:
#                    a         b         c         d       new  new_square_d  \
# 2021-07-26  0.932866  2.059838 -0.934938 -1.612990 -2.547928      2.601737
# 2021-07-22 -0.044195  1.567633  1.051109  0.406368  1.457477      0.165135
# 2021-07-19 -1.084833  0.559696  0.939469 -0.978481 -0.039012      0.957425
# 2021-07-20  0.503097  0.406414  0.323461 -0.493411 -0.169950      0.243454
# 2021-07-18  0.883893  0.195865  0.357537 -2.343262 -1.985725      5.490876
# 2021-07-24 -0.243339 -0.130031 -0.109017  1.556186  1.447169      2.421716
# 2021-07-21 -0.792017 -0.842368 -1.279503  0.245715 -1.033787      0.060376
# 2021-07-27  0.527070 -1.551101  0.329613 -1.136527 -0.806913      1.291693
# 2021-07-25  0.128778 -2.066949 -0.885493 -1.104579 -1.990073      1.220096
# 2021-07-23 -0.168646 -3.189703  1.120132  1.332778  2.452910      1.776298
#
#             new_square_d_log  new_square_d_log_+ve  new_a
# 2021-07-26               NaN             -1.612990      0
# ...

# %% [markdown]
# # How to make index as Column

# %%
df.index
# Out:
# DatetimeIndex(['2021-07-18', '2021-07-19', '2021-07-20', '2021-07-21',
#                '2021-07-22', '2021-07-23', '2021-07-24', '2021-07-25',
#                '2021-07-26', '2021-07-27'],
#               dtype='datetime64[ns]', freq='D')

# %%
df["new_date"] = df.index
df
# Out:
#                    a         b         c         d       new  new_square_d  \
# 2021-07-18  0.883893  0.195865  0.357537 -2.343262 -1.985725      5.490876
# 2021-07-19 -1.084833  0.559696  0.939469 -0.978481 -0.039012      0.957425
# 2021-07-20  0.503097  0.406414  0.323461 -0.493411 -0.169950      0.243454
# 2021-07-21 -0.792017 -0.842368 -1.279503  0.245715 -1.033787      0.060376
# 2021-07-22 -0.044195  1.567633  1.051109  0.406368  1.457477      0.165135
# 2021-07-23 -0.168646 -3.189703  1.120132  1.332778  2.452910      1.776298
# 2021-07-24 -0.243339 -0.130031 -0.109017  1.556186  1.447169      2.421716
# 2021-07-25  0.128778 -2.066949 -0.885493 -1.104579 -1.990073      1.220096
# 2021-07-26  0.932866  2.059838 -0.934938 -1.612990 -2.547928      2.601737
# 2021-07-27  0.527070 -1.551101  0.329613 -1.136527 -0.806913      1.291693
#
#             new_square_d_log  new_square_d_log_+ve  new_a   new_date
# 2021-07-18               NaN             -2.343262      0 2021-07-18
# ...

# %%
df.dtypes
# Out:
# a                              float64
# b                              float64
# c                              float64
# d                              float64
# new                            float64
# new_square_d                   float64
# new_square_d_log               float64
# new_square_d_log_+ve           float64
# new_a                            int64
# new_date                datetime64[ns]
# dtype: object

# %% [markdown]
# # How to seperate Date , Month and Year ?

# %%
df["day"] = df.index.day
df["month"] = df.index.month
df["year"] = df.index.year
df
# Out:
#                    a         b         c         d       new  new_square_d  \
# 2021-07-18  0.883893  0.195865  0.357537 -2.343262 -1.985725      5.490876
# 2021-07-19 -1.084833  0.559696  0.939469 -0.978481 -0.039012      0.957425
# 2021-07-20  0.503097  0.406414  0.323461 -0.493411 -0.169950      0.243454
# 2021-07-21 -0.792017 -0.842368 -1.279503  0.245715 -1.033787      0.060376
# 2021-07-22 -0.044195  1.567633  1.051109  0.406368  1.457477      0.165135
# 2021-07-23 -0.168646 -3.189703  1.120132  1.332778  2.452910      1.776298
# 2021-07-24 -0.243339 -0.130031 -0.109017  1.556186  1.447169      2.421716
# 2021-07-25  0.128778 -2.066949 -0.885493 -1.104579 -1.990073      1.220096
# 2021-07-26  0.932866  2.059838 -0.934938 -1.612990 -2.547928      2.601737
# 2021-07-27  0.527070 -1.551101  0.329613 -1.136527 -0.806913      1.291693
#
#             new_square_d_log  new_square_d_log_+ve  new_a   new_date  day  \
# ...

# %% [markdown]
# # Add a New column with weekday

# %%
df["weekday"] = df.index.day_name()
df
# Out:
#                    a         b         c         d       new  new_square_d  \
# 2021-07-18  0.883893  0.195865  0.357537 -2.343262 -1.985725      5.490876
# 2021-07-19 -1.084833  0.559696  0.939469 -0.978481 -0.039012      0.957425
# 2021-07-20  0.503097  0.406414  0.323461 -0.493411 -0.169950      0.243454
# 2021-07-21 -0.792017 -0.842368 -1.279503  0.245715 -1.033787      0.060376
# 2021-07-22 -0.044195  1.567633  1.051109  0.406368  1.457477      0.165135
# 2021-07-23 -0.168646 -3.189703  1.120132  1.332778  2.452910      1.776298
# 2021-07-24 -0.243339 -0.130031 -0.109017  1.556186  1.447169      2.421716
# 2021-07-25  0.128778 -2.066949 -0.885493 -1.104579 -1.990073      1.220096
# 2021-07-26  0.932866  2.059838 -0.934938 -1.612990 -2.547928      2.601737
# 2021-07-27  0.527070 -1.551101  0.329613 -1.136527 -0.806913      1.291693
#
#             new_square_d_log  new_square_d_log_+ve  new_a   new_date  day  \
# ...

# %% [markdown]
# # Group by on a particular week day

# %%
df.groupby( by = "weekday").count()
# Out:
#            a  b  c  d  new  new_square_d  new_square_d_log  \
# weekday
# Friday     1  1  1  1    1             1                 1
# Monday     2  2  2  2    2             2                 0
# Saturday   1  1  1  1    1             1                 1
# Sunday     2  2  2  2    2             2                 0
# Thursday   1  1  1  1    1             1                 1
# Tuesday    2  2  2  2    2             2                 0
# Wednesday  1  1  1  1    1             1                 1
#
#            new_square_d_log_+ve  new_a  new_date  day  month  year
# weekday
# Friday                        1      1         1    1      1     1
# Monday                        2      2         2    2      2     2
# Saturday                      1      1         1    1      1     1
# Sunday                        2      2         2    2      2     2
# Thursday                      1      1         1    1      1     1
# Tuesday                       2      2         2    2      2     2
# ...
